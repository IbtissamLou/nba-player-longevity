# %% [markdown]
# *Ce notebook couvre la phase de modélisation, de sélection et d'évaluation des modèles pour la prédiction de la longévité des joueurs en NBA.*
#
# Il comprend :
#
# - *Gestion des classes déséquilibrées*
# -  *L'entraînement et l'évaluation de plusieurs modèles (Random Forest, Balanced Random Forest, XGBoost, SVC)*
# - *L'optimisation des hyperparamètres avec GridSearchCV et Optuna*

# %% [markdown]
# #### 1. Importation des Bibliothèques

# %% [markdown]
# Nous utilisons les bibliothèques suivantes pour la modélisation er l'évaluation des modèles.

# %%
import numpy as np
import pandas as pd
import xgboost as xgb
from sklearn.model_selection import train_test_split, GridSearchCV , StratifiedKFold
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.utils.class_weight import compute_class_weight
from sklearn.ensemble import RandomForestClassifier 
import optuna
from imblearn.ensemble import BalancedRandomForestClassifier
from sklearn.metrics import confusion_matrix, recall_score, precision_score, f1_score, balanced_accuracy_score
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import KFold
from sklearn.svm import SVC
import matplotlib.pyplot as plt
from imblearn.over_sampling import SMOTE
# Out:
# A module that was compiled using NumPy 1.x cannot be run in
# NumPy 2.2.3 as it may crash. To support both 1.x and 2.x
# versions of NumPy, modules must be compiled with NumPy 2.0.
# Some module may need to rebuild instead e.g. with 'pybind11>=2.12'.
#
# If you are a user of the module, the easiest solution will be to
# downgrade to 'numpy<2' or try to upgrade the affected module.
# We expect that some modules will need time to support NumPy 2.
#
# Traceback (most recent call last):  File "/Users/ibtissama/anaconda3/lib/python3.10/runpy.py", line 196, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "/Users/ibtissama/anaconda3/lib/python3.10/runpy.py", line 86, in _run_code
#     exec(code, run_globals)
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/ipykernel_launcher.py", line 17, in <module>
#     app.launch_new_instance()
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/traitlets/config/application.py", line 992, in launch_instance
#     app.start()
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/ipykernel/kernelapp.py", line 711, in start
#     self.io_loop.start()
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/tornado/platform/asyncio.py", line 199, in start
#     self.asyncio_loop.run_forever()
#   File "/Users/ibtissama/anaconda3/lib/python3.10/asyncio/base_events.py", line 603, in run_forever
#     self._run_once()
#   File "/Users/ibtissama/anaconda3/lib/python3.10/asyncio/base_events.py", line 1906, in _run_once
#     handle._run()
#   File "/Users/ibtissama/anaconda3/lib/python3.10/asyncio/events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/ipykernel/kernelbase.py", line 510, in dispatch_queue
#     await self.process_one()
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/ipykernel/kernelbase.py", line 499, in process_one
#     await dispatch(*args)
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/ipykernel/kernelbase.py", line 406, in dispatch_shell
#     await result
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/ipykernel/kernelbase.py", line 729, in execute_request
#     reply_content = await reply_content
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/ipykernel/ipkernel.py", line 411, in do_execute
#     res = shell.run_cell(
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/ipykernel/zmqshell.py", line 531, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 2961, in run_cell
#     result = self._run_cell(
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 3016, in _run_cell
#     result = runner(coro)
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/IPython/core/async_helpers.py", line 129, in _pseudo_sync_runner
#     coro.send(None)
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 3221, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 3400, in run_ast_nodes
#     if await self.run_code(code, result, async_=asy):
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 3460, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "/var/folders/dj/km2r8x2x49n1n14w2nxczv_40000gn/T/ipykernel_40087/310030941.py", line 2, in <module>
#     import pandas as pd
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/pandas/__init__.py", line 26, in <module>
#     from pandas.compat import (
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/pandas/compat/__init__.py", line 27, in <module>
#     from pandas.compat.pyarrow import (
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/pandas/compat/pyarrow.py", line 8, in <module>
#     import pyarrow as pa
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/pyarrow/__init__.py", line 65, in <module>
#     import pyarrow.lib as _lib
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# AttributeError: _ARRAY_API not found
# A module that was compiled using NumPy 1.x cannot be run in
# NumPy 2.2.3 as it may crash. To support both 1.x and 2.x
# versions of NumPy, modules must be compiled with NumPy 2.0.
# Some module may need to rebuild instead e.g. with 'pybind11>=2.12'.
#
# If you are a user of the module, the easiest solution will be to
# downgrade to 'numpy<2' or try to upgrade the affected module.
# We expect that some modules will need time to support NumPy 2.
#
# Traceback (most recent call last):  File "/Users/ibtissama/anaconda3/lib/python3.10/runpy.py", line 196, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "/Users/ibtissama/anaconda3/lib/python3.10/runpy.py", line 86, in _run_code
#     exec(code, run_globals)
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/ipykernel_launcher.py", line 17, in <module>
#     app.launch_new_instance()
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/traitlets/config/application.py", line 992, in launch_instance
#     app.start()
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/ipykernel/kernelapp.py", line 711, in start
#     self.io_loop.start()
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/tornado/platform/asyncio.py", line 199, in start
#     self.asyncio_loop.run_forever()
#   File "/Users/ibtissama/anaconda3/lib/python3.10/asyncio/base_events.py", line 603, in run_forever
#     self._run_once()
#   File "/Users/ibtissama/anaconda3/lib/python3.10/asyncio/base_events.py", line 1906, in _run_once
#     handle._run()
#   File "/Users/ibtissama/anaconda3/lib/python3.10/asyncio/events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/ipykernel/kernelbase.py", line 510, in dispatch_queue
#     await self.process_one()
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/ipykernel/kernelbase.py", line 499, in process_one
#     await dispatch(*args)
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/ipykernel/kernelbase.py", line 406, in dispatch_shell
#     await result
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/ipykernel/kernelbase.py", line 729, in execute_request
#     reply_content = await reply_content
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/ipykernel/ipkernel.py", line 411, in do_execute
#     res = shell.run_cell(
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/ipykernel/zmqshell.py", line 531, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 2961, in run_cell
#     result = self._run_cell(
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 3016, in _run_cell
#     result = runner(coro)
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/IPython/core/async_helpers.py", line 129, in _pseudo_sync_runner
#     coro.send(None)
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 3221, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 3400, in run_ast_nodes
#     if await self.run_code(code, result, async_=asy):
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 3460, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "/var/folders/dj/km2r8x2x49n1n14w2nxczv_40000gn/T/ipykernel_40087/310030941.py", line 2, in <module>
#     import pandas as pd
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/pandas/__init__.py", line 49, in <module>
#     from pandas.core.api import (
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/pandas/core/api.py", line 9, in <module>
#     from pandas.core.dtypes.dtypes import (
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/pandas/core/dtypes/dtypes.py", line 24, in <module>
#     from pandas._libs import (
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/pyarrow/__init__.py", line 65, in <module>
#     import pyarrow.lib as _lib
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# AttributeError: _ARRAY_API not found
# A module that was compiled using NumPy 1.x cannot be run in
# NumPy 2.2.3 as it may crash. To support both 1.x and 2.x
# versions of NumPy, modules must be compiled with NumPy 2.0.
# Some module may need to rebuild instead e.g. with 'pybind11>=2.12'.
#
# If you are a user of the module, the easiest solution will be to
# downgrade to 'numpy<2' or try to upgrade the affected module.
# We expect that some modules will need time to support NumPy 2.
#
# Traceback (most recent call last):  File "/Users/ibtissama/anaconda3/lib/python3.10/runpy.py", line 196, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "/Users/ibtissama/anaconda3/lib/python3.10/runpy.py", line 86, in _run_code
#     exec(code, run_globals)
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/ipykernel_launcher.py", line 17, in <module>
#     app.launch_new_instance()
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/traitlets/config/application.py", line 992, in launch_instance
#     app.start()
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/ipykernel/kernelapp.py", line 711, in start
#     self.io_loop.start()
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/tornado/platform/asyncio.py", line 199, in start
#     self.asyncio_loop.run_forever()
#   File "/Users/ibtissama/anaconda3/lib/python3.10/asyncio/base_events.py", line 603, in run_forever
#     self._run_once()
#   File "/Users/ibtissama/anaconda3/lib/python3.10/asyncio/base_events.py", line 1906, in _run_once
#     handle._run()
#   File "/Users/ibtissama/anaconda3/lib/python3.10/asyncio/events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/ipykernel/kernelbase.py", line 510, in dispatch_queue
#     await self.process_one()
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/ipykernel/kernelbase.py", line 499, in process_one
#     await dispatch(*args)
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/ipykernel/kernelbase.py", line 406, in dispatch_shell
#     await result
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/ipykernel/kernelbase.py", line 729, in execute_request
#     reply_content = await reply_content
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/ipykernel/ipkernel.py", line 411, in do_execute
#     res = shell.run_cell(
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/ipykernel/zmqshell.py", line 531, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 2961, in run_cell
#     result = self._run_cell(
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 3016, in _run_cell
#     result = runner(coro)
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/IPython/core/async_helpers.py", line 129, in _pseudo_sync_runner
#     coro.send(None)
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 3221, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 3400, in run_ast_nodes
#     if await self.run_code(code, result, async_=asy):
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 3460, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "/var/folders/dj/km2r8x2x49n1n14w2nxczv_40000gn/T/ipykernel_40087/310030941.py", line 2, in <module>
#     import pandas as pd
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/pandas/__init__.py", line 49, in <module>
#     from pandas.core.api import (
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/pandas/core/api.py", line 28, in <module>
#     from pandas.core.arrays import Categorical
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/pandas/core/arrays/__init__.py", line 1, in <module>
#     from pandas.core.arrays.arrow import ArrowExtensionArray
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/pandas/core/arrays/arrow/__init__.py", line 5, in <module>
#     from pandas.core.arrays.arrow.array import ArrowExtensionArray
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/pandas/core/arrays/arrow/array.py", line 50, in <module>
#     from pandas.core import (
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/pandas/core/ops/__init__.py", line 8, in <module>
#     from pandas.core.ops.array_ops import (
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/pandas/core/ops/array_ops.py", line 56, in <module>
#     from pandas.core.computation import expressions
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/pandas/core/computation/expressions.py", line 21, in <module>
#     from pandas.core.computation.check import NUMEXPR_INSTALLED
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/pandas/core/computation/check.py", line 5, in <module>
#     ne = import_optional_dependency("numexpr", errors="warn")
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/pandas/compat/_optional.py", line 135, in import_optional_dependency
#     module = importlib.import_module(name)
#   File "/Users/ibtissama/anaconda3/lib/python3.10/importlib/__init__.py", line 126, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/numexpr/__init__.py", line 24, in <module>
#     from numexpr.interpreter import MAX_THREADS, use_vml, __BLOCK_SIZE1__
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# AttributeError: _ARRAY_API not found
# A module that was compiled using NumPy 1.x cannot be run in
# NumPy 2.2.3 as it may crash. To support both 1.x and 2.x
# versions of NumPy, modules must be compiled with NumPy 2.0.
# Some module may need to rebuild instead e.g. with 'pybind11>=2.12'.
#
# If you are a user of the module, the easiest solution will be to
# downgrade to 'numpy<2' or try to upgrade the affected module.
# We expect that some modules will need time to support NumPy 2.
#
# Traceback (most recent call last):  File "/Users/ibtissama/anaconda3/lib/python3.10/runpy.py", line 196, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "/Users/ibtissama/anaconda3/lib/python3.10/runpy.py", line 86, in _run_code
#     exec(code, run_globals)
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/ipykernel_launcher.py", line 17, in <module>
#     app.launch_new_instance()
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/traitlets/config/application.py", line 992, in launch_instance
#     app.start()
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/ipykernel/kernelapp.py", line 711, in start
#     self.io_loop.start()
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/tornado/platform/asyncio.py", line 199, in start
#     self.asyncio_loop.run_forever()
#   File "/Users/ibtissama/anaconda3/lib/python3.10/asyncio/base_events.py", line 603, in run_forever
#     self._run_once()
#   File "/Users/ibtissama/anaconda3/lib/python3.10/asyncio/base_events.py", line 1906, in _run_once
#     handle._run()
#   File "/Users/ibtissama/anaconda3/lib/python3.10/asyncio/events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/ipykernel/kernelbase.py", line 510, in dispatch_queue
#     await self.process_one()
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/ipykernel/kernelbase.py", line 499, in process_one
#     await dispatch(*args)
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/ipykernel/kernelbase.py", line 406, in dispatch_shell
#     await result
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/ipykernel/kernelbase.py", line 729, in execute_request
#     reply_content = await reply_content
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/ipykernel/ipkernel.py", line 411, in do_execute
#     res = shell.run_cell(
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/ipykernel/zmqshell.py", line 531, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 2961, in run_cell
#     result = self._run_cell(
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 3016, in _run_cell
#     result = runner(coro)
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/IPython/core/async_helpers.py", line 129, in _pseudo_sync_runner
#     coro.send(None)
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 3221, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 3400, in run_ast_nodes
#     if await self.run_code(code, result, async_=asy):
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 3460, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "/var/folders/dj/km2r8x2x49n1n14w2nxczv_40000gn/T/ipykernel_40087/310030941.py", line 2, in <module>
#     import pandas as pd
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/pandas/__init__.py", line 49, in <module>
#     from pandas.core.api import (
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/pandas/core/api.py", line 28, in <module>
#     from pandas.core.arrays import Categorical
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/pandas/core/arrays/__init__.py", line 1, in <module>
#     from pandas.core.arrays.arrow import ArrowExtensionArray
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/pandas/core/arrays/arrow/__init__.py", line 5, in <module>
#     from pandas.core.arrays.arrow.array import ArrowExtensionArray
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/pandas/core/arrays/arrow/array.py", line 64, in <module>
#     from pandas.core.arrays.masked import BaseMaskedArray
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/pandas/core/arrays/masked.py", line 60, in <module>
#     from pandas.core import (
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/pandas/core/nanops.py", line 52, in <module>
#     bn = import_optional_dependency("bottleneck", errors="warn")
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/pandas/compat/_optional.py", line 135, in import_optional_dependency
#     module = importlib.import_module(name)
#   File "/Users/ibtissama/anaconda3/lib/python3.10/importlib/__init__.py", line 126, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/bottleneck/__init__.py", line 7, in <module>
#     from .move import (move_argmax, move_argmin, move_max, move_mean, move_median,
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# AttributeError: _ARRAY_API not found

# %% [markdown]
# Dans le cadre de l'évaluation des modèles de classification, plusieurs versions de la fonction de scoring ont été développées pour affiner l'analyse des performances :
#
# *Version 1 - score_classifier :*
#
# Utilise une validation croisée K-Fold simple / stratified.
# Calcule la matrice de confusion ainsi que les métriques pour les deux classes séparément (Classe 0 et Classe 1).
# Initialement, la version de base ne prenait en compte que le recall global, ce qui était insuffisant dans notre contexte.
# Désormais, cette fonction analyse séparément la classe majoritaire (1) et la classe minoritaire (0), ce qui est essentiel pour éviter les erreurs coûteuses.
#
# *Version 2 - score_classifier_with_tuning :*
#
# Ajoute une optimisation des hyperparamètres à l'aide de GridSearchCV.
# Permet d'identifier les meilleurs paramètres pour chaque modèle afin d'améliorer sa performance.
#
#
# *Version 3 - score_classifier_with_optuna :*
#
# Utilise Optuna, une approche avancée d'optimisation des hyperparamètres, qui est plus efficace et rapide que GridSearchCV.
# Recherche automatiquement les meilleurs hyperparamètres en fonction de la performance du modèle.
# Permet d'améliorer encore davantage la classification en évitant un exploration exhaustive du paramètre space.

# %% [markdown]
# 👉 *Pour plus de détails sur les fonctions de scoring, veuillez vous référer au rapport technique.*

# %% [markdown]
# Importation des fonctions de scoring

# %%
from scoring_kfold import score_classifier
from scoring_optim import score_classifier_with_tuning
from scoring_optuna import score_classifier_with_optuna

# %% [markdown]
# #### 2. Chargement et Préparation des Données

# %% [markdown]
# Nous importons les données prétraitées dans le fichier précédent pour les utiliser dans la phase de modélisation et d'évaluation.

# %%
# Chargement des données
df = pd.read_csv("NBA_transf.csv")
df = df.drop(columns=["Unnamed: 0"])  # Suppression de la colonne inutile

# Extraction des labels et des features
names = df['Name'].values.tolist()  # Noms des joueurs
labels = df['TARGET_5Yrs'].values  # Labels (Classe 0 = <5 ans, Classe 1 = ≥5 ans)
paramset = df.drop(['TARGET_5Yrs', 'Name'], axis=1).columns.values  # Noms des features
df_vals = df.drop(['TARGET_5Yrs', 'Name'], axis=1).values  # Valeurs des features

print(f"Taille du dataset: {df_vals.shape}")
# Out:
# Taille du dataset: (1328, 19)

# %% [markdown]
# Ce dataset contient l'ensemble des statistiques des joueurs, prétraitées dans l'étape précédente.

# %% [markdown]
# #### 3. Équilibrage des Classes avec SMOTE

# %% [markdown]
# Dans notre jeu de données, la classe 1 (joueurs ayant une carrière ≥5 ans) est sur-représentée par rapport à la classe 0 (joueurs ayant une carrière <5 ans).
#
# Un modèle entraîné sur ces données non équilibrées risque de privilégier la classe majoritaire et de sous-estimer les joueurs ayant une carrière courte.
#
# Nous avons testé deux stratégies d’équilibrage :
#
# Pondération des classes dans les modèles (via class_weight='balanced').
# Sur-échantillonnage de la classe minoritaire avec SMOTE (Synthetic Minority Over-sampling Technique).
#
# 📌 Après comparaison des performances des modèles avec les deux techniques, SMOTE a donné de meilleurs.
# SMOTE génère artificiellement des échantillons similaires à la classe minoritaire, ce qui permet au modèle d’avoir plus d’exemples pour apprendre à bien prédire les joueurs à carrière courte.

# %% [markdown]
# 👉 *Pour plus de détails sur l’analyse comparative des techniques d’équilibrage, voir la section dédiée dans le document technique.*

# %%
# Application de SMOTE pour équilibrer les classes
oversample = SMOTE()
over_X, over_y = oversample.fit_resample(df_vals, labels)

print(f"Taille du dataset après SMOTE: {over_X.shape}")
# Out:
# Taille du dataset après SMOTE: (1648, 19)

# %% [markdown]
# SMOTE permet d'obtenir une meilleure balance entre précision et recall pour la classe minoritaire, tout en évitant de simplement ajuster les poids dans les modèles.

# %% [markdown]
# #### 4. Choix des Modèles de Classification

# %% [markdown]
# Pour cette tâche de classification, nous avons sélectionné trois modèles adaptés aux problématiques d’apprentissage supervisé sur des données déséquilibrées :
#
# 1️⃣ Random Forest (RF) -> Modèle basé sur un ensemble d’arbres de décision.
#
# 2️⃣ Balanced Random Forest (BRF) -> Variante du Random Forest, où chaque arbre est entraîné sur un échantillon équilibré de la classe minoritaire et majoritaire.
#
# 3️⃣ XGBoost (XGB) -> Algorithme de boosting optimisé pour la classification binaire.
#
# 👉 *Pour plus de détails sur le choix des modèles, voir la section dédiée dans le document technique.*

# %% [markdown]
# #### 5. Évaluation des Modèles & Comparaison

# %% [markdown]
# Nous appliquons différentes stratégies d’évaluation sur chaque modèle pour comparer leurs performances et identifier le meilleur.
#
# Trois méthodes d’évaluation sont utilisées :
#
# 1️⃣ score_classifier → Validation croisée KFold simple / stratified.
#
# 2️⃣ score_classifier_with_tuning → Optimisation des hyperparamètres avec GridSearchCV.
#
# 3️⃣ score_classifier_with_optuna → Optimisation avancée avec Optuna.
#
# 💡 Objectif : Nous allons tester chaque modèle avec ces trois stratégies et analyser leur précision, recall et F1-score.

# %% [markdown]
# ##### 5.1 Random Forest (RF)

# %%
# Version 1 - kfold simple
rf = RandomForestClassifier(random_state=42)
score_classifier(over_X, rf, over_y,"kfold")
# Out:
# 📊 Confusion Matrix:
# [[634. 190.]
#  [256. 568.]]
#
# 🎯 Performance Metrics:
# 🔹 Precision: Class 1 (Long Career Players): 0.7511
# 🔹 Recall: Class 1 (Long Career Players): 0.6894
# 🔹 F1-score: Class 1 (Long Career Players): 0.7176
# 🔹 Precision: Class 0 (Short Career Players): 0.7135
# 🔹 Recall: Class 0 (Short Career Players): 0.7699
# 🔹 F1-score: Class 0 (Short Career Players): 0.7395
#
# 📌 Full Classification Report (Averaged Over 5 Folds):
#               precision    recall  f1-score   support
#
#          0.0       0.71      0.77      0.74       824
#          1.0       0.75      0.69      0.72       824
#
#     accuracy                           0.73      1648
#    macro avg       0.73      0.73      0.73      1648
# weighted avg       0.73      0.73      0.73      1648

# %% [markdown]
# Dans cette première version, le modèle a été testé avec des hyperparamètres par défaut, sans optimisation spécifique.
#
# On observe les résultats suivants :
#
# ✅ F1-score Classe 1 (Longue carrière) : 0.7176
#
# ✅ F1-score Classe 0 (Courte carrière) : 0.7395
#
# ✅ Accuracy globale : 0.73
#
# 🔍 Analyse :
#
# Le modèle montre une bonne capacité de généralisation, avec une précision et un rappel équilibrés entre les deux classes.
# Toutefois, il ne parvient pas encore à parfaitement différencier les joueurs ayant une longue carrière, avec un recall de 0.6894 pour la classe 1.
# Légère sous-estimation des joueurs ayant une longue carrière, ce qui signifie que certains joueurs prometteurs ne sont pas bien identifiés.

# %%
#Version 2 - Optimisation GridSearchCV
param_grid_brf = {
    "n_estimators": [100, 300, 500],
    "max_depth": [3, 5, 7, None],
    "min_samples_split": [2, 5, 10],
    "min_samples_leaf": [1, 2, 4],
    "max_features": ['sqrt', 'log2', None],
}

rf = RandomForestClassifier(random_state=42)

score_classifier_with_tuning(over_X, rf, over_y, param_grid_brf,5,"kfold")
# Out:
# Fitting 5 folds for each of 324 candidates, totalling 1620 fits
# A module that was compiled using NumPy 1.x cannot be run in
# NumPy 2.1.3 as it may crash. To support both 1.x and 2.x
# versions of NumPy, modules must be compiled with NumPy 2.0.
# Some module may need to rebuild instead e.g. with 'pybind11>=2.12'.
#
# If you are a user of the module, the easiest solution will be to
# downgrade to 'numpy<2' or try to upgrade the affected module.
# We expect that some modules will need time to support NumPy 2.
#
# Traceback (most recent call last):  File "/Users/ibtissama/anaconda3/lib/python3.10/runpy.py", line 196, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "/Users/ibtissama/anaconda3/lib/python3.10/runpy.py", line 86, in _run_code
#     exec(code, run_globals)
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/joblib/externals/loky/backend/popen_loky_posix.py", line 180, in <module>
#     exitcode = process_obj._bootstrap()
#   File "/Users/ibtissama/anaconda3/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/Users/ibtissama/anaconda3/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/joblib/externals/loky/process_executor.py", line 426, in _process_worker
#     call_item = call_queue.get(block=True, timeout=timeout)
#   File "/Users/ibtissama/anaconda3/lib/python3.10/multiprocessing/queues.py", line 122, in get
#     return _ForkingPickler.loads(res)
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/sklearn/__init__.py", line 73, in <module>
#     from .base import clone  # noqa: E402
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/sklearn/base.py", line 19, in <module>
#     from .utils._estimator_html_repr import _HTMLDocumentationLinkMixin, estimator_html_repr
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/sklearn/utils/__init__.py", line 15, in <module>
#     from ._chunking import gen_batches, gen_even_slices
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/sklearn/utils/_chunking.py", line 11, in <module>
#     from ._param_validation import Interval, validate_params
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/sklearn/utils/_param_validation.py", line 17, in <module>
#     from .validation import _is_arraylike_not_scalar
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/sklearn/utils/validation.py", line 21, in <module>
#     from ..utils._array_api import _asarray_with_order, _is_numpy_namespace, get_namespace
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/sklearn/utils/_array_api.py", line 17, in <module>
#     from .fixes import parse_version
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/sklearn/utils/fixes.py", line 20, in <module>
#     import pandas as pd
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/pandas/__init__.py", line 26, in <module>
#     from pandas.compat import (
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/pandas/compat/__init__.py", line 27, in <module>
#     from pandas.compat.pyarrow import (
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/pandas/compat/pyarrow.py", line 8, in <module>
#     import pyarrow as pa
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/pyarrow/__init__.py", line 65, in <module>
#     import pyarrow.lib as _lib
#
# A module that was compiled using NumPy 1.x cannot be run in
# NumPy 2.1.3 as it may crash. To support both 1.x and 2.x
# versions of NumPy, modules must be compiled with NumPy 2.0.
# Some module may need to rebuild instead e.g. with 'pybind11>=2.12'.
#
# If you are a user of the module, the easiest solution will be to
# downgrade to 'numpy<2' or try to upgrade the affected module.
# We expect that some modules will need time to support NumPy 2.
#
# Traceback (most recent call last):  File "/Users/ibtissama/anaconda3/lib/python3.10/runpy.py", line 196, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "/Users/ibtissama/anaconda3/lib/python3.10/runpy.py", line 86, in _run_code
#     exec(code, run_globals)
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/joblib/externals/loky/backend/popen_loky_posix.py", line 180, in <module>
#     exitcode = process_obj._bootstrap()
#   File "/Users/ibtissama/anaconda3/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/Users/ibtissama/anaconda3/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/joblib/externals/loky/process_executor.py", line 426, in _process_worker
#     call_item = call_queue.get(block=True, timeout=timeout)
#   File "/Users/ibtissama/anaconda3/lib/python3.10/multiprocessing/queues.py", line 122, in get
#     return _ForkingPickler.loads(res)
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/sklearn/__init__.py", line 73, in <module>
#     from .base import clone  # noqa: E402
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/sklearn/base.py", line 19, in <module>
#     from .utils._estimator_html_repr import _HTMLDocumentationLinkMixin, estimator_html_repr
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/sklearn/utils/__init__.py", line 15, in <module>
#     from ._chunking import gen_batches, gen_even_slices
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/sklearn/utils/_chunking.py", line 11, in <module>
#     from ._param_validation import Interval, validate_params
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/sklearn/utils/_param_validation.py", line 17, in <module>
#     from .validation import _is_arraylike_not_scalar
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/sklearn/utils/validation.py", line 21, in <module>
#     from ..utils._array_api import _asarray_with_order, _is_numpy_namespace, get_namespace
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/sklearn/utils/_array_api.py", line 17, in <module>
#     from .fixes import parse_version
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/sklearn/utils/fixes.py", line 20, in <module>
#     import pandas as pd
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/pandas/__init__.py", line 26, in <module>
#     from pandas.compat import (
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/pandas/compat/__init__.py", line 27, in <module>
#     from pandas.compat.pyarrow import (
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/pandas/compat/pyarrow.py", line 8, in <module>
#     import pyarrow as pa
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/pyarrow/__init__.py", line 65, in <module>
#     import pyarrow.lib as _lib
#
# A module that was compiled using NumPy 1.x cannot be run in
# NumPy 2.1.3 as it may crash. To support both 1.x and 2.x
# versions of NumPy, modules must be compiled with NumPy 2.0.
# Some module may need to rebuild instead e.g. with 'pybind11>=2.12'.
#
# If you are a user of the module, the easiest solution will be to
# downgrade to 'numpy<2' or try to upgrade the affected module.
# We expect that some modules will need time to support NumPy 2.
#
# Traceback (most recent call last):  File "/Users/ibtissama/anaconda3/lib/python3.10/runpy.py", line 196, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "/Users/ibtissama/anaconda3/lib/python3.10/runpy.py", line 86, in _run_code
#     exec(code, run_globals)
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/joblib/externals/loky/backend/popen_loky_posix.py", line 180, in <module>
#     exitcode = process_obj._bootstrap()
#   File "/Users/ibtissama/anaconda3/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/Users/ibtissama/anaconda3/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/joblib/externals/loky/process_executor.py", line 426, in _process_worker
#     call_item = call_queue.get(block=True, timeout=timeout)
#   File "/Users/ibtissama/anaconda3/lib/python3.10/multiprocessing/queues.py", line 122, in get
#     return _ForkingPickler.loads(res)
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/sklearn/__init__.py", line 73, in <module>
#     from .base import clone  # noqa: E402
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/sklearn/base.py", line 19, in <module>
#     from .utils._estimator_html_repr import _HTMLDocumentationLinkMixin, estimator_html_repr
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/sklearn/utils/__init__.py", line 15, in <module>
#     from ._chunking import gen_batches, gen_even_slices
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/sklearn/utils/_chunking.py", line 11, in <module>
#     from ._param_validation import Interval, validate_params
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/sklearn/utils/_param_validation.py", line 17, in <module>
#     from .validation import _is_arraylike_not_scalar
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/sklearn/utils/validation.py", line 21, in <module>
#     from ..utils._array_api import _asarray_with_order, _is_numpy_namespace, get_namespace
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/sklearn/utils/_array_api.py", line 17, in <module>
#     from .fixes import parse_version
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/sklearn/utils/fixes.py", line 20, in <module>
#     import pandas as pd
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/pandas/__init__.py", line 26, in <module>
#     from pandas.compat import (
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/pandas/compat/__init__.py", line 27, in <module>
#     from pandas.compat.pyarrow import (
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/pandas/compat/pyarrow.py", line 8, in <module>
#     import pyarrow as pa
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/pyarrow/__init__.py", line 65, in <module>
#     import pyarrow.lib as _lib
#
# A module that was compiled using NumPy 1.x cannot be run in
# NumPy 2.1.3 as it may crash. To support both 1.x and 2.x
# versions of NumPy, modules must be compiled with NumPy 2.0.
# Some module may need to rebuild instead e.g. with 'pybind11>=2.12'.
#
# If you are a user of the module, the easiest solution will be to
# downgrade to 'numpy<2' or try to upgrade the affected module.
# We expect that some modules will need time to support NumPy 2.
#
# Traceback (most recent call last):  File "/Users/ibtissama/anaconda3/lib/python3.10/runpy.py", line 196, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "/Users/ibtissama/anaconda3/lib/python3.10/runpy.py", line 86, in _run_code
#     exec(code, run_globals)
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/joblib/externals/loky/backend/popen_loky_posix.py", line 180, in <module>
#     exitcode = process_obj._bootstrap()
#   File "/Users/ibtissama/anaconda3/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/Users/ibtissama/anaconda3/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/joblib/externals/loky/process_executor.py", line 426, in _process_worker
#     call_item = call_queue.get(block=True, timeout=timeout)
#   File "/Users/ibtissama/anaconda3/lib/python3.10/multiprocessing/queues.py", line 122, in get
#     return _ForkingPickler.loads(res)
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/sklearn/__init__.py", line 73, in <module>
#     from .base import clone  # noqa: E402
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/sklearn/base.py", line 19, in <module>
#     from .utils._estimator_html_repr import _HTMLDocumentationLinkMixin, estimator_html_repr
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/sklearn/utils/__init__.py", line 15, in <module>
#     from ._chunking import gen_batches, gen_even_slices
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/sklearn/utils/_chunking.py", line 11, in <module>
#     from ._param_validation import Interval, validate_params
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/sklearn/utils/_param_validation.py", line 17, in <module>
#     from .validation import _is_arraylike_not_scalar
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/sklearn/utils/validation.py", line 21, in <module>
#     from ..utils._array_api import _asarray_with_order, _is_numpy_namespace, get_namespace
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/sklearn/utils/_array_api.py", line 17, in <module>
#     from .fixes import parse_version
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/sklearn/utils/fixes.py", line 20, in <module>
#     import pandas as pd
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/pandas/__init__.py", line 26, in <module>
#     from pandas.compat import (
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/pandas/compat/__init__.py", line 27, in <module>
#     from pandas.compat.pyarrow import (
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/pandas/compat/pyarrow.py", line 8, in <module>
#     import pyarrow as pa
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/pyarrow/__init__.py", line 65, in <module>
#     import pyarrow.lib as _lib
# AttributeError: _ARRAY_API not found
#
# A module that was compiled using NumPy 1.x cannot be run in
# NumPy 2.1.3 as it may crash. To support both 1.x and 2.x
# versions of NumPy, modules must be compiled with NumPy 2.0.
# Some module may need to rebuild instead e.g. with 'pybind11>=2.12'.
#
# If you are a user of the module, the easiest solution will be to
# downgrade to 'numpy<2' or try to upgrade the affected module.
# We expect that some modules will need time to support NumPy 2.
#
# Traceback (most recent call last):  File "/Users/ibtissama/anaconda3/lib/python3.10/runpy.py", line 196, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "/Users/ibtissama/anaconda3/lib/python3.10/runpy.py", line 86, in _run_code
#     exec(code, run_globals)
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/joblib/externals/loky/backend/popen_loky_posix.py", line 180, in <module>
#     exitcode = process_obj._bootstrap()
#   File "/Users/ibtissama/anaconda3/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/Users/ibtissama/anaconda3/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/joblib/externals/loky/process_executor.py", line 426, in _process_worker
#     call_item = call_queue.get(block=True, timeout=timeout)
#   File "/Users/ibtissama/anaconda3/lib/python3.10/multiprocessing/queues.py", line 122, in get
#     return _ForkingPickler.loads(res)
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/sklearn/__init__.py", line 73, in <module>
#     from .base import clone  # noqa: E402
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/sklearn/base.py", line 19, in <module>
#     from .utils._estimator_html_repr import _HTMLDocumentationLinkMixin, estimator_html_repr
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/sklearn/utils/__init__.py", line 15, in <module>
#     from ._chunking import gen_batches, gen_even_slices
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/sklearn/utils/_chunking.py", line 11, in <module>
#     from ._param_validation import Interval, validate_params
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/sklearn/utils/_param_validation.py", line 17, in <module>
#     from .validation import _is_arraylike_not_scalar
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/sklearn/utils/validation.py", line 21, in <module>
#     from ..utils._array_api import _asarray_with_order, _is_numpy_namespace, get_namespace
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/sklearn/utils/_array_api.py", line 17, in <module>
#     from .fixes import parse_version
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/sklearn/utils/fixes.py", line 20, in <module>
#     import pandas as pd
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/pandas/__init__.py", line 26, in <module>
#     from pandas.compat import (
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/pandas/compat/__init__.py", line 27, in <module>
#     from pandas.compat.pyarrow import (
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/pandas/compat/pyarrow.py", line 8, in <module>
#     import pyarrow as pa
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/pyarrow/__init__.py", line 65, in <module>
#     import pyarrow.lib as _lib
#
# A module that was compiled using NumPy 1.x cannot be run in
# NumPy 2.1.3 as it may crash. To support both 1.x and 2.x
# versions of NumPy, modules must be compiled with NumPy 2.0.
# Some module may need to rebuild instead e.g. with 'pybind11>=2.12'.
#
# If you are a user of the module, the easiest solution will be to
# downgrade to 'numpy<2' or try to upgrade the affected module.
# We expect that some modules will need time to support NumPy 2.
#
# Traceback (most recent call last):  File "/Users/ibtissama/anaconda3/lib/python3.10/runpy.py", line 196, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "/Users/ibtissama/anaconda3/lib/python3.10/runpy.py", line 86, in _run_code
#     exec(code, run_globals)
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/joblib/externals/loky/backend/popen_loky_posix.py", line 180, in <module>
#     exitcode = process_obj._bootstrap()
#   File "/Users/ibtissama/anaconda3/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/Users/ibtissama/anaconda3/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/joblib/externals/loky/process_executor.py", line 426, in _process_worker
#     call_item = call_queue.get(block=True, timeout=timeout)
#   File "/Users/ibtissama/anaconda3/lib/python3.10/multiprocessing/queues.py", line 122, in get
#     return _ForkingPickler.loads(res)
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/sklearn/__init__.py", line 73, in <module>
#     from .base import clone  # noqa: E402
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/sklearn/base.py", line 19, in <module>
#     from .utils._estimator_html_repr import _HTMLDocumentationLinkMixin, estimator_html_repr
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/sklearn/utils/__init__.py", line 15, in <module>
#     from ._chunking import gen_batches, gen_even_slices
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/sklearn/utils/_chunking.py", line 11, in <module>
#     from ._param_validation import Interval, validate_params
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/sklearn/utils/_param_validation.py", line 17, in <module>
#     from .validation import _is_arraylike_not_scalar
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/sklearn/utils/validation.py", line 21, in <module>
#     from ..utils._array_api import _asarray_with_order, _is_numpy_namespace, get_namespace
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/sklearn/utils/_array_api.py", line 17, in <module>
#     from .fixes import parse_version
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/sklearn/utils/fixes.py", line 20, in <module>
#     import pandas as pd
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/pandas/__init__.py", line 26, in <module>
#     from pandas.compat import (
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/pandas/compat/__init__.py", line 27, in <module>
#     from pandas.compat.pyarrow import (
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/pandas/compat/pyarrow.py", line 8, in <module>
#     import pyarrow as pa
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/pyarrow/__init__.py", line 65, in <module>
#     import pyarrow.lib as _lib
# AttributeError: _ARRAY_API not found
#
# A module that was compiled using NumPy 1.x cannot be run in
# NumPy 2.1.3 as it may crash. To support both 1.x and 2.x
# versions of NumPy, modules must be compiled with NumPy 2.0.
# Some module may need to rebuild instead e.g. with 'pybind11>=2.12'.
#
# If you are a user of the module, the easiest solution will be to
# downgrade to 'numpy<2' or try to upgrade the affected module.
# We expect that some modules will need time to support NumPy 2.
#
# Traceback (most recent call last):  File "/Users/ibtissama/anaconda3/lib/python3.10/runpy.py", line 196, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "/Users/ibtissama/anaconda3/lib/python3.10/runpy.py", line 86, in _run_code
#     exec(code, run_globals)
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/joblib/externals/loky/backend/popen_loky_posix.py", line 180, in <module>
#     exitcode = process_obj._bootstrap()
#   File "/Users/ibtissama/anaconda3/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/Users/ibtissama/anaconda3/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/joblib/externals/loky/process_executor.py", line 426, in _process_worker
#     call_item = call_queue.get(block=True, timeout=timeout)
#   File "/Users/ibtissama/anaconda3/lib/python3.10/multiprocessing/queues.py", line 122, in get
#     return _ForkingPickler.loads(res)
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/sklearn/__init__.py", line 73, in <module>
#     from .base import clone  # noqa: E402
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/sklearn/base.py", line 19, in <module>
#     from .utils._estimator_html_repr import _HTMLDocumentationLinkMixin, estimator_html_repr
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/sklearn/utils/__init__.py", line 15, in <module>
#     from ._chunking import gen_batches, gen_even_slices
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/sklearn/utils/_chunking.py", line 11, in <module>
#     from ._param_validation import Interval, validate_params
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/sklearn/utils/_param_validation.py", line 17, in <module>
#     from .validation import _is_arraylike_not_scalar
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/sklearn/utils/validation.py", line 21, in <module>
#     from ..utils._array_api import _asarray_with_order, _is_numpy_namespace, get_namespace
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/sklearn/utils/_array_api.py", line 17, in <module>
#     from .fixes import parse_version
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/sklearn/utils/fixes.py", line 20, in <module>
#     import pandas as pd
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/pandas/__init__.py", line 26, in <module>
#     from pandas.compat import (
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/pandas/compat/__init__.py", line 27, in <module>
#     from pandas.compat.pyarrow import (
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/pandas/compat/pyarrow.py", line 8, in <module>
#     import pyarrow as pa
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/pyarrow/__init__.py", line 65, in <module>
#     import pyarrow.lib as _lib
# AttributeErrorAttributeError: _ARRAY_API not found: _ARRAY_API not found
# AttributeError: _ARRAY_API not found
# AttributeError: _ARRAY_API not found
# AttributeError: _ARRAY_API not found
#
# A module that was compiled using NumPy 1.x cannot be run in
# NumPy 2.1.3 as it may crash. To support both 1.x and 2.x
# versions of NumPy, modules must be compiled with NumPy 2.0.
# Some module may need to rebuild instead e.g. with 'pybind11>=2.12'.
#
# If you are a user of the module, the easiest solution will be to
# downgrade to 'numpy<2' or try to upgrade the affected module.
# We expect that some modules will need time to support NumPy 2.
#
# Traceback (most recent call last):  File "/Users/ibtissama/anaconda3/lib/python3.10/runpy.py", line 196, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "/Users/ibtissama/anaconda3/lib/python3.10/runpy.py", line 86, in _run_code
#     exec(code, run_globals)
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/joblib/externals/loky/backend/popen_loky_posix.py", line 180, in <module>
#     exitcode = process_obj._bootstrap()
#   File "/Users/ibtissama/anaconda3/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/Users/ibtissama/anaconda3/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/joblib/externals/loky/process_executor.py", line 426, in _process_worker
#     call_item = call_queue.get(block=True, timeout=timeout)
#   File "/Users/ibtissama/anaconda3/lib/python3.10/multiprocessing/queues.py", line 122, in get
#     return _ForkingPickler.loads(res)
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/sklearn/__init__.py", line 73, in <module>
#     from .base import clone  # noqa: E402
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/sklearn/base.py", line 19, in <module>
#     from .utils._estimator_html_repr import _HTMLDocumentationLinkMixin, estimator_html_repr
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/sklearn/utils/__init__.py", line 15, in <module>
#     from ._chunking import gen_batches, gen_even_slices
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/sklearn/utils/_chunking.py", line 11, in <module>
#     from ._param_validation import Interval, validate_params
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/sklearn/utils/_param_validation.py", line 17, in <module>
#     from .validation import _is_arraylike_not_scalar
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/sklearn/utils/validation.py", line 21, in <module>
#     from ..utils._array_api import _asarray_with_order, _is_numpy_namespace, get_namespace
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/sklearn/utils/_array_api.py", line 17, in <module>
#     from .fixes import parse_version
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/sklearn/utils/fixes.py", line 20, in <module>
#     import pandas as pd
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/pandas/__init__.py", line 26, in <module>
#     from pandas.compat import (
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/pandas/compat/__init__.py", line 27, in <module>
#     from pandas.compat.pyarrow import (
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/pandas/compat/pyarrow.py", line 8, in <module>
#     import pyarrow as pa
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/pyarrow/__init__.py", line 65, in <module>
#     import pyarrow.lib as _lib
#
# AttributeError: _ARRAY_API not found
#
# A module that was compiled using NumPy 1.x cannot be run in
# NumPy 2.1.3 as it may crash. To support both 1.x and 2.x
# versions of NumPy, modules must be compiled with NumPy 2.0.
# Some module may need to rebuild instead e.g. with 'pybind11>=2.12'.
#
# If you are a user of the module, the easiest solution will be to
# downgrade to 'numpy<2' or try to upgrade the affected module.
# We expect that some modules will need time to support NumPy 2.
#
# Traceback (most recent call last):  File "/Users/ibtissama/anaconda3/lib/python3.10/runpy.py", line 196, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "/Users/ibtissama/anaconda3/lib/python3.10/runpy.py", line 86, in _run_code
#     exec(code, run_globals)
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/joblib/externals/loky/backend/popen_loky_posix.py", line 180, in <module>
#     exitcode = process_obj._bootstrap()
#   File "/Users/ibtissama/anaconda3/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/Users/ibtissama/anaconda3/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/joblib/externals/loky/process_executor.py", line 426, in _process_worker
#     call_item = call_queue.get(block=True, timeout=timeout)
#   File "/Users/ibtissama/anaconda3/lib/python3.10/multiprocessing/queues.py", line 122, in get
#     return _ForkingPickler.loads(res)
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/sklearn/__init__.py", line 73, in <module>
#     from .base import clone  # noqa: E402
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/sklearn/base.py", line 19, in <module>
#     from .utils._estimator_html_repr import _HTMLDocumentationLinkMixin, estimator_html_repr
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/sklearn/utils/__init__.py", line 15, in <module>
#     from ._chunking import gen_batches, gen_even_slices
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/sklearn/utils/_chunking.py", line 11, in <module>
#     from ._param_validation import Interval, validate_params
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/sklearn/utils/_param_validation.py", line 17, in <module>
#     from .validation import _is_arraylike_not_scalar
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/sklearn/utils/validation.py", line 21, in <module>
#     from ..utils._array_api import _asarray_with_order, _is_numpy_namespace, get_namespace
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/sklearn/utils/_array_api.py", line 17, in <module>
#     from .fixes import parse_version
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/sklearn/utils/fixes.py", line 20, in <module>
#     import pandas as pd
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/pandas/__init__.py", line 49, in <module>
#     from pandas.core.api import (
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/pandas/core/api.py", line 9, in <module>
#     from pandas.core.dtypes.dtypes import (
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/pandas/core/dtypes/dtypes.py", line 24, in <module>
#     from pandas._libs import (
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/pyarrow/__init__.py", line 65, in <module>
#     import pyarrow.lib as _lib
# AttributeError: _ARRAY_API not found
#
# A module that was compiled using NumPy 1.x cannot be run in
# NumPy 2.1.3 as it may crash. To support both 1.x and 2.x
# versions of NumPy, modules must be compiled with NumPy 2.0.
# Some module may need to rebuild instead e.g. with 'pybind11>=2.12'.
#
# If you are a user of the module, the easiest solution will be to
# downgrade to 'numpy<2' or try to upgrade the affected module.
# We expect that some modules will need time to support NumPy 2.
#
# Traceback (most recent call last):  File "/Users/ibtissama/anaconda3/lib/python3.10/runpy.py", line 196, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "/Users/ibtissama/anaconda3/lib/python3.10/runpy.py", line 86, in _run_code
#     exec(code, run_globals)
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/joblib/externals/loky/backend/popen_loky_posix.py", line 180, in <module>
#     exitcode = process_obj._bootstrap()
#   File "/Users/ibtissama/anaconda3/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/Users/ibtissama/anaconda3/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/joblib/externals/loky/process_executor.py", line 426, in _process_worker
#     call_item = call_queue.get(block=True, timeout=timeout)
#   File "/Users/ibtissama/anaconda3/lib/python3.10/multiprocessing/queues.py", line 122, in get
#     return _ForkingPickler.loads(res)
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/sklearn/__init__.py", line 73, in <module>
#     from .base import clone  # noqa: E402
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/sklearn/base.py", line 19, in <module>
#     from .utils._estimator_html_repr import _HTMLDocumentationLinkMixin, estimator_html_repr
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/sklearn/utils/__init__.py", line 15, in <module>
#     from ._chunking import gen_batches, gen_even_slices
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/sklearn/utils/_chunking.py", line 11, in <module>
#     from ._param_validation import Interval, validate_params
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/sklearn/utils/_param_validation.py", line 17, in <module>
#     from .validation import _is_arraylike_not_scalar
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/sklearn/utils/validation.py", line 21, in <module>
#     from ..utils._array_api import _asarray_with_order, _is_numpy_namespace, get_namespace
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/sklearn/utils/_array_api.py", line 17, in <module>
#     from .fixes import parse_version
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/sklearn/utils/fixes.py", line 20, in <module>
#     import pandas as pd
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/pandas/__init__.py", line 49, in <module>
#     from pandas.core.api import (
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/pandas/core/api.py", line 9, in <module>
#     from pandas.core.dtypes.dtypes import (
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/pandas/core/dtypes/dtypes.py", line 24, in <module>
#     from pandas._libs import (
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/pyarrow/__init__.py", line 65, in <module>
#     import pyarrow.lib as _lib
# AttributeError: _ARRAY_API not found
#
# A module that was compiled using NumPy 1.x cannot be run in
# NumPy 2.1.3 as it may crash. To support both 1.x and 2.x
# versions of NumPy, modules must be compiled with NumPy 2.0.
# Some module may need to rebuild instead e.g. with 'pybind11>=2.12'.
#
# If you are a user of the module, the easiest solution will be to
# downgrade to 'numpy<2' or try to upgrade the affected module.
# We expect that some modules will need time to support NumPy 2.
#
# Traceback (most recent call last):  File "/Users/ibtissama/anaconda3/lib/python3.10/runpy.py", line 196, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "/Users/ibtissama/anaconda3/lib/python3.10/runpy.py", line 86, in _run_code
#     exec(code, run_globals)
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/joblib/externals/loky/backend/popen_loky_posix.py", line 180, in <module>
#     exitcode = process_obj._bootstrap()
#   File "/Users/ibtissama/anaconda3/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/Users/ibtissama/anaconda3/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/joblib/externals/loky/process_executor.py", line 426, in _process_worker
#     call_item = call_queue.get(block=True, timeout=timeout)
#   File "/Users/ibtissama/anaconda3/lib/python3.10/multiprocessing/queues.py", line 122, in get
#     return _ForkingPickler.loads(res)
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/sklearn/__init__.py", line 73, in <module>
#     from .base import clone  # noqa: E402
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/sklearn/base.py", line 19, in <module>
#     from .utils._estimator_html_repr import _HTMLDocumentationLinkMixin, estimator_html_repr
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/sklearn/utils/__init__.py", line 15, in <module>
#     from ._chunking import gen_batches, gen_even_slices
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/sklearn/utils/_chunking.py", line 11, in <module>
#     from ._param_validation import Interval, validate_params
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/sklearn/utils/_param_validation.py", line 17, in <module>
#     from .validation import _is_arraylike_not_scalar
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/sklearn/utils/validation.py", line 21, in <module>
#     from ..utils._array_api import _asarray_with_order, _is_numpy_namespace, get_namespace
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/sklearn/utils/_array_api.py", line 17, in <module>
#     from .fixes import parse_version
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/sklearn/utils/fixes.py", line 20, in <module>
#     import pandas as pd
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/pandas/__init__.py", line 49, in <module>
#     from pandas.core.api import (
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/pandas/core/api.py", line 9, in <module>
#     from pandas.core.dtypes.dtypes import (
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/pandas/core/dtypes/dtypes.py", line 24, in <module>
#     from pandas._libs import (
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/pyarrow/__init__.py", line 65, in <module>
#     import pyarrow.lib as _lib
# AttributeError: _ARRAY_API not found
#
# A module that was compiled using NumPy 1.x cannot be run in
# NumPy 2.1.3 as it may crash. To support both 1.x and 2.x
# versions of NumPy, modules must be compiled with NumPy 2.0.
# Some module may need to rebuild instead e.g. with 'pybind11>=2.12'.
#
# If you are a user of the module, the easiest solution will be to
# downgrade to 'numpy<2' or try to upgrade the affected module.
# We expect that some modules will need time to support NumPy 2.
#
# Traceback (most recent call last):  File "/Users/ibtissama/anaconda3/lib/python3.10/runpy.py", line 196, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "/Users/ibtissama/anaconda3/lib/python3.10/runpy.py", line 86, in _run_code
#     exec(code, run_globals)
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/joblib/externals/loky/backend/popen_loky_posix.py", line 180, in <module>
#     exitcode = process_obj._bootstrap()
#   File "/Users/ibtissama/anaconda3/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/Users/ibtissama/anaconda3/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/joblib/externals/loky/process_executor.py", line 426, in _process_worker
#     call_item = call_queue.get(block=True, timeout=timeout)
#   File "/Users/ibtissama/anaconda3/lib/python3.10/multiprocessing/queues.py", line 122, in get
#     return _ForkingPickler.loads(res)
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/sklearn/__init__.py", line 73, in <module>
#     from .base import clone  # noqa: E402
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/sklearn/base.py", line 19, in <module>
#     from .utils._estimator_html_repr import _HTMLDocumentationLinkMixin, estimator_html_repr
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/sklearn/utils/__init__.py", line 15, in <module>
#     from ._chunking import gen_batches, gen_even_slices
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/sklearn/utils/_chunking.py", line 11, in <module>
#     from ._param_validation import Interval, validate_params
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/sklearn/utils/_param_validation.py", line 17, in <module>
#     from .validation import _is_arraylike_not_scalar
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/sklearn/utils/validation.py", line 21, in <module>
#     from ..utils._array_api import _asarray_with_order, _is_numpy_namespace, get_namespace
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/sklearn/utils/_array_api.py", line 17, in <module>
#     from .fixes import parse_version
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/sklearn/utils/fixes.py", line 20, in <module>
#     import pandas as pd
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/pandas/__init__.py", line 49, in <module>
#     from pandas.core.api import (
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/pandas/core/api.py", line 9, in <module>
#     from pandas.core.dtypes.dtypes import (
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/pandas/core/dtypes/dtypes.py", line 24, in <module>
#     from pandas._libs import (
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/pyarrow/__init__.py", line 65, in <module>
#     import pyarrow.lib as _lib
# AttributeError: _ARRAY_API not found
#
# A module that was compiled using NumPy 1.x cannot be run in
# NumPy 2.1.3 as it may crash. To support both 1.x and 2.x
# versions of NumPy, modules must be compiled with NumPy 2.0.
# Some module may need to rebuild instead e.g. with 'pybind11>=2.12'.
#
# If you are a user of the module, the easiest solution will be to
# downgrade to 'numpy<2' or try to upgrade the affected module.
# We expect that some modules will need time to support NumPy 2.
#
# Traceback (most recent call last):  File "/Users/ibtissama/anaconda3/lib/python3.10/runpy.py", line 196, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "/Users/ibtissama/anaconda3/lib/python3.10/runpy.py", line 86, in _run_code
#     exec(code, run_globals)
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/joblib/externals/loky/backend/popen_loky_posix.py", line 180, in <module>
#     exitcode = process_obj._bootstrap()
#   File "/Users/ibtissama/anaconda3/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/Users/ibtissama/anaconda3/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/joblib/externals/loky/process_executor.py", line 426, in _process_worker
#     call_item = call_queue.get(block=True, timeout=timeout)
#   File "/Users/ibtissama/anaconda3/lib/python3.10/multiprocessing/queues.py", line 122, in get
#     return _ForkingPickler.loads(res)
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/sklearn/__init__.py", line 73, in <module>
#     from .base import clone  # noqa: E402
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/sklearn/base.py", line 19, in <module>
#     from .utils._estimator_html_repr import _HTMLDocumentationLinkMixin, estimator_html_repr
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/sklearn/utils/__init__.py", line 15, in <module>
#     from ._chunking import gen_batches, gen_even_slices
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/sklearn/utils/_chunking.py", line 11, in <module>
#     from ._param_validation import Interval, validate_params
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/sklearn/utils/_param_validation.py", line 17, in <module>
#     from .validation import _is_arraylike_not_scalar
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/sklearn/utils/validation.py", line 21, in <module>
#     from ..utils._array_api import _asarray_with_order, _is_numpy_namespace, get_namespace
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/sklearn/utils/_array_api.py", line 17, in <module>
#     from .fixes import parse_version
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/sklearn/utils/fixes.py", line 20, in <module>
#     import pandas as pd
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/pandas/__init__.py", line 49, in <module>
#     from pandas.core.api import (
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/pandas/core/api.py", line 9, in <module>
#     from pandas.core.dtypes.dtypes import (
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/pandas/core/dtypes/dtypes.py", line 24, in <module>
#     from pandas._libs import (
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/pyarrow/__init__.py", line 65, in <module>
#     import pyarrow.lib as _lib
# AttributeError: _ARRAY_API not found
#
# A module that was compiled using NumPy 1.x cannot be run in
# NumPy 2.1.3 as it may crash. To support both 1.x and 2.x
# versions of NumPy, modules must be compiled with NumPy 2.0.
# Some module may need to rebuild instead e.g. with 'pybind11>=2.12'.
#
# If you are a user of the module, the easiest solution will be to
# downgrade to 'numpy<2' or try to upgrade the affected module.
# We expect that some modules will need time to support NumPy 2.
#
# Traceback (most recent call last):  File "/Users/ibtissama/anaconda3/lib/python3.10/runpy.py", line 196, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "/Users/ibtissama/anaconda3/lib/python3.10/runpy.py", line 86, in _run_code
#     exec(code, run_globals)
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/joblib/externals/loky/backend/popen_loky_posix.py", line 180, in <module>
#     exitcode = process_obj._bootstrap()
#   File "/Users/ibtissama/anaconda3/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/Users/ibtissama/anaconda3/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/joblib/externals/loky/process_executor.py", line 426, in _process_worker
#     call_item = call_queue.get(block=True, timeout=timeout)
#   File "/Users/ibtissama/anaconda3/lib/python3.10/multiprocessing/queues.py", line 122, in get
#     return _ForkingPickler.loads(res)
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/sklearn/__init__.py", line 73, in <module>
#     from .base import clone  # noqa: E402
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/sklearn/base.py", line 19, in <module>
#     from .utils._estimator_html_repr import _HTMLDocumentationLinkMixin, estimator_html_repr
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/sklearn/utils/__init__.py", line 15, in <module>
#     from ._chunking import gen_batches, gen_even_slices
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/sklearn/utils/_chunking.py", line 11, in <module>
#     from ._param_validation import Interval, validate_params
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/sklearn/utils/_param_validation.py", line 17, in <module>
#     from .validation import _is_arraylike_not_scalar
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/sklearn/utils/validation.py", line 21, in <module>
#     from ..utils._array_api import _asarray_with_order, _is_numpy_namespace, get_namespace
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/sklearn/utils/_array_api.py", line 17, in <module>
#     from .fixes import parse_version
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/sklearn/utils/fixes.py", line 20, in <module>
#     import pandas as pd
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/pandas/__init__.py", line 49, in <module>
#     from pandas.core.api import (
# ...
#     from pandas.core.arrays.arrow.array import ArrowExtensionArray
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/pandas/core/arrays/arrow/array.py", line 64, in <module>
#     from pandas.core.arrays.masked import BaseMaskedArray
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/pandas/core/arrays/masked.py", line 60, in <module>
#     from pandas.core import (
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/pandas/core/nanops.py", line 52, in <module>
#     bn = import_optional_dependency("bottleneck", errors="warn")
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/pandas/compat/_optional.py", line 135, in import_optional_dependency
#     module = importlib.import_module(name)
#   File "/Users/ibtissama/anaconda3/lib/python3.10/importlib/__init__.py", line 126, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/bottleneck/__init__.py", line 7, in <module>
#     from .move import (move_argmax, move_argmin, move_max, move_mean, move_median,
# AttributeError: _ARRAY_API not found
# AttributeError: _ARRAY_API not found
#
# A module that was compiled using NumPy 1.x cannot be run in
# NumPy 2.1.3 as it may crash. To support both 1.x and 2.x
# versions of NumPy, modules must be compiled with NumPy 2.0.
# Some module may need to rebuild instead e.g. with 'pybind11>=2.12'.
#
# If you are a user of the module, the easiest solution will be to
# downgrade to 'numpy<2' or try to upgrade the affected module.
# We expect that some modules will need time to support NumPy 2.
#
# Traceback (most recent call last):  File "/Users/ibtissama/anaconda3/lib/python3.10/runpy.py", line 196, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "/Users/ibtissama/anaconda3/lib/python3.10/runpy.py", line 86, in _run_code
#     exec(code, run_globals)
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/joblib/externals/loky/backend/popen_loky_posix.py", line 180, in <module>
#     exitcode = process_obj._bootstrap()
#   File "/Users/ibtissama/anaconda3/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/Users/ibtissama/anaconda3/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/joblib/externals/loky/process_executor.py", line 426, in _process_worker
#     call_item = call_queue.get(block=True, timeout=timeout)
#   File "/Users/ibtissama/anaconda3/lib/python3.10/multiprocessing/queues.py", line 122, in get
#     return _ForkingPickler.loads(res)
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/sklearn/__init__.py", line 73, in <module>
#     from .base import clone  # noqa: E402
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/sklearn/base.py", line 19, in <module>
#     from .utils._estimator_html_repr import _HTMLDocumentationLinkMixin, estimator_html_repr
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/sklearn/utils/__init__.py", line 15, in <module>
#     from ._chunking import gen_batches, gen_even_slices
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/sklearn/utils/_chunking.py", line 11, in <module>
#     from ._param_validation import Interval, validate_params
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/sklearn/utils/_param_validation.py", line 17, in <module>
#     from .validation import _is_arraylike_not_scalar
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/sklearn/utils/validation.py", line 21, in <module>
#     from ..utils._array_api import _asarray_with_order, _is_numpy_namespace, get_namespace
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/sklearn/utils/_array_api.py", line 17, in <module>
#     from .fixes import parse_version
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/sklearn/utils/fixes.py", line 20, in <module>
#     import pandas as pd
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/pandas/__init__.py", line 49, in <module>
#     from pandas.core.api import (
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/pandas/core/api.py", line 28, in <module>
#     from pandas.core.arrays import Categorical
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/pandas/core/arrays/__init__.py", line 1, in <module>
#     from pandas.core.arrays.arrow import ArrowExtensionArray
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/pandas/core/arrays/arrow/__init__.py", line 5, in <module>
#     from pandas.core.arrays.arrow.array import ArrowExtensionArray
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/pandas/core/arrays/arrow/array.py", line 64, in <module>
#     from pandas.core.arrays.masked import BaseMaskedArray
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/pandas/core/arrays/masked.py", line 60, in <module>
#     from pandas.core import (
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/pandas/core/nanops.py", line 52, in <module>
#     bn = import_optional_dependency("bottleneck", errors="warn")
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/pandas/compat/_optional.py", line 135, in import_optional_dependency
#     module = importlib.import_module(name)
#   File "/Users/ibtissama/anaconda3/lib/python3.10/importlib/__init__.py", line 126, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/bottleneck/__init__.py", line 7, in <module>
#     from .move import (move_argmax, move_argmin, move_max, move_mean, move_median,
# AttributeError: _ARRAY_API not found
#
# A module that was compiled using NumPy 1.x cannot be run in
# NumPy 2.1.3 as it may crash. To support both 1.x and 2.x
# versions of NumPy, modules must be compiled with NumPy 2.0.
# Some module may need to rebuild instead e.g. with 'pybind11>=2.12'.
#
# If you are a user of the module, the easiest solution will be to
# downgrade to 'numpy<2' or try to upgrade the affected module.
# We expect that some modules will need time to support NumPy 2.
#
# Traceback (most recent call last):  File "/Users/ibtissama/anaconda3/lib/python3.10/runpy.py", line 196, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "/Users/ibtissama/anaconda3/lib/python3.10/runpy.py", line 86, in _run_code
#     exec(code, run_globals)
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/joblib/externals/loky/backend/popen_loky_posix.py", line 180, in <module>
#     exitcode = process_obj._bootstrap()
#   File "/Users/ibtissama/anaconda3/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/Users/ibtissama/anaconda3/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/joblib/externals/loky/process_executor.py", line 426, in _process_worker
#     call_item = call_queue.get(block=True, timeout=timeout)
#   File "/Users/ibtissama/anaconda3/lib/python3.10/multiprocessing/queues.py", line 122, in get
#     return _ForkingPickler.loads(res)
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/sklearn/__init__.py", line 73, in <module>
#     from .base import clone  # noqa: E402
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/sklearn/base.py", line 19, in <module>
#     from .utils._estimator_html_repr import _HTMLDocumentationLinkMixin, estimator_html_repr
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/sklearn/utils/__init__.py", line 15, in <module>
#     from ._chunking import gen_batches, gen_even_slices
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/sklearn/utils/_chunking.py", line 11, in <module>
#     from ._param_validation import Interval, validate_params
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/sklearn/utils/_param_validation.py", line 17, in <module>
#     from .validation import _is_arraylike_not_scalar
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/sklearn/utils/validation.py", line 21, in <module>
#     from ..utils._array_api import _asarray_with_order, _is_numpy_namespace, get_namespace
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/sklearn/utils/_array_api.py", line 17, in <module>
#     from .fixes import parse_version
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/sklearn/utils/fixes.py", line 20, in <module>
#     import pandas as pd
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/pandas/__init__.py", line 49, in <module>
#     from pandas.core.api import (
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/pandas/core/api.py", line 28, in <module>
#     from pandas.core.arrays import Categorical
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/pandas/core/arrays/__init__.py", line 1, in <module>
#     from pandas.core.arrays.arrow import ArrowExtensionArray
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/pandas/core/arrays/arrow/__init__.py", line 5, in <module>
#     from pandas.core.arrays.arrow.array import ArrowExtensionArray
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/pandas/core/arrays/arrow/array.py", line 64, in <module>
#     from pandas.core.arrays.masked import BaseMaskedArray
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/pandas/core/arrays/masked.py", line 60, in <module>
#     from pandas.core import (
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/pandas/core/nanops.py", line 52, in <module>
#     bn = import_optional_dependency("bottleneck", errors="warn")
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/pandas/compat/_optional.py", line 135, in import_optional_dependency
#     module = importlib.import_module(name)
#   File "/Users/ibtissama/anaconda3/lib/python3.10/importlib/__init__.py", line 126, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/bottleneck/__init__.py", line 7, in <module>
#     from .move import (move_argmax, move_argmin, move_max, move_mean, move_median,
# AttributeError: _ARRAY_API not found
#
# A module that was compiled using NumPy 1.x cannot be run in
# NumPy 2.1.3 as it may crash. To support both 1.x and 2.x
# versions of NumPy, modules must be compiled with NumPy 2.0.
# Some module may need to rebuild instead e.g. with 'pybind11>=2.12'.
#
# If you are a user of the module, the easiest solution will be to
# downgrade to 'numpy<2' or try to upgrade the affected module.
# We expect that some modules will need time to support NumPy 2.
#
# Traceback (most recent call last):  File "/Users/ibtissama/anaconda3/lib/python3.10/runpy.py", line 196, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "/Users/ibtissama/anaconda3/lib/python3.10/runpy.py", line 86, in _run_code
#     exec(code, run_globals)
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/joblib/externals/loky/backend/popen_loky_posix.py", line 180, in <module>
#     exitcode = process_obj._bootstrap()
#   File "/Users/ibtissama/anaconda3/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/Users/ibtissama/anaconda3/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/joblib/externals/loky/process_executor.py", line 426, in _process_worker
#     call_item = call_queue.get(block=True, timeout=timeout)
#   File "/Users/ibtissama/anaconda3/lib/python3.10/multiprocessing/queues.py", line 122, in get
#     return _ForkingPickler.loads(res)
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/sklearn/__init__.py", line 73, in <module>
#     from .base import clone  # noqa: E402
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/sklearn/base.py", line 19, in <module>
#     from .utils._estimator_html_repr import _HTMLDocumentationLinkMixin, estimator_html_repr
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/sklearn/utils/__init__.py", line 15, in <module>
#     from ._chunking import gen_batches, gen_even_slices
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/sklearn/utils/_chunking.py", line 11, in <module>
#     from ._param_validation import Interval, validate_params
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/sklearn/utils/_param_validation.py", line 17, in <module>
#     from .validation import _is_arraylike_not_scalar
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/sklearn/utils/validation.py", line 21, in <module>
#     from ..utils._array_api import _asarray_with_order, _is_numpy_namespace, get_namespace
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/sklearn/utils/_array_api.py", line 17, in <module>
#     from .fixes import parse_version
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/sklearn/utils/fixes.py", line 20, in <module>
#     import pandas as pd
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/pandas/__init__.py", line 49, in <module>
#     from pandas.core.api import (
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/pandas/core/api.py", line 28, in <module>
#     from pandas.core.arrays import Categorical
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/pandas/core/arrays/__init__.py", line 1, in <module>
#     from pandas.core.arrays.arrow import ArrowExtensionArray
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/pandas/core/arrays/arrow/__init__.py", line 5, in <module>
#     from pandas.core.arrays.arrow.array import ArrowExtensionArray
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/pandas/core/arrays/arrow/array.py", line 64, in <module>
#     from pandas.core.arrays.masked import BaseMaskedArray
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/pandas/core/arrays/masked.py", line 60, in <module>
#     from pandas.core import (
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/pandas/core/nanops.py", line 52, in <module>
#     bn = import_optional_dependency("bottleneck", errors="warn")
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/pandas/compat/_optional.py", line 135, in import_optional_dependency
#     module = importlib.import_module(name)
#   File "/Users/ibtissama/anaconda3/lib/python3.10/importlib/__init__.py", line 126, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/bottleneck/__init__.py", line 7, in <module>
#     from .move import (move_argmax, move_argmin, move_max, move_mean, move_median,
# AttributeError: _ARRAY_API not found
# Fitting 5 folds for each of 324 candidates, totalling 1620 fits
# Fitting 5 folds for each of 324 candidates, totalling 1620 fits
# Fitting 5 folds for each of 324 candidates, totalling 1620 fits
# Fitting 5 folds for each of 324 candidates, totalling 1620 fits
#
# 📊 Average Confusion Matrix:
# [[629. 195.]
#  [239. 585.]]
#
# 🎯 Performance Metrics:
# 🔹 Precision (Class 1 - Long Career Players): 0.7507
# 🔹 Recall (Class 1 - Majority): 0.7100
# 🔹 F1-score (Class 1 - Long Career Players): 0.7291
# 🔹 Precision (Class 0 - Short Career Players): 0.7250
# 🔹 Recall (Class 0 - Minority): 0.7630
# 🔹 F1-score (Class 0 - Short Career Players): 0.7429
#
# 📜 Full Classification Report (average over folds):
#               precision    recall  f1-score   support
#
#          0.0       0.72      0.76      0.74       824
#          1.0       0.75      0.71      0.73       824
#
#     accuracy                           0.74      1648
#    macro avg       0.74      0.74      0.74      1648
# weighted avg       0.74      0.74      0.74      1648

# %% [markdown]
# L’ajout d’une optimisation par recherche exhaustive (GridSearchCV) a permis de trouver les meilleurs hyperparamètres du modèle.
#
# Cette approche a entraîné une amélioration des performances :
#
# ✅ F1-score Classe 1 (Longue carrière) : 0.7291 (+1.15%)
#
# ✅ F1-score Classe 0 (Courte carrière) : 0.7429 (+0.34%)
#
# ✅ Accuracy globale : 0.74 (+1 point)
#
# 🔍 Analyse :
#
# Le modèle fait de meilleurs choix, notamment pour la classe 1, avec une légère augmentation du recall (0.7100 contre 0.6894 précédemment).
# Le F1-score de la classe 0 (joueurs avec une carrière courte) s’améliore également, ce qui signifie que le modèle identifie mieux les joueurs qui ne dépasseront pas 5 ans en NBA.
# Amélioration globale de l’équilibre entre précision et rappel, grâce à un réglage plus fin des paramètres du modèle.

# %%
#Vesion 3 - Optimisation avec Optuna
rf = RandomForestClassifier(random_state=42)
rf_model = score_classifier_with_optuna(over_X, rf, over_y, 50, cv=5, use_stratified=False)
rf_model
# Out:
# [I 2025-03-06 15:38:49,925] A new study created in memory with name: no-name-9b13b0df-45e1-4204-bb11-9f4ec9b10681
# [I 2025-03-06 15:39:00,533] Trial 0 finished with value: 0.7232866644209365 and parameters: {'n_estimators': 800, 'max_depth': 10, 'min_samples_split': 7, 'min_samples_leaf': 4, 'max_features': 'sqrt'}. Best is trial 0 with value: 0.7232866644209365.
# [I 2025-03-06 15:39:03,537] Trial 1 finished with value: 0.7274719457895569 and parameters: {'n_estimators': 200, 'max_depth': None, 'min_samples_split': 6, 'min_samples_leaf': 2, 'max_features': 'log2'}. Best is trial 1 with value: 0.7274719457895569.
# [I 2025-03-06 15:39:07,201] Trial 2 finished with value: 0.7183056136532509 and parameters: {'n_estimators': 300, 'max_depth': 10, 'min_samples_split': 3, 'min_samples_leaf': 9, 'max_features': 'log2'}. Best is trial 1 with value: 0.7274719457895569.
# [I 2025-03-06 15:39:09,678] Trial 3 finished with value: 0.7223443102386662 and parameters: {'n_estimators': 200, 'max_depth': None, 'min_samples_split': 19, 'min_samples_leaf': 5, 'max_features': 'log2'}. Best is trial 1 with value: 0.7274719457895569.
# [I 2025-03-06 15:39:13,380] Trial 4 finished with value: 0.6969425649338953 and parameters: {'n_estimators': 400, 'max_depth': 5, 'min_samples_split': 4, 'min_samples_leaf': 3, 'max_features': 'log2'}. Best is trial 1 with value: 0.7274719457895569.
# [I 2025-03-06 15:39:36,737] Trial 5 finished with value: 0.7156395954084295 and parameters: {'n_estimators': 500, 'max_depth': 10, 'min_samples_split': 3, 'min_samples_leaf': 1, 'max_features': None}. Best is trial 1 with value: 0.7274719457895569.
# [I 2025-03-06 15:39:40,877] Trial 6 finished with value: 0.7259010966387023 and parameters: {'n_estimators': 300, 'max_depth': None, 'min_samples_split': 17, 'min_samples_leaf': 2, 'max_features': 'log2'}. Best is trial 1 with value: 0.7274719457895569.
# [I 2025-03-06 15:39:44,690] Trial 7 finished with value: 0.7171946459401904 and parameters: {'n_estimators': 300, 'max_depth': 10, 'min_samples_split': 13, 'min_samples_leaf': 3, 'max_features': 'sqrt'}. Best is trial 1 with value: 0.7274719457895569.
# [I 2025-03-06 15:40:24,190] Trial 8 finished with value: 0.7218436777185617 and parameters: {'n_estimators': 900, 'max_depth': None, 'min_samples_split': 3, 'min_samples_leaf': 3, 'max_features': None}. Best is trial 1 with value: 0.7274719457895569.
# [I 2025-03-06 15:40:33,413] Trial 9 finished with value: 0.7190745818881474 and parameters: {'n_estimators': 200, 'max_depth': None, 'min_samples_split': 20, 'min_samples_leaf': 1, 'max_features': None}. Best is trial 1 with value: 0.7274719457895569.
# [I 2025-03-06 15:41:00,566] Trial 10 finished with value: 0.7192920695756988 and parameters: {'n_estimators': 700, 'max_depth': None, 'min_samples_split': 9, 'min_samples_leaf': 7, 'max_features': None}. Best is trial 1 with value: 0.7274719457895569.
# [I 2025-03-06 15:41:05,623] Trial 11 finished with value: 0.7239570533786118 and parameters: {'n_estimators': 100, 'max_depth': 15, 'min_samples_split': 15, 'min_samples_leaf': 1, 'max_features': None}. Best is trial 1 with value: 0.7274719457895569.
# [I 2025-03-06 15:41:28,124] Trial 12 finished with value: 0.7171220863623465 and parameters: {'n_estimators': 600, 'max_depth': None, 'min_samples_split': 16, 'min_samples_leaf': 7, 'max_features': None}. Best is trial 1 with value: 0.7274719457895569.
# [I 2025-03-06 15:41:32,893] Trial 13 finished with value: 0.7261958421290026 and parameters: {'n_estimators': 100, 'max_depth': None, 'min_samples_split': 8, 'min_samples_leaf': 2, 'max_features': None}. Best is trial 1 with value: 0.7274719457895569.
# [I 2025-03-06 15:41:36,916] Trial 14 finished with value: 0.7227648050474625 and parameters: {'n_estimators': 100, 'max_depth': None, 'min_samples_split': 7, 'min_samples_leaf': 5, 'max_features': None}. Best is trial 1 with value: 0.7274719457895569.
# [I 2025-03-06 15:41:41,062] Trial 15 finished with value: 0.7246430197232991 and parameters: {'n_estimators': 100, 'max_depth': None, 'min_samples_split': 10, 'min_samples_leaf': 7, 'max_features': None}. Best is trial 1 with value: 0.7274719457895569.
# [I 2025-03-06 15:41:58,344] Trial 16 finished with value: 0.7147429137532109 and parameters: {'n_estimators': 500, 'max_depth': None, 'min_samples_split': 6, 'min_samples_leaf': 10, 'max_features': None}. Best is trial 1 with value: 0.7274719457895569.
# [I 2025-03-06 15:42:44,476] Trial 17 finished with value: 0.7253395308852882 and parameters: {'n_estimators': 1000, 'max_depth': None, 'min_samples_split': 12, 'min_samples_leaf': 2, 'max_features': None}. Best is trial 1 with value: 0.7274719457895569.
# [I 2025-03-06 15:43:00,959] Trial 18 finished with value: 0.7183871658060315 and parameters: {'n_estimators': 400, 'max_depth': None, 'min_samples_split': 9, 'min_samples_leaf': 6, 'max_features': None}. Best is trial 1 with value: 0.7274719457895569.
# [I 2025-03-06 15:43:09,360] Trial 19 finished with value: 0.7235567000395038 and parameters: {'n_estimators': 200, 'max_depth': None, 'min_samples_split': 5, 'min_samples_leaf': 4, 'max_features': None}. Best is trial 1 with value: 0.7274719457895569.
# [I 2025-03-06 15:43:26,580] Trial 20 finished with value: 0.7193583159059889 and parameters: {'n_estimators': 400, 'max_depth': None, 'min_samples_split': 8, 'min_samples_leaf': 4, 'max_features': None}. Best is trial 1 with value: 0.7274719457895569.
# [I 2025-03-06 15:43:40,109] Trial 21 finished with value: 0.7202948281779725 and parameters: {'n_estimators': 300, 'max_depth': None, 'min_samples_split': 17, 'min_samples_leaf': 2, 'max_features': None}. Best is trial 1 with value: 0.7274719457895569.
# [I 2025-03-06 15:43:49,025] Trial 22 finished with value: 0.7253026384535262 and parameters: {'n_estimators': 200, 'max_depth': None, 'min_samples_split': 11, 'min_samples_leaf': 2, 'max_features': None}. Best is trial 1 with value: 0.7274719457895569.
# [I 2025-03-06 15:43:53,462] Trial 23 finished with value: 0.7260399690802053 and parameters: {'n_estimators': 100, 'max_depth': None, 'min_samples_split': 14, 'min_samples_leaf': 2, 'max_features': None}. Best is trial
classification Report:
#               precision    recall  f1-score   support
#
#          0.0       0.73      0.76      0.75       824
#          1.0       0.75      0.71      0.73       824
#
#     accuracy                           0.74      1648
#    macro avg       0.74      0.74      0.74      1648
# weighted avg       0.74      0.74      0.74      1648
# RandomForestClassifier(max_features=None, min_samples_leaf=2,
#                        min_samples_split=13, random_state=42)

# %% [markdown]
# L’utilisation d’Optuna, une technique plus avancée et adaptative d’optimisation des hyperparamètres, a permis d’obtenir les meilleurs résultats observés jusque-là :
#
# ✅ F1-score Classe 1 (Longue carrière) : 0.7310 (+1.34% par rapport à la V1)
#
# ✅ F1-score Classe 0 (Courte carrière) : 0.7447 (+0.52% par rapport à la V1)
#
# ✅ Accuracy globale : 74
#
# 🔍 Analyse :
#
# L’optimisation dynamique via Optuna a permis de mieux ajuster les hyperparamètres, ce qui se traduit par une meilleure séparation des classes.
# Le recall pour la classe 1 (0.7123) continue d’augmenter, ce qui signifie que plus de joueurs prometteurs sont correctement identifiés.
# Le modèle réduit encore davantage les erreurs sur la classe 0, atteignant un recall de 0.7644 (meilleure valeur observée).
# Meilleure balance globale entre recall et précision, ce qui signifie que le modèle est plus fiable pour éviter les faux positifs et les faux négatifs.

# %% [markdown]
# 👉 *Le modèle final (Version 3 - Optuna) est plus performant que les versions précédentes, offrant une meilleure capacité de prédiction pour identifier les joueurs ayant une longue carrière NBA.*

# %% [markdown]
# ##### 5.2 Balanced Random Forest (BRF)

# %%
# Version 1 - KFold Stratifié
brf = BalancedRandomForestClassifier(random_state=42)

score_classifier(df_vals, brf, labels,"stratified")
# Out:
# 📊 Confusion Matrix:
# [[324. 180.]
#  [239. 585.]]
#
# 🎯 Performance Metrics:
# 🔹 Precision: Class 1 (Long Career Players): 0.7654
# 🔹 Recall: Class 1 (Long Career Players): 0.7099
# 🔹 F1-score: Class 1 (Long Career Players): 0.7359
# 🔹 Precision: Class 0 (Short Career Players): 0.5768
# 🔹 Recall: Class 0 (Short Career Players): 0.6428
# 🔹 F1-score: Class 0 (Short Career Players): 0.6069
#
# 📌 Full Classification Report (Averaged Over 5 Folds):
#               precision    recall  f1-score   support
#
#          0.0       0.58      0.64      0.61       504
#          1.0       0.76      0.71      0.74       824
#
#     accuracy                           0.68      1328
#    macro avg       0.67      0.68      0.67      1328
# weighted avg       0.69      0.68      0.69      1328

# %% [markdown]
# Dans cette première approche, nous avons utilisé les hyperparamètres par défaut du modèle sans optimisation spécifique.
#
# ✅ F1-score Classe 1 (Longue carrière) : 0.7359
#
# ✅ F1-score Classe 0 (Courte carrière) : 0.6069
#
# ✅ Accuracy globale : 0.68
#
# 🔍 Analyse :
#
# Le modèle favorise fortement la classe majoritaire (Classe 1 - joueurs avec une longue carrière), avec un recall de 0.7099. Cela signifie qu'il parvient à capturer un bon nombre de joueurs qui auront une longue carrière.
# Cependant, le recall de la classe 0 (0.6428) est relativement faible, indiquant que le modèle ne détecte pas bien les joueurs ayant une carrière courte.
# Le déséquilibre des classes semble impacter les performances globales, avec une précision faible pour la classe 0 (0.5768)

# %%
# Version 2 - Optimisation GridSearchCV
param_grid_brf = {
    "n_estimators": [100, 300, 500],
    "max_depth": [3, 5, 7, None],
    "min_samples_split": [2, 5, 10],
    "min_samples_leaf": [1, 2, 4],
    "max_features": ['sqrt', 'log2', None],
}

brf = BalancedRandomForestClassifier(random_state=42)

score_classifier_with_tuning(over_X, brf, over_y, param_grid_brf,5,"stratified")
# Out:
# Fitting 5 folds for each of 324 candidates, totalling 1620 fits
# A module that was compiled using NumPy 1.x cannot be run in
# NumPy 2.1.3 as it may crash. To support both 1.x and 2.x
# versions of NumPy, modules must be compiled with NumPy 2.0.
# Some module may need to rebuild instead e.g. with 'pybind11>=2.12'.
#
# If you are a user of the module, the easiest solution will be to
# downgrade to 'numpy<2' or try to upgrade the affected module.
# We expect that some modules will need time to support NumPy 2.
#
# Traceback (most recent call last):  File "/Users/ibtissama/anaconda3/lib/python3.10/runpy.py", line 196, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "/Users/ibtissama/anaconda3/lib/python3.10/runpy.py", line 86, in _run_code
#     exec(code, run_globals)
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/joblib/externals/loky/backend/popen_loky_posix.py", line 180, in <module>
#     exitcode = process_obj._bootstrap()
#   File "/Users/ibtissama/anaconda3/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/Users/ibtissama/anaconda3/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/joblib/externals/loky/process_executor.py", line 426, in _process_worker
#     call_item = call_queue.get(block=True, timeout=timeout)
#   File "/Users/ibtissama/anaconda3/lib/python3.10/multiprocessing/queues.py", line 122, in get
#     return _ForkingPickler.loads(res)
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/sklearn/__init__.py", line 73, in <module>
#     from .base import clone  # noqa: E402
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/sklearn/base.py", line 19, in <module>
#     from .utils._estimator_html_repr import _HTMLDocumentationLinkMixin, estimator_html_repr
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/sklearn/utils/__init__.py", line 15, in <module>
#     from ._chunking import gen_batches, gen_even_slices
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/sklearn/utils/_chunking.py", line 11, in <module>
#     from ._param_validation import Interval, validate_params
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/sklearn/utils/_param_validation.py", line 17, in <module>
#     from .validation import _is_arraylike_not_scalar
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/sklearn/utils/validation.py", line 21, in <module>
#     from ..utils._array_api import _asarray_with_order, _is_numpy_namespace, get_namespace
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/sklearn/utils/_array_api.py", line 17, in <module>
#     from .fixes import parse_version
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/sklearn/utils/fixes.py", line 20, in <module>
#     import pandas as pd
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/pandas/__init__.py", line 26, in <module>
#     from pandas.compat import (
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/pandas/compat/__init__.py", line 27, in <module>
#     from pandas.compat.pyarrow import (
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/pandas/compat/pyarrow.py", line 8, in <module>
#     import pyarrow as pa
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/pyarrow/__init__.py", line 65, in <module>
#     import pyarrow.lib as _lib
#
# A module that was compiled using NumPy 1.x cannot be run in
# NumPy 2.1.3 as it may crash. To support both 1.x and 2.x
# versions of NumPy, modules must be compiled with NumPy 2.0.
# Some module may need to rebuild instead e.g. with 'pybind11>=2.12'.
#
# If you are a user of the module, the easiest solution will be to
# downgrade to 'numpy<2' or try to upgrade the affected module.
# We expect that some modules will need time to support NumPy 2.
#
# Traceback (most recent call last):  File "/Users/ibtissama/anaconda3/lib/python3.10/runpy.py", line 196, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "/Users/ibtissama/anaconda3/lib/python3.10/runpy.py", line 86, in _run_code
#     exec(code, run_globals)
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/joblib/externals/loky/backend/popen_loky_posix.py", line 180, in <module>
#     exitcode = process_obj._bootstrap()
#   File "/Users/ibtissama/anaconda3/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/Users/ibtissama/anaconda3/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/joblib/externals/loky/process_executor.py", line 426, in _process_worker
#     call_item = call_queue.get(block=True, timeout=timeout)
#   File "/Users/ibtissama/anaconda3/lib/python3.10/multiprocessing/queues.py", line 122, in get
#     return _ForkingPickler.loads(res)
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/sklearn/__init__.py", line 73, in <module>
#     from .base import clone  # noqa: E402
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/sklearn/base.py", line 19, in <module>
#     from .utils._estimator_html_repr import _HTMLDocumentationLinkMixin, estimator_html_repr
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/sklearn/utils/__init__.py", line 15, in <module>
#     from ._chunking import gen_batches, gen_even_slices
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/sklearn/utils/_chunking.py", line 11, in <module>
#     from ._param_validation import Interval, validate_params
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/sklearn/utils/_param_validation.py", line 17, in <module>
#     from .validation import _is_arraylike_not_scalar
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/sklearn/utils/validation.py", line 21, in <module>
#     from ..utils._array_api import _asarray_with_order, _is_numpy_namespace, get_namespace
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/sklearn/utils/_array_api.py", line 17, in <module>
#     from .fixes import parse_version
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/sklearn/utils/fixes.py", line 20, in <module>
#     import pandas as pd
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/pandas/__init__.py", line 26, in <module>
#     from pandas.compat import (
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/pandas/compat/__init__.py", line 27, in <module>
#     from pandas.compat.pyarrow import (
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/pandas/compat/pyarrow.py", line 8, in <module>
#     import pyarrow as pa
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/pyarrow/__init__.py", line 65, in <module>
#     import pyarrow.lib as _lib
#
# A module that was compiled using NumPy 1.x cannot be run in
# NumPy 2.1.3 as it may crash. To support both 1.x and 2.x
# versions of NumPy, modules must be compiled with NumPy 2.0.
# Some module may need to rebuild instead e.g. with 'pybind11>=2.12'.
#
# If you are a user of the module, the easiest solution will be to
# downgrade to 'numpy<2' or try to upgrade the affected module.
# We expect that some modules will need time to support NumPy 2.
#
# Traceback (most recent call last):  File "/Users/ibtissama/anaconda3/lib/python3.10/runpy.py", line 196, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "/Users/ibtissama/anaconda3/lib/python3.10/runpy.py", line 86, in _run_code
#     exec(code, run_globals)
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/joblib/externals/loky/backend/popen_loky_posix.py", line 180, in <module>
#     exitcode = process_obj._bootstrap()
#   File "/Users/ibtissama/anaconda3/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/Users/ibtissama/anaconda3/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/joblib/externals/loky/process_executor.py", line 426, in _process_worker
#     call_item = call_queue.get(block=True, timeout=timeout)
#   File "/Users/ibtissama/anaconda3/lib/python3.10/multiprocessing/queues.py", line 122, in get
#     return _ForkingPickler.loads(res)
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/sklearn/__init__.py", line 73, in <module>
#     from .base import clone  # noqa: E402
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/sklearn/base.py", line 19, in <module>
#     from .utils._estimator_html_repr import _HTMLDocumentationLinkMixin, estimator_html_repr
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/sklearn/utils/__init__.py", line 15, in <module>
#     from ._chunking import gen_batches, gen_even_slices
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/sklearn/utils/_chunking.py", line 11, in <module>
#     from ._param_validation import Interval, validate_params
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/sklearn/utils/_param_validation.py", line 17, in <module>
#     from .validation import _is_arraylike_not_scalar
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/sklearn/utils/validation.py", line 21, in <module>
#     from ..utils._array_api import _asarray_with_order, _is_numpy_namespace, get_namespace
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/sklearn/utils/_array_api.py", line 17, in <module>
#     from .fixes import parse_version
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/sklearn/utils/fixes.py", line 20, in <module>
#     import pandas as pd
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/pandas/__init__.py", line 26, in <module>
#     from pandas.compat import (
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/pandas/compat/__init__.py", line 27, in <module>
#     from pandas.compat.pyarrow import (
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/pandas/compat/pyarrow.py", line 8, in <module>
#     import pyarrow as pa
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/pyarrow/__init__.py", line 65, in <module>
#     import pyarrow.lib as _lib
#
# A module that was compiled using NumPy 1.x cannot be run in
# NumPy 2.1.3 as it may crash. To support both 1.x and 2.x
# versions of NumPy, modules must be compiled with NumPy 2.0.
# Some module may need to rebuild instead e.g. with 'pybind11>=2.12'.
#
# If you are a user of the module, the easiest solution will be to
# downgrade to 'numpy<2' or try to upgrade the affected module.
# We expect that some modules will need time to support NumPy 2.
#
# Traceback (most recent call last):  File "/Users/ibtissama/anaconda3/lib/python3.10/runpy.py", line 196, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "/Users/ibtissama/anaconda3/lib/python3.10/runpy.py", line 86, in _run_code
#     exec(code, run_globals)
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/joblib/externals/loky/backend/popen_loky_posix.py", line 180, in <module>
#     exitcode = process_obj._bootstrap()
#   File "/Users/ibtissama/anaconda3/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/Users/ibtissama/anaconda3/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/joblib/externals/loky/process_executor.py", line 426, in _process_worker
#     call_item = call_queue.get(block=True, timeout=timeout)
#   File "/Users/ibtissama/anaconda3/lib/python3.10/multiprocessing/queues.py", line 122, in get
#     return _ForkingPickler.loads(res)
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/sklearn/__init__.py", line 73, in <module>
#     from .base import clone  # noqa: E402
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/sklearn/base.py", line 19, in <module>
#     from .utils._estimator_html_repr import _HTMLDocumentationLinkMixin, estimator_html_repr
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/sklearn/utils/__init__.py", line 15, in <module>
#     from ._chunking import gen_batches, gen_even_slices
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/sklearn/utils/_chunking.py", line 11, in <module>
#     from ._param_validation import Interval, validate_params
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/sklearn/utils/_param_validation.py", line 17, in <module>
#     from .validation import _is_arraylike_not_scalar
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/sklearn/utils/validation.py", line 21, in <module>
#     from ..utils._array_api import _asarray_with_order, _is_numpy_namespace, get_namespace
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/sklearn/utils/_array_api.py", line 17, in <module>
#     from .fixes import parse_version
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/sklearn/utils/fixes.py", line 20, in <module>
#     import pandas as pd
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/pandas/__init__.py", line 26, in <module>
#     from pandas.compat import (
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/pandas/compat/__init__.py", line 27, in <module>
#     from pandas.compat.pyarrow import (
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/pandas/compat/pyarrow.py", line 8, in <module>
#     import pyarrow as pa
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/pyarrow/__init__.py", line 65, in <module>
#     import pyarrow.lib as _lib
# AttributeError: AttributeError: _ARRAY_API not found
# AttributeError: _ARRAY_API not found
#
# A module that was compiled using NumPy 1.x cannot be run in
# NumPy 2.1.3 as it may crash. To support both 1.x and 2.x
# versions of NumPy, modules must be compiled with NumPy 2.0.
# Some module may need to rebuild instead e.g. with 'pybind11>=2.12'.
#
# If you are a user of the module, the easiest solution will be to
# downgrade to 'numpy<2' or try to upgrade the affected module.
# We expect that some modules will need time to support NumPy 2.
#
# Traceback (most recent call last):  File "/Users/ibtissama/anaconda3/lib/python3.10/runpy.py", line 196, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "/Users/ibtissama/anaconda3/lib/python3.10/runpy.py", line 86, in _run_code
#     exec(code, run_globals)
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/joblib/externals/loky/backend/popen_loky_posix.py", line 180, in <module>
#     exitcode = process_obj._bootstrap()
#   File "/Users/ibtissama/anaconda3/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/Users/ibtissama/anaconda3/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/joblib/externals/loky/process_executor.py", line 426, in _process_worker
#     call_item = call_queue.get(block=True, timeout=timeout)
#   File "/Users/ibtissama/anaconda3/lib/python3.10/multiprocessing/queues.py", line 122, in get
#     return _ForkingPickler.loads(res)
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/sklearn/__init__.py", line 73, in <module>
#     from .base import clone  # noqa: E402
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/sklearn/base.py", line 19, in <module>
#     from .utils._estimator_html_repr import _HTMLDocumentationLinkMixin, estimator_html_repr
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/sklearn/utils/__init__.py", line 15, in <module>
#     from ._chunking import gen_batches, gen_even_slices
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/sklearn/utils/_chunking.py", line 11, in <module>
#     from ._param_validation import Interval, validate_params
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/sklearn/utils/_param_validation.py", line 17, in <module>
#     from .validation import _is_arraylike_not_scalar
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/sklearn/utils/validation.py", line 21, in <module>
#     from ..utils._array_api import _asarray_with_order, _is_numpy_namespace, get_namespace
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/sklearn/utils/_array_api.py", line 17, in <module>
#     from .fixes import parse_version
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/sklearn/utils/fixes.py", line 20, in <module>
#     import pandas as pd
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/pandas/__init__.py", line 26, in <module>
#     from pandas.compat import (
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/pandas/compat/__init__.py", line 27, in <module>
#     from pandas.compat.pyarrow import (
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/pandas/compat/pyarrow.py", line 8, in <module>
#     import pyarrow as pa
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/pyarrow/__init__.py", line 65, in <module>
#     import pyarrow.lib as _lib
# _ARRAY_API not foundAttributeError:
# _ARRAY_API not found
# AttributeError: _ARRAY_API not found
#
# A module that was compiled using NumPy 1.x cannot be run in
# NumPy 2.1.3 as it may crash. To support both 1.x and 2.x
# versions of NumPy, modules must be compiled with NumPy 2.0.
# Some module may need to rebuild instead e.g. with 'pybind11>=2.12'.
#
# If you are a user of the module, the easiest solution will be to
# downgrade to 'numpy<2' or try to upgrade the affected module.
# We expect that some modules will need time to support NumPy 2.
#
# Traceback (most recent call last):  File "/Users/ibtissama/anaconda3/lib/python3.10/runpy.py", line 196, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "/Users/ibtissama/anaconda3/lib/python3.10/runpy.py", line 86, in _run_code
#     exec(code, run_globals)
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/joblib/externals/loky/backend/popen_loky_posix.py", line 180, in <module>
#     exitcode = process_obj._bootstrap()
#   File "/Users/ibtissama/anaconda3/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/Users/ibtissama/anaconda3/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/joblib/externals/loky/process_executor.py", line 426, in _process_worker
#     call_item = call_queue.get(block=True, timeout=timeout)
#   File "/Users/ibtissama/anaconda3/lib/python3.10/multiprocessing/queues.py", line 122, in get
#     return _ForkingPickler.loads(res)
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/sklearn/__init__.py", line 73, in <module>
#     from .base import clone  # noqa: E402
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/sklearn/base.py", line 19, in <module>
#     from .utils._estimator_html_repr import _HTMLDocumentationLinkMixin, estimator_html_repr
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/sklearn/utils/__init__.py", line 15, in <module>
#     from ._chunking import gen_batches, gen_even_slices
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/sklearn/utils/_chunking.py", line 11, in <module>
#     from ._param_validation import Interval, validate_params
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/sklearn/utils/_param_validation.py", line 17, in <module>
#     from .validation import _is_arraylike_not_scalar
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/sklearn/utils/validation.py", line 21, in <module>
#     from ..utils._array_api import _asarray_with_order, _is_numpy_namespace, get_namespace
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/sklearn/utils/_array_api.py", line 17, in <module>
#     from .fixes import parse_version
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/sklearn/utils/fixes.py", line 20, in <module>
#     import pandas as pd
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/pandas/__init__.py", line 26, in <module>
#     from pandas.compat import (
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/pandas/compat/__init__.py", line 27, in <module>
#     from pandas.compat.pyarrow import (
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/pandas/compat/pyarrow.py", line 8, in <module>
#     import pyarrow as pa
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/pyarrow/__init__.py", line 65, in <module>
#     import pyarrow.lib as _lib
#
# A module that was compiled using NumPy 1.x cannot be run in
# NumPy 2.1.3 as it may crash. To support both 1.x and 2.x
# versions of NumPy, modules must be compiled with NumPy 2.0.
# Some module may need to rebuild instead e.g. with 'pybind11>=2.12'.
#
# If you are a user of the module, the easiest solution will be to
# downgrade to 'numpy<2' or try to upgrade the affected module.
# We expect that some modules will need time to support NumPy 2.
#
# Traceback (most recent call last):  File "/Users/ibtissama/anaconda3/lib/python3.10/runpy.py", line 196, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "/Users/ibtissama/anaconda3/lib/python3.10/runpy.py", line 86, in _run_code
#     exec(code, run_globals)
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/joblib/externals/loky/backend/popen_loky_posix.py", line 180, in <module>
#     exitcode = process_obj._bootstrap()
#   File "/Users/ibtissama/anaconda3/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/Users/ibtissama/anaconda3/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/joblib/externals/loky/process_executor.py", line 426, in _process_worker
#     call_item = call_queue.get(block=True, timeout=timeout)
#   File "/Users/ibtissama/anaconda3/lib/python3.10/multiprocessing/queues.py", line 122, in get
#     return _ForkingPickler.loads(res)
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/sklearn/__init__.py", line 73, in <module>
#     from .base import clone  # noqa: E402
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/sklearn/base.py", line 19, in <module>
#     from .utils._estimator_html_repr import _HTMLDocumentationLinkMixin, estimator_html_repr
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/sklearn/utils/__init__.py", line 15, in <module>
#     from ._chunking import gen_batches, gen_even_slices
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/sklearn/utils/_chunking.py", line 11, in <module>
#     from ._param_validation import Interval, validate_params
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/sklearn/utils/_param_validation.py", line 17, in <module>
#     from .validation import _is_arraylike_not_scalar
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/sklearn/utils/validation.py", line 21, in <module>
#     from ..utils._array_api import _asarray_with_order, _is_numpy_namespace, get_namespace
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/sklearn/utils/_array_api.py", line 17, in <module>
#     from .fixes import parse_version
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/sklearn/utils/fixes.py", line 20, in <module>
#     import pandas as pd
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/pandas/__init__.py", line 26, in <module>
#     from pandas.compat import (
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/pandas/compat/__init__.py", line 27, in <module>
#     from pandas.compat.pyarrow import (
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/pandas/compat/pyarrow.py", line 8, in <module>
#     import pyarrow as pa
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/pyarrow/__init__.py", line 65, in <module>
#     import pyarrow.lib as _lib
# AttributeError: _ARRAY_API not found
# AttributeError: _ARRAY_API not found
#
# A module that was compiled using NumPy 1.x cannot be run in
# NumPy 2.1.3 as it may crash. To support both 1.x and 2.x
# versions of NumPy, modules must be compiled with NumPy 2.0.
# Some module may need to rebuild instead e.g. with 'pybind11>=2.12'.
#
# If you are a user of the module, the easiest solution will be to
# downgrade to 'numpy<2' or try to upgrade the affected module.
# We expect that some modules will need time to support NumPy 2.
#
# Traceback (most recent call last):  File "/Users/ibtissama/anaconda3/lib/python3.10/runpy.py", line 196, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "/Users/ibtissama/anaconda3/lib/python3.10/runpy.py", line 86, in _run_code
#     exec(code, run_globals)
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/joblib/externals/loky/backend/popen_loky_posix.py", line 180, in <module>
#     exitcode = process_obj._bootstrap()
#   File "/Users/ibtissama/anaconda3/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/Users/ibtissama/anaconda3/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/joblib/externals/loky/process_executor.py", line 426, in _process_worker
#     call_item = call_queue.get(block=True, timeout=timeout)
#   File "/Users/ibtissama/anaconda3/lib/python3.10/multiprocessing/queues.py", line 122, in get
#     return _ForkingPickler.loads(res)
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/sklearn/__init__.py", line 73, in <module>
#     from .base import clone  # noqa: E402
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/sklearn/base.py", line 19, in <module>
#     from .utils._estimator_html_repr import _HTMLDocumentationLinkMixin, estimator_html_repr
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/sklearn/utils/__init__.py", line 15, in <module>
#     from ._chunking import gen_batches, gen_even_slices
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/sklearn/utils/_chunking.py", line 11, in <module>
#     from ._param_validation import Interval, validate_params
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/sklearn/utils/_param_validation.py", line 17, in <module>
#     from .validation import _is_arraylike_not_scalar
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/sklearn/utils/validation.py", line 21, in <module>
#     from ..utils._array_api import _asarray_with_order, _is_numpy_namespace, get_namespace
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/sklearn/utils/_array_api.py", line 17, in <module>
#     from .fixes import parse_version
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/sklearn/utils/fixes.py", line 20, in <module>
#     import pandas as pd
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/pandas/__init__.py", line 26, in <module>
#     from pandas.compat import (
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/pandas/compat/__init__.py", line 27, in <module>
#     from pandas.compat.pyarrow import (
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/pandas/compat/pyarrow.py", line 8, in <module>
#     import pyarrow as pa
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/pyarrow/__init__.py", line 65, in <module>
#     import pyarrow.lib as _lib
# AttributeError: _ARRAY_API not found
#
# A module that was compiled using NumPy 1.x cannot be run in
# NumPy 2.1.3 as it may crash. To support both 1.x and 2.x
# versions of NumPy, modules must be compiled with NumPy 2.0.
# Some module may need to rebuild instead e.g. with 'pybind11>=2.12'.
#
# If you are a user of the module, the easiest solution will be to
# downgrade to 'numpy<2' or try to upgrade the affected module.
# We expect that some modules will need time to support NumPy 2.
#
# Traceback (most recent call last):  File "/Users/ibtissama/anaconda3/lib/python3.10/runpy.py", line 196, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "/Users/ibtissama/anaconda3/lib/python3.10/runpy.py", line 86, in _run_code
#     exec(code, run_globals)
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/joblib/externals/loky/backend/popen_loky_posix.py", line 180, in <module>
#     exitcode = process_obj._bootstrap()
#   File "/Users/ibtissama/anaconda3/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/Users/ibtissama/anaconda3/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/joblib/externals/loky/process_executor.py", line 426, in _process_worker
#     call_item = call_queue.get(block=True, timeout=timeout)
#   File "/Users/ibtissama/anaconda3/lib/python3.10/multiprocessing/queues.py", line 122, in get
#     return _ForkingPickler.loads(res)
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/sklearn/__init__.py", line 73, in <module>
#     from .base import clone  # noqa: E402
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/sklearn/base.py", line 19, in <module>
#     from .utils._estimator_html_repr import _HTMLDocumentationLinkMixin, estimator_html_repr
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/sklearn/utils/__init__.py", line 15, in <module>
#     from ._chunking import gen_batches, gen_even_slices
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/sklearn/utils/_chunking.py", line 11, in <module>
#     from ._param_validation import Interval, validate_params
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/sklearn/utils/_param_validation.py", line 17, in <module>
#     from .validation import _is_arraylike_not_scalar
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/sklearn/utils/validation.py", line 21, in <module>
#     from ..utils._array_api import _asarray_with_order, _is_numpy_namespace, get_namespace
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/sklearn/utils/_array_api.py", line 17, in <module>
#     from .fixes import parse_version
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/sklearn/utils/fixes.py", line 20, in <module>
#     import pandas as pd
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/pandas/__init__.py", line 49, in <module>
#     from pandas.core.api import (
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/pandas/core/api.py", line 9, in <module>
#     from pandas.core.dtypes.dtypes import (
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/pandas/core/dtypes/dtypes.py", line 24, in <module>
#     from pandas._libs import (
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/pyarrow/__init__.py", line 65, in <module>
#     import pyarrow.lib as _lib
#
# A module that was compiled using NumPy 1.x cannot be run in
# NumPy 2.1.3 as it may crash. To support both 1.x and 2.x
# versions of NumPy, modules must be compiled with NumPy 2.0.
# Some module may need to rebuild instead e.g. with 'pybind11>=2.12'.
#
# If you are a user of the module, the easiest solution will be to
# downgrade to 'numpy<2' or try to upgrade the affected module.
# We expect that some modules will need time to support NumPy 2.
#
# Traceback (most recent call last):  File "/Users/ibtissama/anaconda3/lib/python3.10/runpy.py", line 196, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "/Users/ibtissama/anaconda3/lib/python3.10/runpy.py", line 86, in _run_code
#     exec(code, run_globals)
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/joblib/externals/loky/backend/popen_loky_posix.py", line 180, in <module>
#     exitcode = process_obj._bootstrap()
#   File "/Users/ibtissama/anaconda3/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/Users/ibtissama/anaconda3/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/joblib/externals/loky/process_executor.py", line 426, in _process_worker
#     call_item = call_queue.get(block=True, timeout=timeout)
#   File "/Users/ibtissama/anaconda3/lib/python3.10/multiprocessing/queues.py", line 122, in get
#     return _ForkingPickler.loads(res)
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/sklearn/__init__.py", line 73, in <module>
#     from .base import clone  # noqa: E402
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/sklearn/base.py", line 19, in <module>
#     from .utils._estimator_html_repr import _HTMLDocumentationLinkMixin, estimator_html_repr
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/sklearn/utils/__init__.py", line 15, in <module>
#     from ._chunking import gen_batches, gen_even_slices
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/sklearn/utils/_chunking.py", line 11, in <module>
#     from ._param_validation import Interval, validate_params
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/sklearn/utils/_param_validation.py", line 17, in <module>
#     from .validation import _is_arraylike_not_scalar
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/sklearn/utils/validation.py", line 21, in <module>
#     from ..utils._array_api import _asarray_with_order, _is_numpy_namespace, get_namespace
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/sklearn/utils/_array_api.py", line 17, in <module>
#     from .fixes import parse_version
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/sklearn/utils/fixes.py", line 20, in <module>
#     import pandas as pd
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/pandas/__init__.py", line 49, in <module>
#     from pandas.core.api import (
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/pandas/core/api.py", line 9, in <module>
#     from pandas.core.dtypes.dtypes import (
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/pandas/core/dtypes/dtypes.py", line 24, in <module>
#     from pandas._libs import (
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/pyarrow/__init__.py", line 65, in <module>
#     import pyarrow.lib as _lib
#
# A module that was compiled using NumPy 1.x cannot be run in
# NumPy 2.1.3 as it may crash. To support both 1.x and 2.x
# versions of NumPy, modules must be compiled with NumPy 2.0.
# Some module may need to rebuild instead e.g. with 'pybind11>=2.12'.
#
# If you are a user of the module, the easiest solution will be to
# downgrade to 'numpy<2' or try to upgrade the affected module.
# We expect that some modules will need time to support NumPy 2.
#
# Traceback (most recent call last):  File "/Users/ibtissama/anaconda3/lib/python3.10/runpy.py", line 196, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "/Users/ibtissama/anaconda3/lib/python3.10/runpy.py", line 86, in _run_code
#     exec(code, run_globals)
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/joblib/externals/loky/backend/popen_loky_posix.py", line 180, in <module>
#     exitcode = process_obj._bootstrap()
#   File "/Users/ibtissama/anaconda3/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/Users/ibtissama/anaconda3/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/joblib/externals/loky/process_executor.py", line 426, in _process_worker
#     call_item = call_queue.get(block=True, timeout=timeout)
#   File "/Users/ibtissama/anaconda3/lib/python3.10/multiprocessing/queues.py", line 122, in get
#     return _ForkingPickler.loads(res)
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/sklearn/__init__.py", line 73, in <module>
#     from .base import clone  # noqa: E402
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/sklearn/base.py", line 19, in <module>
#     from .utils._estimator_html_repr import _HTMLDocumentationLinkMixin, estimator_html_repr
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/sklearn/utils/__init__.py", line 15, in <module>
#     from ._chunking import gen_batches, gen_even_slices
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/sklearn/utils/_chunking.py", line 11, in <module>
#     from ._param_validation import Interval, validate_params
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/sklearn/utils/_param_validation.py", line 17, in <module>
#     from .validation import _is_arraylike_not_scalar
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/sklearn/utils/validation.py", line 21, in <module>
#     from ..utils._array_api import _asarray_with_order, _is_numpy_namespace, get_namespace
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/sklearn/utils/_array_api.py", line 17, in <module>
#     from .fixes import parse_version
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/sklearn/utils/fixes.py", line 20, in <module>
#     import pandas as pd
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/pandas/__init__.py", line 49, in <module>
#     from pandas.core.api import (
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/pandas/core/api.py", line 9, in <module>
#     from pandas.core.dtypes.dtypes import (
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/pandas/core/dtypes/dtypes.py", line 24, in <module>
#     from pandas._libs import (
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/pyarrow/__init__.py", line 65, in <module>
#     import pyarrow.lib as _lib
# AttributeErrorAttributeError: : _ARRAY_API not found_ARRAY_API not found
#
# AttributeError: _ARRAY_API not found
#
# A module that was compiled using NumPy 1.x cannot be run in
# NumPy 2.1.3 as it may crash. To support both 1.x and 2.x
# versions of NumPy, modules must be compiled with NumPy 2.0.
# Some module may need to rebuild instead e.g. with 'pybind11>=2.12'.
#
# If you are a user of the module, the easiest solution will be to
# downgrade to 'numpy<2' or try to upgrade the affected module.
# We expect that some modules will need time to support NumPy 2.
#
# Traceback (most recent call last):  File "/Users/ibtissama/anaconda3/lib/python3.10/runpy.py", line 196, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "/Users/ibtissama/anaconda3/lib/python3.10/runpy.py", line 86, in _run_code
#     exec(code, run_globals)
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/joblib/externals/loky/backend/popen_loky_posix.py", line 180, in <module>
#     exitcode = process_obj._bootstrap()
#   File "/Users/ibtissama/anaconda3/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/Users/ibtissama/anaconda3/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/joblib/externals/loky/process_executor.py", line 426, in _process_worker
#     call_item = call_queue.get(block=True, timeout=timeout)
#   File "/Users/ibtissama/anaconda3/lib/python3.10/multiprocessing/queues.py", line 122, in get
#     return _ForkingPickler.loads(res)
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/sklearn/__init__.py", line 73, in <module>
#     from .base import clone  # noqa: E402
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/sklearn/base.py", line 19, in <module>
#     from .utils._estimator_html_repr import _HTMLDocumentationLinkMixin, estimator_html_repr
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/sklearn/utils/__init__.py", line 15, in <module>
#     from ._chunking import gen_batches, gen_even_slices
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/sklearn/utils/_chunking.py", line 11, in <module>
#     from ._param_validation import Interval, validate_params
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/sklearn/utils/_param_validation.py", line 17, in <module>
#     from .validation import _is_arraylike_not_scalar
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/sklearn/utils/validation.py", line 21, in <module>
#     from ..utils._array_api import _asarray_with_order, _is_numpy_namespace, get_namespace
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/sklearn/utils/_array_api.py", line 17, in <module>
#     from .fixes import parse_version
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/sklearn/utils/fixes.py", line 20, in <module>
#     import pandas as pd
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/pandas/__init__.py", line 49, in <module>
#     from pandas.core.api import (
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/pandas/core/api.py", line 9, in <module>
#     from pandas.core.dtypes.dtypes import (
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/pandas/core/dtypes/dtypes.py", line 24, in <module>
#     from pandas._libs import (
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/pyarrow/__init__.py", line 65, in <module>
#     import pyarrow.lib as _lib
# AttributeError: _ARRAY_API not found
#
# A module that was compiled using NumPy 1.x cannot be run in
# NumPy 2.1.3 as it may crash. To support both 1.x and 2.x
# versions of NumPy, modules must be compiled with NumPy 2.0.
# Some module may need to rebuild instead e.g. with 'pybind11>=2.12'.
#
# If you are a user of the module, the easiest solution will be to
# downgrade to 'numpy<2' or try to upgrade the affected module.
# We expect that some modules will need time to support NumPy 2.
#
# Traceback (most recent call last):  File "/Users/ibtissama/anaconda3/lib/python3.10/runpy.py", line 196, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "/Users/ibtissama/anaconda3/lib/python3.10/runpy.py", line 86, in _run_code
#     exec(code, run_globals)
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/joblib/externals/loky/backend/popen_loky_posix.py", line 180, in <module>
#     exitcode = process_obj._bootstrap()
#   File "/Users/ibtissama/anaconda3/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/Users/ibtissama/anaconda3/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/joblib/externals/loky/process_executor.py", line 426, in _process_worker
#     call_item = call_queue.get(block=True, timeout=timeout)
#   File "/Users/ibtissama/anaconda3/lib/python3.10/multiprocessing/queues.py", line 122, in get
#     return _ForkingPickler.loads(res)
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/sklearn/__init__.py", line 73, in <module>
#     from .base import clone  # noqa: E402
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/sklearn/base.py", line 19, in <module>
#     from .utils._estimator_html_repr import _HTMLDocumentationLinkMixin, estimator_html_repr
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/sklearn/utils/__init__.py", line 15, in <module>
#     from ._chunking import gen_batches, gen_even_slices
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/sklearn/utils/_chunking.py", line 11, in <module>
#     from ._param_validation import Interval, validate_params
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/sklearn/utils/_param_validation.py", line 17, in <module>
#     from .validation import _is_arraylike_not_scalar
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/sklearn/utils/validation.py", line 21, in <module>
#     from ..utils._array_api import _asarray_with_order, _is_numpy_namespace, get_namespace
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/sklearn/utils/_array_api.py", line 17, in <module>
#     from .fixes import parse_version
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/sklearn/utils/fixes.py", line 20, in <module>
#     import pandas as pd
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/pandas/__init__.py", line 49, in <module>
#     from pandas.core.api import (
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/pandas/core/api.py", line 9, in <module>
#     from pandas.core.dtypes.dtypes import (
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/pandas/core/dtypes/dtypes.py", line 24, in <module>
#     from pandas._libs import (
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/pyarrow/__init__.py", line 65, in <module>
#     import pyarrow.lib as _lib
# AttributeError: _ARRAY_API not found
#
# A module that was compiled using NumPy 1.x cannot be run in
# NumPy 2.1.3 as it may crash. To support both 1.x and 2.x
# versions of NumPy, modules must be compiled with NumPy 2.0.
# Some module may need to rebuild instead e.g. with 'pybind11>=2.12'.
#
# If you are a user of the module, the easiest solution will be to
# downgrade to 'numpy<2' or try to upgrade the affected module.
# We expect that some modules will need time to support NumPy 2.
#
# Traceback (most recent call last):  File "/Users/ibtissama/anaconda3/lib/python3.10/runpy.py", line 196, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "/Users/ibtissama/anaconda3/lib/python3.10/runpy.py", line 86, in _run_code
#     exec(code, run_globals)
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/joblib/externals/loky/backend/popen_loky_posix.py", line 180, in <module>
#     exitcode = process_obj._bootstrap()
#   File "/Users/ibtissama/anaconda3/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/Users/ibtissama/anaconda3/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/joblib/externals/loky/process_executor.py", line 426, in _process_worker
#     call_item = call_queue.get(block=True, timeout=timeout)
#   File "/Users/ibtissama/anaconda3/lib/python3.10/multiprocessing/queues.py", line 122, in get
#     return _ForkingPickler.loads(res)
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/sklearn/__init__.py", line 73, in <module>
#     from .base import clone  # noqa: E402
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/sklearn/base.py", line 19, in <module>
#     from .utils._estimator_html_repr import _HTMLDocumentationLinkMixin, estimator_html_repr
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/sklearn/utils/__init__.py", line 15, in <module>
#     from ._chunking import gen_batches, gen_even_slices
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/sklearn/utils/_chunking.py", line 11, in <module>
#     from ._param_validation import Interval, validate_params
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/sklearn/utils/_param_validation.py", line 17, in <module>
#     from .validation import _is_arraylike_not_scalar
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/sklearn/utils/validation.py", line 21, in <module>
#     from ..utils._array_api import _asarray_with_order, _is_numpy_namespace, get_namespace
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/sklearn/utils/_array_api.py", line 17, in <module>
#     from .fixes import parse_version
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/sklearn/utils/fixes.py", line 20, in <module>
#     import pandas as pd
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/pandas/__init__.py", line 49, in <module>
#     from pandas.core.api import (
# ...
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/pandas/core/arrays/arrow/__init__.py", line 5, in <module>
#     from pandas.core.arrays.arrow.array import ArrowExtensionArray
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/pandas/core/arrays/arrow/array.py", line 64, in <module>
#     from pandas.core.arrays.masked import BaseMaskedArray
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/pandas/core/arrays/masked.py", line 60, in <module>
#     from pandas.core import (
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/pandas/core/nanops.py", line 52, in <module>
#     bn = import_optional_dependency("bottleneck", errors="warn")
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/pandas/compat/_optional.py", line 135, in import_optional_dependency
#     module = importlib.import_module(name)
#   File "/Users/ibtissama/anaconda3/lib/python3.10/importlib/__init__.py", line 126, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/bottleneck/__init__.py", line 7, in <module>
#     from .move import (move_argmax, move_argmin, move_max, move_mean, move_median,
# AttributeError: _ARRAY_API not found
#
# A module that was compiled using NumPy 1.x cannot be run in
# NumPy 2.1.3 as it may crash. To support both 1.x and 2.x
# versions of NumPy, modules must be compiled with NumPy 2.0.
# Some module may need to rebuild instead e.g. with 'pybind11>=2.12'.
#
# If you are a user of the module, the easiest solution will be to
# downgrade to 'numpy<2' or try to upgrade the affected module.
# We expect that some modules will need time to support NumPy 2.
#
# Traceback (most recent call last):  File "/Users/ibtissama/anaconda3/lib/python3.10/runpy.py", line 196, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "/Users/ibtissama/anaconda3/lib/python3.10/runpy.py", line 86, in _run_code
#     exec(code, run_globals)
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/joblib/externals/loky/backend/popen_loky_posix.py", line 180, in <module>
#     exitcode = process_obj._bootstrap()
#   File "/Users/ibtissama/anaconda3/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/Users/ibtissama/anaconda3/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/joblib/externals/loky/process_executor.py", line 426, in _process_worker
#     call_item = call_queue.get(block=True, timeout=timeout)
#   File "/Users/ibtissama/anaconda3/lib/python3.10/multiprocessing/queues.py", line 122, in get
#     return _ForkingPickler.loads(res)
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/sklearn/__init__.py", line 73, in <module>
#     from .base import clone  # noqa: E402
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/sklearn/base.py", line 19, in <module>
#     from .utils._estimator_html_repr import _HTMLDocumentationLinkMixin, estimator_html_repr
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/sklearn/utils/__init__.py", line 15, in <module>
#     from ._chunking import gen_batches, gen_even_slices
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/sklearn/utils/_chunking.py", line 11, in <module>
#     from ._param_validation import Interval, validate_params
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/sklearn/utils/_param_validation.py", line 17, in <module>
#     from .validation import _is_arraylike_not_scalar
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/sklearn/utils/validation.py", line 21, in <module>
#     from ..utils._array_api import _asarray_with_order, _is_numpy_namespace, get_namespace
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/sklearn/utils/_array_api.py", line 17, in <module>
#     from .fixes import parse_version
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/sklearn/utils/fixes.py", line 20, in <module>
#     import pandas as pd
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/pandas/__init__.py", line 49, in <module>
#     from pandas.core.api import (
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/pandas/core/api.py", line 28, in <module>
#     from pandas.core.arrays import Categorical
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/pandas/core/arrays/__init__.py", line 1, in <module>
#     from pandas.core.arrays.arrow import ArrowExtensionArray
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/pandas/core/arrays/arrow/__init__.py", line 5, in <module>
#     from pandas.core.arrays.arrow.array import ArrowExtensionArray
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/pandas/core/arrays/arrow/array.py", line 64, in <module>
#     from pandas.core.arrays.masked import BaseMaskedArray
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/pandas/core/arrays/masked.py", line 60, in <module>
#     from pandas.core import (
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/pandas/core/nanops.py", line 52, in <module>
#     bn = import_optional_dependency("bottleneck", errors="warn")
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/pandas/compat/_optional.py", line 135, in import_optional_dependency
#     module = importlib.import_module(name)
#   File "/Users/ibtissama/anaconda3/lib/python3.10/importlib/__init__.py", line 126, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/bottleneck/__init__.py", line 7, in <module>
#     from .move import (move_argmax, move_argmin, move_max, move_mean, move_median,
# AttributeError: _ARRAY_API not found
#
# A module that was compiled using NumPy 1.x cannot be run in
# NumPy 2.1.3 as it may crash. To support both 1.x and 2.x
# versions of NumPy, modules must be compiled with NumPy 2.0.
# Some module may need to rebuild instead e.g. with 'pybind11>=2.12'.
#
# If you are a user of the module, the easiest solution will be to
# downgrade to 'numpy<2' or try to upgrade the affected module.
# We expect that some modules will need time to support NumPy 2.
#
# Traceback (most recent call last):  File "/Users/ibtissama/anaconda3/lib/python3.10/runpy.py", line 196, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "/Users/ibtissama/anaconda3/lib/python3.10/runpy.py", line 86, in _run_code
#     exec(code, run_globals)
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/joblib/externals/loky/backend/popen_loky_posix.py", line 180, in <module>
#     exitcode = process_obj._bootstrap()
#   File "/Users/ibtissama/anaconda3/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/Users/ibtissama/anaconda3/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/joblib/externals/loky/process_executor.py", line 426, in _process_worker
#     call_item = call_queue.get(block=True, timeout=timeout)
#   File "/Users/ibtissama/anaconda3/lib/python3.10/multiprocessing/queues.py", line 122, in get
#     return _ForkingPickler.loads(res)
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/sklearn/__init__.py", line 73, in <module>
#     from .base import clone  # noqa: E402
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/sklearn/base.py", line 19, in <module>
#     from .utils._estimator_html_repr import _HTMLDocumentationLinkMixin, estimator_html_repr
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/sklearn/utils/__init__.py", line 15, in <module>
#     from ._chunking import gen_batches, gen_even_slices
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/sklearn/utils/_chunking.py", line 11, in <module>
#     from ._param_validation import Interval, validate_params
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/sklearn/utils/_param_validation.py", line 17, in <module>
#     from .validation import _is_arraylike_not_scalar
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/sklearn/utils/validation.py", line 21, in <module>
#     from ..utils._array_api import _asarray_with_order, _is_numpy_namespace, get_namespace
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/sklearn/utils/_array_api.py", line 17, in <module>
#     from .fixes import parse_version
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/sklearn/utils/fixes.py", line 20, in <module>
#     import pandas as pd
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/pandas/__init__.py", line 49, in <module>
#     from pandas.core.api import (
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/pandas/core/api.py", line 28, in <module>
#     from pandas.core.arrays import Categorical
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/pandas/core/arrays/__init__.py", line 1, in <module>
#     from pandas.core.arrays.arrow import ArrowExtensionArray
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/pandas/core/arrays/arrow/__init__.py", line 5, in <module>
#     from pandas.core.arrays.arrow.array import ArrowExtensionArray
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/pandas/core/arrays/arrow/array.py", line 64, in <module>
#     from pandas.core.arrays.masked import BaseMaskedArray
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/pandas/core/arrays/masked.py", line 60, in <module>
#     from pandas.core import (
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/pandas/core/nanops.py", line 52, in <module>
#     bn = import_optional_dependency("bottleneck", errors="warn")
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/pandas/compat/_optional.py", line 135, in import_optional_dependency
#     module = importlib.import_module(name)
#   File "/Users/ibtissama/anaconda3/lib/python3.10/importlib/__init__.py", line 126, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/bottleneck/__init__.py", line 7, in <module>
#     from .move import (move_argmax, move_argmin, move_max, move_mean, move_median,
# AttributeError: _ARRAY_API not found
#
#
# A module that was compiled using NumPy 1.x cannot be run in
# NumPy 2.1.3 as it may crash. To support both 1.x and 2.x
# versions of NumPy, modules must be compiled with NumPy 2.0.
# Some module may need to rebuild instead e.g. with 'pybind11>=2.12'.
#
# If you are a user of the module, the easiest solution will be to
# downgrade to 'numpy<2' or try to upgrade the affected module.
# We expect that some modules will need time to support NumPy 2.
#
# Traceback (most recent call last):  File "/Users/ibtissama/anaconda3/lib/python3.10/runpy.py", line 196, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "/Users/ibtissama/anaconda3/lib/python3.10/runpy.py", line 86, in _run_code
#     exec(code, run_globals)
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/joblib/externals/loky/backend/popen_loky_posix.py", line 180, in <module>
#     exitcode = process_obj._bootstrap()
#   File "/Users/ibtissama/anaconda3/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/Users/ibtissama/anaconda3/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/joblib/externals/loky/process_executor.py", line 426, in _process_worker
#     call_item = call_queue.get(block=True, timeout=timeout)
#   File "/Users/ibtissama/anaconda3/lib/python3.10/multiprocessing/queues.py", line 122, in get
#     return _ForkingPickler.loads(res)
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/sklearn/__init__.py", line 73, in <module>
#     from .base import clone  # noqa: E402
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/sklearn/base.py", line 19, in <module>
#     from .utils._estimator_html_repr import _HTMLDocumentationLinkMixin, estimator_html_repr
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/sklearn/utils/__init__.py", line 15, in <module>
#     from ._chunking import gen_batches, gen_even_slices
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/sklearn/utils/_chunking.py", line 11, in <module>
#     from ._param_validation import Interval, validate_params
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/sklearn/utils/_param_validation.py", line 17, in <module>
#     from .validation import _is_arraylike_not_scalar
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/sklearn/utils/validation.py", line 21, in <module>
#     from ..utils._array_api import _asarray_with_order, _is_numpy_namespace, get_namespace
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/sklearn/utils/_array_api.py", line 17, in <module>
#     from .fixes import parse_version
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/sklearn/utils/fixes.py", line 20, in <module>
#     import pandas as pd
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/pandas/__init__.py", line 49, in <module>
#     from pandas.core.api import (
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/pandas/core/api.py", line 28, in <module>
#     from pandas.core.arrays import Categorical
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/pandas/core/arrays/__init__.py", line 1, in <module>
#     from pandas.core.arrays.arrow import ArrowExtensionArray
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/pandas/core/arrays/arrow/__init__.py", line 5, in <module>
#     from pandas.core.arrays.arrow.array import ArrowExtensionArray
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/pandas/core/arrays/arrow/array.py", line 64, in <module>
#     from pandas.core.arrays.masked import BaseMaskedArray
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/pandas/core/arrays/masked.py", line 60, in <module>
#     from pandas.core import (
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/pandas/core/nanops.py", line 52, in <module>
#     bn = import_optional_dependency("bottleneck", errors="warn")
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/pandas/compat/_optional.py", line 135, in import_optional_dependency
#     module = importlib.import_module(name)
#   File "/Users/ibtissama/anaconda3/lib/python3.10/importlib/__init__.py", line 126, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/bottleneck/__init__.py", line 7, in <module>
#     from .move import (move_argmax, move_argmin, move_max, move_mean, move_median,
# AttributeError: _ARRAY_API not found
# Fitting 5 folds for each of 324 candidates, totalling 1620 fits
# Fitting 5 folds for each of 324 candidates, totalling 1620 fits
# Fitting 5 folds for each of 324 candidates, totalling 1620 fits
# Fitting 5 folds for each of 324 candidates, totalling 1620 fits
#
# 📊 Average Confusion Matrix:
# [[615. 209.]
#  [254. 570.]]
#
# 🎯 Performance Metrics:
# 🔹 Precision (Class 1 - Long Career Players): 0.7309
# 🔹 Recall (Class 1 - Majority): 0.6918
# 🔹 F1-score (Class 1 - Long Career Players): 0.7102
# 🔹 Precision (Class 0 - Short Career Players): 0.7095
# 🔹 Recall (Class 0 - Minority): 0.7464
# 🔹 F1-score (Class 0 - Short Career Players): 0.7270
#
# 📜 Full Classification Report (average over folds):
#               precision    recall  f1-score   support
#
#          0.0       0.71      0.75      0.73       824
#          1.0       0.73      0.69      0.71       824
#
#     accuracy                           0.72      1648
#    macro avg       0.72      0.72      0.72      1648
# weighted avg       0.72      0.72      0.72      1648

# %% [markdown]
# Nous avons ensuite appliqué une optimisation avec GridSearchCV, permettant de tester plusieurs combinaisons d’hyperparamètres et d’améliorer la capacité du modèle à différencier les deux classes.
#
# ✅ F1-score Classe 1 (Longue carrière) :0.7102
#
# ✅ F1-score Classe 0 (Courte carrière) : 0.7270
#
# ✅ Accuracy globale : 0.72(+4 points)
#
# 🔍 Analyse :
#
# Amélioration notable du recall de la classe 0 (0.7464 vs 0.6428 en V1) → Le modèle identifie mieux les joueurs ayant une courte carrière, ce qui réduit les faux positifs (éviter de classer un joueur à faible potentiel comme une future star).
#
# Équilibre entre précision et recall → La précision pour les deux classes augmente, passant de 0.5768 à 0.7095 pour la classe 0, ce qui montre une meilleure capacité du modèle à ne pas confondre les joueurs des deux catégories.
# Le recall de la classe 1 baisse légèrement (0.6918 vs 0.7099 en V1), mais reste stable et permet toujours d’identifier correctement les talents prometteurs.

# %%
# Version 3 - Optimisation avec Optuna
brf = BalancedRandomForestClassifier(random_state=42)
brf_model = score_classifier_with_optuna(over_X, brf, over_y, 50, cv=5, use_stratified=True)
brf_model
# Out:
# [I 2025-03-06 16:40:58,769] A new study created in memory with name: no-name-279a25d1-0f80-4752-9a56-ef78d8492549
# [I 2025-03-06 16:41:02,954] Trial 0 finished with value: 0.7168198721680967 and parameters: {'n_estimators': 200, 'max_depth': 10, 'min_samples_split': 19, 'min_samples_leaf': 1, 'max_features': 'log2'}. Best is trial 0 with value: 0.7168198721680967.
# [I 2025-03-06 16:41:47,574] Trial 1 finished with value: 0.7125850349150689 and parameters: {'n_estimators': 900, 'max_depth': None, 'min_samples_split': 5, 'min_samples_leaf': 8, 'max_features': None}. Best is trial 0 with value: 0.7168198721680967.
# [I 2025-03-06 16:42:18,589] Trial 2 finished with value: 0.6891094670636922 and parameters: {'n_estimators': 900, 'max_depth': 5, 'min_samples_split': 19, 'min_samples_leaf': 5, 'max_features': None}. Best is trial 0 with value: 0.7168198721680967.
# [I 2025-03-06 16:42:25,627] Trial 3 finished with value: 0.7165092354322209 and parameters: {'n_estimators': 400, 'max_depth': None, 'min_samples_split': 5, 'min_samples_leaf': 10, 'max_features': 'sqrt'}. Best is trial 0 with value: 0.7168198721680967.
# [I 2025-03-06 16:42:38,391] Trial 4 finished with value: 0.6981942940492001 and parameters: {'n_estimators': 1000, 'max_depth': 5, 'min_samples_split': 10, 'min_samples_leaf': 5, 'max_features': 'log2'}. Best is trial 0 with value: 0.7168198721680967.
# [I 2025-03-06 16:42:50,287] Trial 5 finished with value: 0.7208995211731709 and parameters: {'n_estimators': 700, 'max_depth': 15, 'min_samples_split': 6, 'min_samples_leaf': 7, 'max_features': 'log2'}. Best is trial 5 with value: 0.7208995211731709.
# [I 2025-03-06 16
 'max_depth': None, 'min_samples_split': 13, 'min_samples_leaf': 2, 'max_features': None}. Best is trial 5 with value: 0.7208995211731709.
# [I 2025-03-06 16:59:34,913] Trial 37 finished with value: 0.714463247366566 and parameters: {'n_estimators': 1000, 'max_depth': None, 'min_samples_split': 4, 'min_samples_leaf': 6, 'max_features': None}. Best is trial 5 with value: 0.7208995211731709.
# [I 2025-03-06 16:59:55,191] Trial 38 finished with value: 0.7141736495124811 and parameters: {'n_estimators': 400, 'max_depth': None, 'min_samples_split': 10, 'min_samples_leaf': 9, 'max_features': None}. Best is trial 5 with value: 0.7208995211731709.
# [I 2025-03-06 17:00:31,733] Trial 39 finished with value: 0.7144118960573277 and parameters: {'n_estimators': 600, 'max_depth': None, 'min_samples_split': 7, 'min_samples_leaf': 2, 'max_features': None}. Best is trial 5 with value: 0.7208995211731709.
# [I 2025-03-06 17:01:27,663] Trial 40 finished with value: 0.7129479652470878 and parameters: {'n_estimators': 1000, 'max_depth': None, 'min_samples_split': 5, 'min_samples_leaf': 5, 'max_features': None}. Best is trial 5 with value: 0.7208995211731709.
# [I 2025-03-06 17:02:19,164] Trial 41 finished with value: 0.7131963693264073 and parameters: {'n_estimators': 900, 'max_depth': None, 'min_samples_split': 13, 'min_samples_leaf': 2, 'max_features': None}. Best is trial 5 with value: 0.7208995211731709.
# [I 2025-03-06 17:03:18,754] Trial 42 finished with value: 0.7153183016144861 and parameters: {'n_estimators': 1000, 'max_depth': None, 'min_samples_split': 13, 'min_samples_leaf': 1, 'max_features': None}. Best is trial 5 with value: 0.7208995211731709.
# [I 2025-03-06 17:04:03,903] Trial 43 finished with value: 0.7149205495021483 and parameters: {'n_estimators': 800, 'max_depth': None, 'min_samples_split': 15, 'min_samples_leaf': 3, 'max_features': None}. Best is trial 5 with value: 0.7208995211731709.
# [I 2025-03-06 17:04:50,446] Trial 44 finished with value: 0.7124727060707572 and parameters: {'n_estimators': 900, 'max_depth': None, 'min_samples_split': 18, 'min_samples_leaf': 7, 'max_features': None}. Best is trial 5 with value: 0.7208995211731709.
# [I 2025-03-06 17:05:45,692] Trial 45 finished with value: 0.7133919443290888 and parameters: {'n_estimators': 900, 'max_depth': None, 'min_samples_split': 11, 'min_samples_leaf': 2, 'max_features': None}. Best is trial 5 with value: 0.7208995211731709.
# [I 2025-03-06 17:06:31,606] Trial 46 finished with value: 0.7162149321520305 and parameters: {'n_estimators': 700, 'max_depth': None, 'min_samples_split': 9, 'min_samples_leaf': 1, 'max_features': None}. Best is trial 5 with value: 0.7208995211731709.
# [I 2025-03-06 17:07:05,369] Trial 47 finished with value: 0.7104513924772344 and parameters: {'n_estimators': 600, 'max_depth': None, 'min_samples_split': 13, 'min_samples_leaf': 8, 'max_features': None}. Best is trial 5 with value: 0.7208995211731709.
# [I 2025-03-06 17:07:30,273] Trial 48 finished with value: 0.7120021861742235 and parameters: {'n_estimators': 500, 'max_depth': None, 'min_samples_split': 15, 'min_samples_leaf': 10, 'max_features': None}. Best is trial 5 with value: 0.7208995211731709.
# [I 2025-03-06 17:08:22,302] Trial 49 finished with value: 0.7117143992207412 and parameters: {'n_estimators': 1000, 'max_depth': None, 'min_samples_split': 16, 'min_samples_leaf': 7, 'max_features': None}. Best is trial 5 with value: 0.7208995211731709.
# ✅ Best Hyperparameters Found: {'n_estimators': 700, 'max_depth': 15, 'min_samples_split': 6, 'min_samples_leaf': 7, 'max_features': 'log2'}
#
# 📊 Average Confusion Matrix:
# [[617. 207.]
#  [242. 582.]]
#
# 🎯 Performance Metrics:
# 🔹 Precision (Class 1 - Long Career Players): 0.7369
# 🔹 Recall (Class 1 - Majority): 0.7063
# 🔹 F1-score (Class 1 - Long Career Players): 0.7209
# 🔹 Precision (Class 0 - Short Career Players): 0.7198
# 🔹 Recall (Class 0 - Minority): 0.7488
# 🔹 F1-score (Class 0 - Short Career Players): 0.7336
#
# 📜 Full Classification Report:
#               precision    recall  f1-score   support
#
#          0.0       0.72      0.75      0.73       824
#          1.0       0.74      0.71      0.72       824
#
#     accuracy                           0.73      1648
#    macro avg       0.73      0.73      0.73      1648
# weighted avg       0.73      0.73      0.73      1648
# BalancedRandomForestClassifier(max_depth=15, max_features='log2',
#                                min_samples_leaf=7, min_samples_split=6,
#                                n_estimators=700, random_state=42)

# %% [markdown]
# L’optimisation via Optuna permet une exploration plus fine et adaptative des hyperparamètres, améliorant la classification globale.
#
# ✅ F1-score Classe 1 (Longue carrière) : 0.7209
#
# ✅ F1-score Classe 0 (Courte carrière) : 0.7336
#
# ✅ Accuracy globale : 0.73  (+5 points)
#
# 🔍 Analyse :
#
# Hausse du recall pour la classe 1 (0.7063 vs 0.6918 en V2) → Le modèle détecte encore mieux les joueurs qui auront une carrière longue.
# Précision plus stable pour la classe 0 (0.7198) → Moins de faux positifs, ce qui signifie que le modèle réduit les erreurs d’investissement sur des joueurs qui ne performeront pas.
# Recall de la classe 0 atteint  0.7488 → Le modèle identifie encore mieux les joueurs avec une carrière courte, renforçant la prise de décision des investisseurs NBA.
# Équilibre parfait entre recall et précision, ce qui permet d’avoir un modèle robuste et fiable.

# %% [markdown]
# 👉 *Le modèle final (Version 3 - Optuna) est plus performant que les versions précédentes, offrant une meilleure capacité de prédiction pour identifier les joueurs ayant une longue carrière NBA.*

# %% [markdown]
# #####  5.3 XGBoost (XGB)

# %%
# Version 1 - KFold Stratifié

# Initialize XGBoost classifier with class weighting
xgb_clf = xgb.XGBClassifier(
    objective='binary:logistic',
    random_state=42,
    eval_metric="logloss",
    tree_method="hist"
)

# Call the scoring function with the updated XGBoost classifier
score_classifier(over_X, xgb_clf, over_y,"stratified")
# Out:
# 📊 Confusion Matrix:
# [[604. 220.]
#  [238. 586.]]
#
# 🎯 Performance Metrics:
# 🔹 Precision: Class 1 (Long Career Players): 0.7279
# 🔹 Recall: Class 1 (Long Career Players): 0.7112
# 🔹 F1-score: Class 1 (Long Career Players): 0.7186
# 🔹 Precision: Class 0 (Short Career Players): 0.7183
# 🔹 Recall: Class 0 (Short Career Players): 0.7329
# 🔹 F1-score: Class 0 (Short Career Players): 0.7248
#
# 📌 Full Classification Report (Averaged Over 5 Folds):
#               precision    recall  f1-score   support
#
#          0.0       0.72      0.73      0.73       824
#          1.0       0.73      0.71      0.72       824
#
#     accuracy                           0.72      1648
#    macro avg       0.72      0.72      0.72      1648
# weighted avg       0.72      0.72      0.72      1648

# %% [markdown]
# ✅ F1-score Classe 1 (Longue carrière) : 0.7186
#
# ✅ F1-score Classe 0 (Courte carrière) : 0.7248
#
# ✅ Accuracy globale : 0.72
#
# 🔍 Analyse :
#
# Le modèle montre une bonne précision générale et une balance entre les classes.
# La précision de la classe 1 (0.7279) est correcte.
# La classe 0 est également bien prise en compte avec un recall de 0.7329.

# %%
# Version 2 - Optimisation GridSearchCV


xgb_clf = xgb.XGBClassifier(
    objective='binary:logistic',  
    random_state=42,
    eval_metric="logloss",  
    use_label_encoder=False,
    tree_method="hist"  
)


# Define parameter grid for tuning
param_grid_xgb = {
    'n_estimators': [100, 300, 1000],  # Number of trees
    'max_depth': [3, 5, 7],  # Tree depth
    'learning_rate': [0.01, 0.1, 0.2],  # Step size shrinkage
    'subsample': [0.7, 0.9],  # Fraction of samples used per tree
    'colsample_bytree': [0.7, 0.9],  # Fraction of features used per tree
}


score_classifier_with_tuning(over_X, xgb_clf, over_y, param_grid_xgb,5,"stratified")
# Out:
# Fitting 5 folds for each of 108 candidates, totalling 540 fits
# A module that was compiled using NumPy 1.x cannot be run in
# NumPy 2.1.3 as it may crash. To support both 1.x and 2.x
# versions of NumPy, modules must be compiled with NumPy 2.0.
# Some module may need to rebuild instead e.g. with 'pybind11>=2.12'.
#
# If you are a user of the module, the easiest solution will be to
# downgrade to 'numpy<2' or try to upgrade the affected module.
# We expect that some modules will need time to support NumPy 2.
#
# Traceback (most recent call last):  File "/Users/ibtissama/anaconda3/lib/python3.10/runpy.py", line 196, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "/Users/ibtissama/anaconda3/lib/python3.10/runpy.py", line 86, in _run_code
#     exec(code, run_globals)
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/joblib/externals/loky/backend/popen_loky_posix.py", line 180, in <module>
#     exitcode = process_obj._bootstrap()
#   File "/Users/ibtissama/anaconda3/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/Users/ibtissama/anaconda3/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/joblib/externals/loky/process_executor.py", line 426, in _process_worker
#     call_item = call_queue.get(block=True, timeout=timeout)
#   File "/Users/ibtissama/anaconda3/lib/python3.10/multiprocessing/queues.py", line 122, in get
#     return _ForkingPickler.loads(res)
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/sklearn/__init__.py", line 73, in <module>
#     from .base import clone  # noqa: E402
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/sklearn/base.py", line 19, in <module>
#     from .utils._estimator_html_repr import _HTMLDocumentationLinkMixin, estimator_html_repr
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/sklearn/utils/__init__.py", line 15, in <module>
#     from ._chunking import gen_batches, gen_even_slices
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/sklearn/utils/_chunking.py", line 11, in <module>
#     from ._param_validation import Interval, validate_params
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/sklearn/utils/_param_validation.py", line 17, in <module>
#     from .validation import _is_arraylike_not_scalar
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/sklearn/utils/validation.py", line 21, in <module>
#     from ..utils._array_api import _asarray_with_order, _is_numpy_namespace, get_namespace
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/sklearn/utils/_array_api.py", line 17, in <module>
#     from .fixes import parse_version
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/sklearn/utils/fixes.py", line 20, in <module>
#     import pandas as pd
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/pandas/__init__.py", line 26, in <module>
#     from pandas.compat import (
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/pandas/compat/__init__.py", line 27, in <module>
#     from pandas.compat.pyarrow import (
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/pandas/compat/pyarrow.py", line 8, in <module>
#     import pyarrow as pa
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/pyarrow/__init__.py", line 65, in <module>
#     import pyarrow.lib as _lib
#
# A module that was compiled using NumPy 1.x cannot be run in
# NumPy 2.1.3 as it may crash. To support both 1.x and 2.x
# versions of NumPy, modules must be compiled with NumPy 2.0.
# Some module may need to rebuild instead e.g. with 'pybind11>=2.12'.
#
# If you are a user of the module, the easiest solution will be to
# downgrade to 'numpy<2' or try to upgrade the affected module.
# We expect that some modules will need time to support NumPy 2.
#
# Traceback (most recent call last):  File "/Users/ibtissama/anaconda3/lib/python3.10/runpy.py", line 196, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "/Users/ibtissama/anaconda3/lib/python3.10/runpy.py", line 86, in _run_code
#     exec(code, run_globals)
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/joblib/externals/loky/backend/popen_loky_posix.py", line 180, in <module>
#     exitcode = process_obj._bootstrap()
#   File "/Users/ibtissama/anaconda3/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/Users/ibtissama/anaconda3/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/joblib/externals/loky/process_executor.py", line 426, in _process_worker
#     call_item = call_queue.get(block=True, timeout=timeout)
#   File "/Users/ibtissama/anaconda3/lib/python3.10/multiprocessing/queues.py", line 122, in get
#     return _ForkingPickler.loads(res)
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/sklearn/__init__.py", line 73, in <module>
#     from .base import clone  # noqa: E402
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/sklearn/base.py", line 19, in <module>
#     from .utils._estimator_html_repr import _HTMLDocumentationLinkMixin, estimator_html_repr
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/sklearn/utils/__init__.py", line 15, in <module>
#     from ._chunking import gen_batches, gen_even_slices
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/sklearn/utils/_chunking.py", line 11, in <module>
#     from ._param_validation import Interval, validate_params
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/sklearn/utils/_param_validation.py", line 17, in <module>
#     from .validation import _is_arraylike_not_scalar
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/sklearn/utils/validation.py", line 21, in <module>
#     from ..utils._array_api import _asarray_with_order, _is_numpy_namespace, get_namespace
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/sklearn/utils/_array_api.py", line 17, in <module>
#     from .fixes import parse_version
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/sklearn/utils/fixes.py", line 20, in <module>
#     import pandas as pd
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/pandas/__init__.py", line 26, in <module>
#     from pandas.compat import (
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/pandas/compat/__init__.py", line 27, in <module>
#     from pandas.compat.pyarrow import (
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/pandas/compat/pyarrow.py", line 8, in <module>
#     import pyarrow as pa
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/pyarrow/__init__.py", line 65, in <module>
#     import pyarrow.lib as _lib
#
# A module that was compiled using NumPy 1.x cannot be run in
# NumPy 2.1.3 as it may crash. To support both 1.x and 2.x
# versions of NumPy, modules must be compiled with NumPy 2.0.
# Some module may need to rebuild instead e.g. with 'pybind11>=2.12'.
#
# If you are a user of the module, the easiest solution will be to
# downgrade to 'numpy<2' or try to upgrade the affected module.
# We expect that some modules will need time to support NumPy 2.
#
# Traceback (most recent call last):  File "/Users/ibtissama/anaconda3/lib/python3.10/runpy.py", line 196, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "/Users/ibtissama/anaconda3/lib/python3.10/runpy.py", line 86, in _run_code
#     exec(code, run_globals)
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/joblib/externals/loky/backend/popen_loky_posix.py", line 180, in <module>
#     exitcode = process_obj._bootstrap()
#   File "/Users/ibtissama/anaconda3/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/Users/ibtissama/anaconda3/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/joblib/externals/loky/process_executor.py", line 426, in _process_worker
#     call_item = call_queue.get(block=True, timeout=timeout)
#   File "/Users/ibtissama/anaconda3/lib/python3.10/multiprocessing/queues.py", line 122, in get
#     return _ForkingPickler.loads(res)
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/sklearn/__init__.py", line 73, in <module>
#     from .base import clone  # noqa: E402
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/sklearn/base.py", line 19, in <module>
#     from .utils._estimator_html_repr import _HTMLDocumentationLinkMixin, estimator_html_repr
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/sklearn/utils/__init__.py", line 15, in <module>
#     from ._chunking import gen_batches, gen_even_slices
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/sklearn/utils/_chunking.py", line 11, in <module>
#     from ._param_validation import Interval, validate_params
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/sklearn/utils/_param_validation.py", line 17, in <module>
#     from .validation import _is_arraylike_not_scalar
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/sklearn/utils/validation.py", line 21, in <module>
#     from ..utils._array_api import _asarray_with_order, _is_numpy_namespace, get_namespace
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/sklearn/utils/_array_api.py", line 17, in <module>
#     from .fixes import parse_version
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/sklearn/utils/fixes.py", line 20, in <module>
#     import pandas as pd
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/pandas/__init__.py", line 26, in <module>
#     from pandas.compat import (
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/pandas/compat/__init__.py", line 27, in <module>
#     from pandas.compat.pyarrow import (
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/pandas/compat/pyarrow.py", line 8, in <module>
#     import pyarrow as pa
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/pyarrow/__init__.py", line 65, in <module>
#     import pyarrow.lib as _lib
#
# A module that was compiled using NumPy 1.x cannot be run in
# NumPy 2.1.3 as it may crash. To support both 1.x and 2.x
# versions of NumPy, modules must be compiled with NumPy 2.0.
# Some module may need to rebuild instead e.g. with 'pybind11>=2.12'.
#
# If you are a user of the module, the easiest solution will be to
# downgrade to 'numpy<2' or try to upgrade the affected module.
# We expect that some modules will need time to support NumPy 2.
#
# Traceback (most recent call last):  File "/Users/ibtissama/anaconda3/lib/python3.10/runpy.py", line 196, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "/Users/ibtissama/anaconda3/lib/python3.10/runpy.py", line 86, in _run_code
#     exec(code, run_globals)
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/joblib/externals/loky/backend/popen_loky_posix.py", line 180, in <module>
#     exitcode = process_obj._bootstrap()
#   File "/Users/ibtissama/anaconda3/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/Users/ibtissama/anaconda3/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/joblib/externals/loky/process_executor.py", line 426, in _process_worker
#     call_item = call_queue.get(block=True, timeout=timeout)
#   File "/Users/ibtissama/anaconda3/lib/python3.10/multiprocessing/queues.py", line 122, in get
#     return _ForkingPickler.loads(res)
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/sklearn/__init__.py", line 73, in <module>
#     from .base import clone  # noqa: E402
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/sklearn/base.py", line 19, in <module>
#     from .utils._estimator_html_repr import _HTMLDocumentationLinkMixin, estimator_html_repr
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/sklearn/utils/__init__.py", line 15, in <module>
#     from ._chunking import gen_batches, gen_even_slices
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/sklearn/utils/_chunking.py", line 11, in <module>
#     from ._param_validation import Interval, validate_params
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/sklearn/utils/_param_validation.py", line 17, in <module>
#     from .validation import _is_arraylike_not_scalar
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/sklearn/utils/validation.py", line 21, in <module>
#     from ..utils._array_api import _asarray_with_order, _is_numpy_namespace, get_namespace
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/sklearn/utils/_array_api.py", line 17, in <module>
#     from .fixes import parse_version
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/sklearn/utils/fixes.py", line 20, in <module>
#     import pandas as pd
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/pandas/__init__.py", line 26, in <module>
#     from pandas.compat import (
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/pandas/compat/__init__.py", line 27, in <module>
#     from pandas.compat.pyarrow import (
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/pandas/compat/pyarrow.py", line 8, in <module>
#     import pyarrow as pa
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/pyarrow/__init__.py", line 65, in <module>
#     import pyarrow.lib as _lib
#
# A module that was compiled using NumPy 1.x cannot be run in
# NumPy 2.1.3 as it may crash. To support both 1.x and 2.x
# versions of NumPy, modules must be compiled with NumPy 2.0.
# Some module may need to rebuild instead e.g. with 'pybind11>=2.12'.
#
# If you are a user of the module, the easiest solution will be to
# downgrade to 'numpy<2' or try to upgrade the affected module.
# We expect that some modules will need time to support NumPy 2.
#
# Traceback (most recent call last):  File "/Users/ibtissama/anaconda3/lib/python3.10/runpy.py", line 196, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "/Users/ibtissama/anaconda3/lib/python3.10/runpy.py", line 86, in _run_code
#     exec(code, run_globals)
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/joblib/externals/loky/backend/popen_loky_posix.py", line 180, in <module>
#     exitcode = process_obj._bootstrap()
#   File "/Users/ibtissama/anaconda3/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/Users/ibtissama/anaconda3/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/joblib/externals/loky/process_executor.py", line 426, in _process_worker
#     call_item = call_queue.get(block=True, timeout=timeout)
#   File "/Users/ibtissama/anaconda3/lib/python3.10/multiprocessing/queues.py", line 122, in get
#     return _ForkingPickler.loads(res)
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/sklearn/__init__.py", line 73, in <module>
#     from .base import clone  # noqa: E402
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/sklearn/base.py", line 19, in <module>
#     from .utils._estimator_html_repr import _HTMLDocumentationLinkMixin, estimator_html_repr
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/sklearn/utils/__init__.py", line 15, in <module>
#     from ._chunking import gen_batches, gen_even_slices
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/sklearn/utils/_chunking.py", line 11, in <module>
#     from ._param_validation import Interval, validate_params
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/sklearn/utils/_param_validation.py", line 17, in <module>
#     from .validation import _is_arraylike_not_scalar
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/sklearn/utils/validation.py", line 21, in <module>
#     from ..utils._array_api import _asarray_with_order, _is_numpy_namespace, get_namespace
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/sklearn/utils/_array_api.py", line 17, in <module>
#     from .fixes import parse_version
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/sklearn/utils/fixes.py", line 20, in <module>
#     import pandas as pd
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/pandas/__init__.py", line 26, in <module>
#     from pandas.compat import (
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/pandas/compat/__init__.py", line 27, in <module>
#     from pandas.compat.pyarrow import (
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/pandas/compat/pyarrow.py", line 8, in <module>
#     import pyarrow as pa
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/pyarrow/__init__.py", line 65, in <module>
#     import pyarrow.lib as _lib
#
# A module that was compiled using NumPy 1.x cannot be run in
# NumPy 2.1.3 as it may crash. To support both 1.x and 2.x
# versions of NumPy, modules must be compiled with NumPy 2.0.
# Some module may need to rebuild instead e.g. with 'pybind11>=2.12'.
#
# If you are a user of the module, the easiest solution will be to
# downgrade to 'numpy<2' or try to upgrade the affected module.
# We expect that some modules will need time to support NumPy 2.
#
# Traceback (most recent call last):  File "/Users/ibtissama/anaconda3/lib/python3.10/runpy.py", line 196, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "/Users/ibtissama/anaconda3/lib/python3.10/runpy.py", line 86, in _run_code
#     exec(code, run_globals)
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/joblib/externals/loky/backend/popen_loky_posix.py", line 180, in <module>
#     exitcode = process_obj._bootstrap()
#   File "/Users/ibtissama/anaconda3/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/Users/ibtissama/anaconda3/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/joblib/externals/loky/process_executor.py", line 426, in _process_worker
#     call_item = call_queue.get(block=True, timeout=timeout)
#   File "/Users/ibtissama/anaconda3/lib/python3.10/multiprocessing/queues.py", line 122, in get
#     return _ForkingPickler.loads(res)
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/sklearn/__init__.py", line 73, in <module>
#     from .base import clone  # noqa: E402
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/sklearn/base.py", line 19, in <module>
#     from .utils._estimator_html_repr import _HTMLDocumentationLinkMixin, estimator_html_repr
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/sklearn/utils/__init__.py", line 15, in <module>
#     from ._chunking import gen_batches, gen_even_slices
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/sklearn/utils/_chunking.py", line 11, in <module>
#     from ._param_validation import Interval, validate_params
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/sklearn/utils/_param_validation.py", line 17, in <module>
#     from .validation import _is_arraylike_not_scalar
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/sklearn/utils/validation.py", line 21, in <module>
#     from ..utils._array_api import _asarray_with_order, _is_numpy_namespace, get_namespace
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/sklearn/utils/_array_api.py", line 17, in <module>
#     from .fixes import parse_version
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/sklearn/utils/fixes.py", line 20, in <module>
#     import pandas as pd
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/pandas/__init__.py", line 26, in <module>
#     from pandas.compat import (
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/pandas/compat/__init__.py", line 27, in <module>
#     from pandas.compat.pyarrow import (
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/pandas/compat/pyarrow.py", line 8, in <module>
#     import pyarrow as pa
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/pyarrow/__init__.py", line 65, in <module>
#     import pyarrow.lib as _lib
# AttributeError: _ARRAY_API not found
# AttributeError: _ARRAY_API not found
# AttributeError: _ARRAY_API not found
# AttributeError: _ARRAY_API not found
# AttributeError: _ARRAY_API not found
# AttributeError: _ARRAY_API not found
#
# A module that was compiled using NumPy 1.x cannot be run in
# NumPy 2.1.3 as it may crash. To support both 1.x and 2.x
# versions of NumPy, modules must be compiled with NumPy 2.0.
# Some module may need to rebuild instead e.g. with 'pybind11>=2.12'.
#
# If you are a user of the module, the easiest solution will be to
# downgrade to 'numpy<2' or try to upgrade the affected module.
# We expect that some modules will need time to support NumPy 2.
#
# Traceback (most recent call last):  File "/Users/ibtissama/anaconda3/lib/python3.10/runpy.py", line 196, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "/Users/ibtissama/anaconda3/lib/python3.10/runpy.py", line 86, in _run_code
#     exec(code, run_globals)
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/joblib/externals/loky/backend/popen_loky_posix.py", line 180, in <module>
#     exitcode = process_obj._bootstrap()
#   File "/Users/ibtissama/anaconda3/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/Users/ibtissama/anaconda3/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/joblib/externals/loky/process_executor.py", line 426, in _process_worker
#     call_item = call_queue.get(block=True, timeout=timeout)
#   File "/Users/ibtissama/anaconda3/lib/python3.10/multiprocessing/queues.py", line 122, in get
#     return _ForkingPickler.loads(res)
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/sklearn/__init__.py", line 73, in <module>
#     from .base import clone  # noqa: E402
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/sklearn/base.py", line 19, in <module>
#     from .utils._estimator_html_repr import _HTMLDocumentationLinkMixin, estimator_html_repr
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/sklearn/utils/__init__.py", line 15, in <module>
#     from ._chunking import gen_batches, gen_even_slices
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/sklearn/utils/_chunking.py", line 11, in <module>
#     from ._param_validation import Interval, validate_params
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/sklearn/utils/_param_validation.py", line 17, in <module>
#     from .validation import _is_arraylike_not_scalar
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/sklearn/utils/validation.py", line 21, in <module>
#     from ..utils._array_api import _asarray_with_order, _is_numpy_namespace, get_namespace
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/sklearn/utils/_array_api.py", line 17, in <module>
#     from .fixes import parse_version
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/sklearn/utils/fixes.py", line 20, in <module>
#     import pandas as pd
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/pandas/__init__.py", line 26, in <module>
#     from pandas.compat import (
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/pandas/compat/__init__.py", line 27, in <module>
#     from pandas.compat.pyarrow import (
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/pandas/compat/pyarrow.py", line 8, in <module>
#     import pyarrow as pa
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/pyarrow/__init__.py", line 65, in <module>
#     import pyarrow.lib as _lib
# AttributeError
# A module that was compiled using NumPy 1.x cannot be run in
# NumPy 2.1.3 as it may crash. To support both 1.x and 2.x
# versions of NumPy, modules must be compiled with NumPy 2.0.
# Some module may need to rebuild instead e.g. with 'pybind11>=2.12'.
#
# If you are a user of the module, the easiest solution will be to
# downgrade to 'numpy<2' or try to upgrade the affected module.
# We expect that some modules will need time to support NumPy 2.
#
# Traceback (most recent call last):  File "/Users/ibtissama/anaconda3/lib/python3.10/runpy.py", line 196, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "/Users/ibtissama/anaconda3/lib/python3.10/runpy.py", line 86, in _run_code
#     exec(code, run_globals)
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/joblib/externals/loky/backend/popen_loky_posix.py", line 180, in <module>
#     exitcode = process_obj._bootstrap()
#   File "/Users/ibtissama/anaconda3/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/Users/ibtissama/anaconda3/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/joblib/externals/loky/process_executor.py", line 426, in _process_worker
#     call_item = call_queue.get(block=True, timeout=timeout)
#   File "/Users/ibtissama/anaconda3/lib/python3.10/multiprocessing/queues.py", line 122, in get
#     return _ForkingPickler.loads(res)
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/sklearn/__init__.py", line 73, in <module>
#     from .base import clone  # noqa: E402
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/sklearn/base.py", line 19, in <module>
#     from .utils._estimator_html_repr import _HTMLDocumentationLinkMixin, estimator_html_repr
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/sklearn/utils/__init__.py", line 15, in <module>
#     from ._chunking import gen_batches, gen_even_slices
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/sklearn/utils/_chunking.py", line 11, in <module>
#     from ._param_validation import Interval, validate_params
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/sklearn/utils/_param_validation.py", line 17, in <module>
#     from .validation import _is_arraylike_not_scalar
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/sklearn/utils/validation.py", line 21, in <module>
#     from ..utils._array_api import _asarray_with_order, _is_numpy_namespace, get_namespace
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/sklearn/utils/_array_api.py", line 17, in <module>
#     from .fixes import parse_version
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/sklearn/utils/fixes.py", line 20, in <module>
#     import pandas as pd
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/pandas/__init__.py", line 26, in <module>
#     from pandas.compat import (
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/pandas/compat/__init__.py", line 27, in <module>
#     from pandas.compat.pyarrow import (
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/pandas/compat/pyarrow.py", line 8, in <module>
#     import pyarrow as pa
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/pyarrow/__init__.py", line 65, in <module>
#     import pyarrow.lib as _lib
# : _ARRAY_API not found
# AttributeError: _ARRAY_API not found
#
# A module that was compiled using NumPy 1.x cannot be run in
# NumPy 2.1.3 as it may crash. To support both 1.x and 2.x
# versions of NumPy, modules must be compiled with NumPy 2.0.
# Some module may need to rebuild instead e.g. with 'pybind11>=2.12'.
#
# If you are a user of the module, the easiest solution will be to
# downgrade to 'numpy<2' or try to upgrade the affected module.
# We expect that some modules will need time to support NumPy 2.
#
# Traceback (most recent call last):  File "/Users/ibtissama/anaconda3/lib/python3.10/runpy.py", line 196, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "/Users/ibtissama/anaconda3/lib/python3.10/runpy.py", line 86, in _run_code
#     exec(code, run_globals)
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/joblib/externals/loky/backend/popen_loky_posix.py", line 180, in <module>
#     exitcode = process_obj._bootstrap()
#   File "/Users/ibtissama/anaconda3/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/Users/ibtissama/anaconda3/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/joblib/externals/loky/process_executor.py", line 426, in _process_worker
#     call_item = call_queue.get(block=True, timeout=timeout)
#   File "/Users/ibtissama/anaconda3/lib/python3.10/multiprocessing/queues.py", line 122, in get
#     return _ForkingPickler.loads(res)
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/sklearn/__init__.py", line 73, in <module>
#     from .base import clone  # noqa: E402
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/sklearn/base.py", line 19, in <module>
#     from .utils._estimator_html_repr import _HTMLDocumentationLinkMixin, estimator_html_repr
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/sklearn/utils/__init__.py", line 15, in <module>
#     from ._chunking import gen_batches, gen_even_slices
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/sklearn/utils/_chunking.py", line 11, in <module>
#     from ._param_validation import Interval, validate_params
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/sklearn/utils/_param_validation.py", line 17, in <module>
#     from .validation import _is_arraylike_not_scalar
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/sklearn/utils/validation.py", line 21, in <module>
#     from ..utils._array_api import _asarray_with_order, _is_numpy_namespace, get_namespace
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/sklearn/utils/_array_api.py", line 17, in <module>
#     from .fixes import parse_version
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/sklearn/utils/fixes.py", line 20, in <module>
#     import pandas as pd
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/pandas/__init__.py", line 49, in <module>
#     from pandas.core.api import (
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/pandas/core/api.py", line 9, in <module>
#     from pandas.core.dtypes.dtypes import (
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/pandas/core/dtypes/dtypes.py", line 24, in <module>
#     from pandas._libs import (
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/pyarrow/__init__.py", line 65, in <module>
#     import pyarrow.lib as _lib
#
# A module that was compiled using NumPy 1.x cannot be run in
# NumPy 2.1.3 as it may crash. To support both 1.x and 2.x
# versions of NumPy, modules must be compiled with NumPy 2.0.
# Some module may need to rebuild instead e.g. with 'pybind11>=2.12'.
#
# If you are a user of the module, the easiest solution will be to
# downgrade to 'numpy<2' or try to upgrade the affected module.
# We expect that some modules will need time to support NumPy 2.
#
# Traceback (most recent call last):  File "/Users/ibtissama/anaconda3/lib/python3.10/runpy.py", line 196, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "/Users/ibtissama/anaconda3/lib/python3.10/runpy.py", line 86, in _run_code
#     exec(code, run_globals)
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/joblib/externals/loky/backend/popen_loky_posix.py", line 180, in <module>
#     exitcode = process_obj._bootstrap()
#   File "/Users/ibtissama/anaconda3/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/Users/ibtissama/anaconda3/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/joblib/externals/loky/process_executor.py", line 426, in _process_worker
#     call_item = call_queue.get(block=True, timeout=timeout)
#   File "/Users/ibtissama/anaconda3/lib/python3.10/multiprocessing/queues.py", line 122, in get
#     return _ForkingPickler.loads(res)
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/sklearn/__init__.py", line 73, in <module>
#     from .base import clone  # noqa: E402
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/sklearn/base.py", line 19, in <module>
#     from .utils._estimator_html_repr import _HTMLDocumentationLinkMixin, estimator_html_repr
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/sklearn/utils/__init__.py", line 15, in <module>
#     from ._chunking import gen_batches, gen_even_slices
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/sklearn/utils/_chunking.py", line 11, in <module>
#     from ._param_validation import Interval, validate_params
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/sklearn/utils/_param_validation.py", line 17, in <module>
#     from .validation import _is_arraylike_not_scalar
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/sklearn/utils/validation.py", line 21, in <module>
#     from ..utils._array_api import _asarray_with_order, _is_numpy_namespace, get_namespace
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/sklearn/utils/_array_api.py", line 17, in <module>
#     from .fixes import parse_version
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/sklearn/utils/fixes.py", line 20, in <module>
#     import pandas as pd
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/pandas/__init__.py", line 49, in <module>
#     from pandas.core.api import (
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/pandas/core/api.py", line 9, in <module>
#     from pandas.core.dtypes.dtypes import (
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/pandas/core/dtypes/dtypes.py", line 24, in <module>
#     from pandas._libs import (
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/pyarrow/__init__.py", line 65, in <module>
#     import pyarrow.lib as _lib
# AttributeError: _ARRAY_API not foundAttributeError: _ARRAY_API not found
#
# A module that was compiled using NumPy 1.x cannot be run in
# NumPy 2.1.3 as it may crash. To support both 1.x and 2.x
# versions of NumPy, modules must be compiled with NumPy 2.0.
# Some module may need to rebuild instead e.g. with 'pybind11>=2.12'.
#
# If you are a user of the module, the easiest solution will be to
# downgrade to 'numpy<2' or try to upgrade the affected module.
# We expect that some modules will need time to support NumPy 2.
#
# Traceback (most recent call last):  File "/Users/ibtissama/anaconda3/lib/python3.10/runpy.py", line 196, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "/Users/ibtissama/anaconda3/lib/python3.10/runpy.py", line 86, in _run_code
#     exec(code, run_globals)
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/joblib/externals/loky/backend/popen_loky_posix.py", line 180, in <module>
#     exitcode = process_obj._bootstrap()
#   File "/Users/ibtissama/anaconda3/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/Users/ibtissama/anaconda3/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/joblib/externals/loky/process_executor.py", line 426, in _process_worker
#     call_item = call_queue.get(block=True, timeout=timeout)
#   File "/Users/ibtissama/anaconda3/lib/python3.10/multiprocessing/queues.py", line 122, in get
#     return _ForkingPickler.loads(res)
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/sklearn/__init__.py", line 73, in <module>
#     from .base import clone  # noqa: E402
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/sklearn/base.py", line 19, in <module>
#     from .utils._estimator_html_repr import _HTMLDocumentationLinkMixin, estimator_html_repr
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/sklearn/utils/__init__.py", line 15, in <module>
#     from ._chunking import gen_batches, gen_even_slices
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/sklearn/utils/_chunking.py", line 11, in <module>
#     from ._param_validation import Interval, validate_params
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/sklearn/utils/_param_validation.py", line 17, in <module>
#     from .validation import _is_arraylike_not_scalar
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/sklearn/utils/validation.py", line 21, in <module>
#     from ..utils._array_api import _asarray_with_order, _is_numpy_namespace, get_namespace
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/sklearn/utils/_array_api.py", line 17, in <module>
#     from .fixes import parse_version
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/sklearn/utils/fixes.py", line 20, in <module>
#     import pandas as pd
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/pandas/__init__.py", line 49, in <module>
#     from pandas.core.api import (
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/pandas/core/api.py", line 9, in <module>
#     from pandas.core.dtypes.dtypes import (
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/pandas/core/dtypes/dtypes.py", line 24, in <module>
#     from pandas._libs import (
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/pyarrow/__init__.py", line 65, in <module>
#     import pyarrow.lib as _lib
# AttributeError: _ARRAY_API not found
# A module that was compiled using NumPy 1.x cannot be run in
# NumPy 2.1.3 as it may crash. To support both 1.x and 2.x
# versions of NumPy, modules must be compiled with NumPy 2.0.
# Some module may need to rebuild instead e.g. with 'pybind11>=2.12'.
#
# If you are a user of the module, the easiest solution will be to
# downgrade to 'numpy<2' or try to upgrade the affected module.
# We expect that some modules will need time to support NumPy 2.
#
# Traceback (most recent call last):  File "/Users/ibtissama/anaconda3/lib/python3.10/runpy.py", line 196, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "/Users/ibtissama/anaconda3/lib/python3.10/runpy.py", line 86, in _run_code
#     exec(code, run_globals)
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/joblib/externals/loky/backend/popen_loky_posix.py", line 180, in <module>
#     exitcode = process_obj._bootstrap()
#   File "/Users/ibtissama/anaconda3/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/Users/ibtissama/anaconda3/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/joblib/externals/loky/process_executor.py", line 426, in _process_worker
#     call_item = call_queue.get(block=True, timeout=timeout)
#   File "/Users/ibtissama/anaconda3/lib/python3.10/multiprocessing/queues.py", line 122, in get
#     return _ForkingPickler.loads(res)
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/sklearn/__init__.py", line 73, in <module>
#     from .base import clone  # noqa: E402
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/sklearn/base.py", line 19, in <module>
#     from .utils._estimator_html_repr import _HTMLDocumentationLinkMixin, estimator_html_repr
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/sklearn/utils/__init__.py", line 15, in <module>
#     from ._chunking import gen_batches, gen_even_slices
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/sklearn/utils/_chunking.py", line 11, in <module>
#     from ._param_validation import Interval, validate_params
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/sklearn/utils/_param_validation.py", line 17, in <module>
#     from .validation import _is_arraylike_not_scalar
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/sklearn/utils/validation.py", line 21, in <module>
#     from ..utils._array_api import _asarray_with_order, _is_numpy_namespace, get_namespace
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/sklearn/utils/_array_api.py", line 17, in <module>
#     from .fixes import parse_version
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/sklearn/utils/fixes.py", line 20, in <module>
#     import pandas as pd
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/pandas/__init__.py", line 49, in <module>
#     from pandas.core.api import (
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/pandas/core/api.py", line 9, in <module>
#     from pandas.core.dtypes.dtypes import (
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/pandas/core/dtypes/dtypes.py", line 24, in <module>
#     from pandas._libs import (
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/pyarrow/__init__.py", line 65, in <module>
#     import pyarrow.lib as _lib
#
# AttributeError: _ARRAY_API not found
#
#
# A module that was compiled using NumPy 1.x cannot be run in
# NumPy 2.1.3 as it may crash. To support both 1.x and 2.x
# versions of NumPy, modules must be compiled with NumPy 2.0.
# Some module may need to rebuild instead e.g. with 'pybind11>=2.12'.
#
# If you are a user of the module, the easiest solution will be to
# downgrade to 'numpy<2' or try to upgrade the affected module.
# We expect that some modules will need time to support NumPy 2.
#
# Traceback (most recent call last):  File "/Users/ibtissama/anaconda3/lib/python3.10/runpy.py", line 196, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "/Users/ibtissama/anaconda3/lib/python3.10/runpy.py", line 86, in _run_code
#     exec(code, run_globals)
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/joblib/externals/loky/backend/popen_loky_posix.py", line 180, in <module>
#     exitcode = process_obj._bootstrap()
#   File "/Users/ibtissama/anaconda3/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/Users/ibtissama/anaconda3/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/joblib/externals/loky/process_executor.py", line 426, in _process_worker
#     call_item = call_queue.get(block=True, timeout=timeout)
#   File "/Users/ibtissama/anaconda3/lib/python3.10/multiprocessing/queues.py", line 122, in get
#     return _ForkingPickler.loads(res)
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/sklearn/__init__.py", line 73, in <module>
#     from .base import clone  # noqa: E402
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/sklearn/base.py", line 19, in <module>
#     from .utils._estimator_html_repr import _HTMLDocumentationLinkMixin, estimator_html_repr
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/sklearn/utils/__init__.py", line 15, in <module>
#     from ._chunking import gen_batches, gen_even_slices
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/sklearn/utils/_chunking.py", line 11, in <module>
#     from ._param_validation import Interval, validate_params
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/sklearn/utils/_param_validation.py", line 17, in <module>
#     from .validation import _is_arraylike_not_scalar
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/sklearn/utils/validation.py", line 21, in <module>
#     from ..utils._array_api import _asarray_with_order, _is_numpy_namespace, get_namespace
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/sklearn/utils/_array_api.py", line 17, in <module>
#     from .fixes import parse_version
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/sklearn/utils/fixes.py", line 20, in <module>
#     import pandas as pd
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/pandas/__init__.py", line 49, in <module>
#     from pandas.core.api import (
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/pandas/core/api.py", line 9, in <module>
#     from pandas.core.dtypes.dtypes import (
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/pandas/core/dtypes/dtypes.py", line 24, in <module>
#     from pandas._libs import (
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/pyarrow/__init__.py", line 65, in <module>
#     import pyarrow.lib as _lib
# AttributeError: _ARRAY_API not found
#
# A module that was compiled using NumPy 1.x cannot be run in
# NumPy 2.1.3 as it may crash. To support both 1.x and 2.x
# versions of NumPy, modules must be compiled with NumPy 2.0.
# Some module may need to rebuild instead e.g. with 'pybind11>=2.12'.
#
# If you are a user of the module, the easiest solution will be to
# downgrade to 'numpy<2' or try to upgrade the affected module.
# We expect that some modules will need time to support NumPy 2.
#
# Traceback (most recent call last):  File "/Users/ibtissama/anaconda3/lib/python3.10/runpy.py", line 196, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "/Users/ibtissama/anaconda3/lib/python3.10/runpy.py", line 86, in _run_code
#     exec(code, run_globals)
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/joblib/externals/loky/backend/popen_loky_posix.py", line 180, in <module>
#     exitcode = process_obj._bootstrap()
#   File "/Users/ibtissama/anaconda3/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/Users/ibtissama/anaconda3/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/joblib/externals/loky/process_executor.py", line 426, in _process_worker
#     call_item = call_queue.get(block=True, timeout=timeout)
#   File "/Users/ibtissama/anaconda3/lib/python3.10/multiprocessing/queues.py", line 122, in get
#     return _ForkingPickler.loads(res)
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/sklearn/__init__.py", line 73, in <module>
#     from .base import clone  # noqa: E402
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/sklearn/base.py", line 19, in <module>
#     from .utils._estimator_html_repr import _HTMLDocumentationLinkMixin, estimator_html_repr
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/sklearn/utils/__init__.py", line 15, in <module>
#     from ._chunking import gen_batches, gen_even_slices
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/sklearn/utils/_chunking.py", line 11, in <module>
#     from ._param_validation import Interval, validate_params
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/sklearn/utils/_param_validation.py", line 17, in <module>
#     from .validation import _is_arraylike_not_scalar
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/sklearn/utils/validation.py", line 21, in <module>
#     from ..utils._array_api import _asarray_with_order, _is_numpy_namespace, get_namespace
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/sklearn/utils/_array_api.py", line 17, in <module>
#     from .fixes import parse_version
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/sklearn/utils/fixes.py", line 20, in <module>
#     import pandas as pd
#   File "/Users/ibtissama/anaconda3/lib/python3.10/site-packages/pandas/__init__.py", line 49, in <module>
#     from pandas.core.api import (
# ...
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/ibtissama/anaconda3/lib/python3.10/site-packages/xgboost/core.py:158: UserWarning: [17:22:20] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/ibtissama/anaconda3/lib/python3.10/site-packages/xgboost/core.py:158: UserWarning: [17:22:20] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/ibtissama/anaconda3/lib/python3.10/site-packages/xgboost/core.py:158: UserWarning: [17:22:20] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/ibtissama/anaconda3/lib/python3.10/site-packages/xgboost/core.py:158: UserWarning: [17:22:20] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/ibtissama/anaconda3/lib/python3.10/site-packages/xgboost/core.py:158: UserWarning: [17:22:20] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/ibtissama/anaconda3/lib/python3.10/site-packages/xgboost/core.py:158: UserWarning: [17:22:20] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/ibtissama/anaconda3/lib/python3.10/site-packages/xgboost/core.py:158: UserWarning: [17:22:20] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/ibtissama/anaconda3/lib/python3.10/site-packages/xgboost/core.py:158: UserWarning: [17:22:20] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/ibtissama/anaconda3/lib/python3.10/site-packages/xgboost/core.py:158: UserWarning: [17:22:20] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/ibtissama/anaconda3/lib/python3.10/site-packages/xgboost/core.py:158: UserWarning: [17:22:20] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/ibtissama/anaconda3/lib/python3.10/site-packages/xgboost/core.py:158: UserWarning: [17:22:21] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/ibtissama/anaconda3/lib/python3.10/site-packages/xgboost/core.py:158: UserWarning: [17:22:21] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/ibtissama/anaconda3/lib/python3.10/site-packages/xgboost/core.py:158: UserWarning: [17:22:21] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/ibtissama/anaconda3/lib/python3.10/site-packages/xgboost/core.py:158: UserWarning: [17:22:21] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/ibtissama/anaconda3/lib/python3.10/site-packages/xgboost/core.py:158: UserWarning: [17:22:21] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/ibtissama/anaconda3/lib/python3.10/site-packages/xgboost/core.py:158: UserWarning: [17:22:21] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/ibtissama/anaconda3/lib/python3.10/site-packages/xgboost/core.py:158: UserWarning: [17:22:21] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/ibtissama/anaconda3/lib/python3.10/site-packages/xgboost/core.py:158: UserWarning: [17:22:21] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/ibtissama/anaconda3/lib/python3.10/site-packages/xgboost/core.py:158: UserWarning: [17:22:21] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/ibtissama/anaconda3/lib/python3.10/site-packages/xgboost/core.py:158: UserWarning: [17:22:21] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/ibtissama/anaconda3/lib/python3.10/site-packages/xgboost/core.py:158: UserWarning: [17:22:21] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/ibtissama/anaconda3/lib/python3.10/site-packages/xgboost/core.py:158: UserWarning: [17:22:21] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/ibtissama/anaconda3/lib/python3.10/site-packages/xgboost/core.py:158: UserWarning: [17:22:21] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/ibtissama/anaconda3/lib/python3.10/site-packages/xgboost/core.py:158: UserWarning: [17:22:21] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/ibtissama/anaconda3/lib/python3.10/site-packages/xgboost/core.py:158: UserWarning: [17:22:21] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/ibtissama/anaconda3/lib/python3.10/site-packages/xgboost/core.py:158: UserWarning: [17:22:21] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/ibtissama/anaconda3/lib/python3.10/site-packages/xgboost/core.py:158: UserWarning: [17:22:21] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/ibtissama/anaconda3/lib/python3.10/site-packages/xgboost/core.py:158: UserWarning: [17:22:22] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/ibtissama/anaconda3/lib/python3.10/site-packages/xgboost/core.py:158: UserWarning: [17:22:22] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/ibtissama/anaconda3/lib/python3.10/site-packages/xgboost/core.py:158: UserWarning: [17:22:22] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/ibtissama/anaconda3/lib/python3.10/site-packages/xgboost/core.py:158: UserWarning: [17:22:22] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/ibtissama/anaconda3/lib/python3.10/site-packages/xgboost/core.py:158: UserWarning: [17:22:22] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/ibtissama/anaconda3/lib/python3.10/site-packages/xgboost/core.py:158: UserWarning: [17:22:22] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/ibtissama/anaconda3/lib/python3.10/site-packages/xgboost/core.py:158: UserWarning: [17:22:22] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/ibtissama/anaconda3/lib/python3.10/site-packages/xgboost/core.py:158: UserWarning: [17:22:22] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/ibtissama/anaconda3/lib/python3.10/site-packages/xgboost/core.py:158: UserWarning: [17:22:22] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/ibtissama/anaconda3/lib/python3.10/site-packages/xgboost/core.py:158: UserWarning: [17:22:22] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/ibtissama/anaconda3/lib/python3.10/site-packages/xgboost/core.py:158: UserWarning: [17:22:22] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/ibtissama/anaconda3/lib/python3.10/site-packages/xgboost/core.py:158: UserWarning: [17:22:22] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/ibtissama/anaconda3/lib/python3.10/site-packages/xgboost/core.py:158: UserWarning: [17:22:22] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/ibtissama/anaconda3/lib/python3.10/site-packages/xgboost/core.py:158: UserWarning: [17:22:22] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/ibtissama/anaconda3/lib/python3.10/site-packages/xgboost/core.py:158: UserWarning: [17:22:22] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/ibtissama/anaconda3/lib/python3.10/site-packages/xgboost/core.py:158: UserWarning: [17:22:22] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/ibtissama/anaconda3/lib/python3.10/site-packages/xgboost/core.py:158: UserWarning: [17:22:22] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/ibtissama/anaconda3/lib/python3.10/site-packages/xgboost/core.py:158: UserWarning: [17:22:22] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/ibtissama/anaconda3/lib/python3.10/site-packages/xgboost/core.py:158: UserWarning: [17:22:23] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/ibtissama/anaconda3/lib/python3.10/site-packages/xgboost/core.py:158: UserWarning: [17:22:23] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/ibtissama/anaconda3/lib/python3.10/site-packages/xgboost/core.py:158: UserWarning: [17:22:23] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/ibtissama/anaconda3/lib/python3.10/site-packages/xgboost/core.py:158: UserWarning: [17:22:23] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/ibtissama/anaconda3/lib/python3.10/site-packages/xgboost/core.py:158: UserWarning: [17:22:23] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/ibtissama/anaconda3/lib/python3.10/site-packages/xgboost/core.py:158: UserWarning: [17:22:23] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/ibtissama/anaconda3/lib/python3.10/site-packages/xgboost/core.py:158: UserWarning: [17:22:23] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/ibtissama/anaconda3/lib/python3.10/site-packages/xgboost/core.py:158: UserWarning: [17:22:23] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/ibtissama/anaconda3/lib/python3.10/site-packages/xgboost/core.py:158: UserWarning: [17:22:23] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/ibtissama/anaconda3/lib/python3.10/site-packages/xgboost/core.py:158: UserWarning: [17:22:23] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/ibtissama/anaconda3/lib/python3.10/site-packages/xgboost/core.py:158: UserWarning: [17:22:23] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/ibtissama/anaconda3/lib/python3.10/site-packages/xgboost/core.py:158: UserWarning: [17:22:23] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/ibtissama/anaconda3/lib/python3.10/site-packages/xgboost/core.py:158: UserWarning: [17:22:23] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/ibtissama/anaconda3/lib/python3.10/site-packages/xgboost/core.py:158: UserWarning: [17:22:23] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# 📊 Average Confusion Matrix:
# [[599. 225.]
#  [241. 583.]]
#
# 🎯 Performance Metrics:
# 🔹 Precision (Class 1 - Long Career Players): 0.7202
# 🔹 Recall (Class 1 - Majority): 0.7076
# 🔹 F1-score (Class 1 - Long Career Players): 0.7133
# 🔹 Precision (Class 0 - Short Career Players): 0.7155
# 🔹 Recall (Class 0 - Minority): 0.7269
# 🔹 F1-score (Class 0 - Short Career Players): 0.7207
#
# 📜 Full Classification Report (average over folds):
#               precision    recall  f1-score   support
#
#          0.0       0.71      0.73      0.72       824
#          1.0       0.72      0.71      0.71       824
#
#     accuracy                           0.72      1648
#    macro avg       0.72      0.72      0.72      1648
# weighted avg       0.72      0.72      0.72      1648
# /Users/ibtissama/anaconda3/lib/python3.10/site-packages/xgboost/core.py:158: UserWarning: [17:22:24] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)

# %% [markdown]
# ✅ F1-score Classe 1 (Longue carrière) : 0.7133
#
# ✅ F1-score Classe 0 (Courte carrière) : 0.7207
#
# ✅ Accuracy globale : 0.72
#
# 🔍 Analyse :
#
# Dans ce cas l'optimisation n'a pa permit d'avoir des performances mieux que la version précédente.

# %%
# Version 3 - Optimisation avec Optuna


xgb_clf = xgb.XGBClassifier(
    objective='binary:logistic',  
    random_state=42,
    eval_metric="logloss",  
    use_label_encoder=False,
    tree_method="hist"  
)

XGB_model = score_classifier_with_optuna(over_X, xgb_clf, over_y, 50, cv=5, use_stratified=True)
XGB_model
# Out:
# [I 2025-03-06 17:26:58,208] A new study created in memory with name: no-name-b78f889e-a24a-4e64-8ac9-a9deeb624421
# /Users/ibtissama/anaconda3/lib/python3.10/site-packages/xgboost/core.py:158: UserWarning: [17:26:58] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/ibtissama/anaconda3/lib/python3.10/site-packages/xgboost/core.py:158: UserWarning: [17:26:58] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/ibtissama/anaconda3/lib/python3.10/site-packages/xgboost/core.py:158: UserWarning: [17:26:59] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/ibtissama/anaconda3/lib/python3.10/site-packages/xgboost/core.py:158: UserWarning: [17:26:59] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/ibtissama/anaconda3/lib/python3.10/site-packages/xgboost/core.py:158: UserWarning: [17:26:59] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2025-03-06 17:26:59,841] Trial 0 finished with value: 0.7113069738424953 and parameters: {'n_estimators': 300, 'max_depth': 4, 'learning_rate': 0.09974127891835952, 'subsample': 0.768908232732275, 'colsample_bytree': 0.5512044482104064}. Best is trial 0 with value: 0.7113069738424953.
# /Users/ibtissama/anaconda3/lib/python3.10/site-packages/xgboost/core.py:158: UserWarning: [17:26:59] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/ibtissama/anaconda3/lib/python3.10/site-packages/xgboost/core.py:158: UserWarning: [17:27:00] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/ibtissama/anaconda3/lib/python3.10/site-packages/xgboost/core.py:158: UserWarning: [17:27:00] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/ibtissama/anaconda3/lib/python3.10/site-packages/xgboost/core.py:158: UserWarning: [17:27:01] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/ibtissama/anaconda3/lib/python3.10/site-packages/xgboost/core.py:158: UserWarning: [17:27:01] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2025-03-06 17:27:02,243] Trial 1 finished with value: 0.7248025568320399 and parameters: {'n_estimators': 300, 'max_depth': 10, 'learning_rate': 0.0908621197143736, 'subsample': 0.7889810026163234, 'colsample_bytree': 0.925120347017027}. Best is trial 1 with value: 0.7248025568320399.
# /Users/ibtissama/anaconda3/lib/python3.10/site-packages/xgboost/core.py:158: UserWarning: [17:27:02] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/ibtissama/anaconda3/lib/python3.10/site-packages/xgboost/core.py:158: UserWarning: [17:27:02] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/ibtissama/anaconda3/lib/python3.10/site-packages/xgboost/core.py:158: UserWarning: [17:27:03] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/ibtissama/anaconda3/lib/python3.10/site-packages/xgboost/core.py:158: UserWarning: [17:27:04] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/ibtissama/anaconda3/lib/python3.10/site-packages/xgboost/core.py:158: UserWarning: [17:27:04] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2025-03-06 17:27:05,497] Trial 2 finished with value: 0.7152086764936837 and parameters: {'n_estimators': 400, 'max_depth': 7, 'learning_rate': 0.0037225030004855654, 'subsample': 0.8722220989700482, 'colsample_bytree': 0.8798945582181517}. Best is trial 1 with value: 0.7248025568320399.
# /Users/ibtissama/anaconda3/lib/python3.10/site-packages/xgboost/core.py:158: UserWarning: [17:27:05] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/ibtissama/anaconda3/lib/python3.10/site-packages/xgboost/core.py:158: UserWarning: [17:27:05] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/ibtissama/anaconda3/lib/python3.10/site-packages/xgboost/core.py:158: UserWarning: [17:27:06] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/ibtissama/anaconda3/lib/python3.10/site-packages/xgboost/core.py:158: UserWarning: [17:27:06] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/ibtissama/anaconda3/lib/python3.10/site-packages/xgboost/core.py:158: UserWarning: [17:27:06] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2025-03-06 17:27:06,947] Trial 3 finished with value: 0.7167094676543606 and parameters: {'n_estimators': 400, 'max_depth': 5, 'learning_rate': 0.11080785810956281, 'subsample': 0.9973271541903963, 'colsample_bytree': 0.5418105951181293}. Best is trial 1 with value: 0.7248025568320399.
# /Users/ibtissama/anaconda3/lib/python3.10/site-packages/xgboost/core.py:158: UserWarning: [17:27:06] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/ibtissama/anaconda3/lib/python3.10/site-packages/xgboost/core.py:158: UserWarning: [17:27:07] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/ibtissama/anaconda3/lib/python3.10/site-packages/xgboost/core.py:158: UserWarning: [17:27:07] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/ibtissama/anaconda3/lib/python3.10/site-packages/xgboost/core.py:158: UserWarning: [17:27:07] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/ibtissama/anaconda3/lib/python3.10/site-packages/xgboost/core.py:158: UserWarning: [17:27:07] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2025-03-06 17:27:07,818] Trial 4 finished with value: 0.714265394773007 and parameters: {'n_estimators': 100, 'max_depth': 8, 'learning_rate': 0.01809032109667904, 'subsample': 0.7061527751343433, 'colsample_bytree': 0.7711216277577939}. Best is trial 1 with value: 0.7248025568320399.
# /Users/ibtissama/anaconda3/lib/python3.10/site-packages/xgboost/core.py:158: UserWarning: [17:27:07] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/ibtissama/anaconda3/lib/python3.10/site-packages/xgboost/core.py:158: UserWarning: [17:27:08] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/ibtissama/anaconda3/lib/python3.10/site-packages/xgboost/core.py:158: UserWarning: [17:27:08] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/ibtissama/anaconda3/lib/python3.10/site-packages/xgboost/core.py:158: UserWarning: [17:27:09] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/ibtissama/anaconda3/lib/python3.10/site-packages/xgboost/core.py:158: UserWarning: [17:27:09] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2025-03-06 17:27:10,332] Trial 5 finished with value: 0.719177333964798 and parameters: {'n_estimators': 400, 'max_depth': 7, 'learning_rate': 0.006964726933171331, 'subsample': 0.5341715156667438, 'colsample_bytree': 0.5996871177167704}. Best is trial 1 with value: 0.7248025568320399.
# /Users/ibtissama/anaconda3/lib/python3.10/site-packages/xgboost/core.py:158: UserWarning: [17:27:10] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/ibtissama/anaconda3/lib/python3.10/site-packages/xgboost/core.py:158: UserWarning: [17:27:10] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/ibtissama/anaconda3/lib/python3.10/site-packages/xgboost/core.py:158: UserWarning: [17:27:11] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/ibtissama/anaconda3/lib/python3.10/site-packages/xgboost/core.py:158: UserWarning: [17:27:11] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/ibtissama/anaconda3/lib/python3.10/site-packages/xgboost/core.py:158: UserWarning: [17:27:12] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2025-03-06 17:27:12,476] Trial 6 finished with value: 0.721515874038559 and parameters: {'n_estimators': 300, 'max_depth': 9, 'learning_rate': 0.07408493482261108, 'subsample': 0.844168499049602, 'colsample_bytree': 0.8698075564434427}. Best is trial 1 with value: 0.7248025568320399.
# /Users/ibtissama/anaconda3/lib/python3.10/site-packages/xgboost/core.py:158: UserWarning: [17:27:12] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/ibtissama/anaconda3/lib/python3.10/site-packages/xgboost/core.py:158: UserWarning: [17:27:12] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/ibtissama/anaconda3/lib/python3.10/site-packages/xgboost/core.py:158: UserWarning: [17:27:13] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/ibtissama/anaconda3/lib/python3.10/site-packages/xgboost/core.py:158: UserWarning: [17:27:13] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/ibtissama/anaconda3/lib/python3.10/site-packages/xgboost/core.py:158: UserWarning: [17:27:13] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2025-03-06 17:27:14,247] Trial 7 finished with value: 0.7171105988270071 and parameters: {'n_estimators': 500, 'max_depth': 5, 'learning_rate': 0.00376322996506829, 'subsample': 0.7862386708726035, 'colsample_bytree': 0.6405210413707898}. Best is trial 1 with value: 0.7248025568320399.
# /Users/ibtissama/anaconda3/lib/python3.10/site-packages/xgboost/core.py:158: UserWarning: [17:27:14] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/ibtissama/anaconda3/lib/python3.10/site-packages/xgboost/core.py:158: UserWarning: [17:27:14] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/ibtissama/anaconda3/lib/python3.10/site-packages/xgboost/core.py:158: UserWarning: [17:27:15] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/ibtissama/anaconda3/lib/python3.10/site-packages/xgboost/core.py:158: UserWarning: [17:27:15] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/ibtissama/anaconda3/lib/python3.10/site-packages/xgboost/core.py:158: UserWarning: [17:27:15] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2025-03-06 17:27:16,090] Trial 8 finished with value: 0.7273050195875375 and parameters: {'n_estimators': 300, 'max_depth': 7, 'learning_rate': 0.010289007166791935, 'subsample': 0.9008838376573147, 'colsample_bytree': 0.641748090216351}. Best is trial 8 with value: 0.7273050195875375.
# /Users/ibtissama/anaconda3/lib/python3.10/site-packages/xgboost/core.py:158: UserWarning: [17:27:16] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/ibtissama/anaconda3/lib/python3.10/site-packages/xgboost/core.py:158: UserWarning: [17:27:16] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/ibtissama/anaconda3/lib/python3.10/site-packages/xgboost/core.py:158: UserWarning: [17:27:16] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/ibtissama/anaconda3/lib/python3.10/site-packages/xgboost/core.py:158: UserWarning: [17:27:16] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/ibtissama/anaconda3/lib/python3.10/site-packages/xgboost/core.py:158: UserWarning: [17:27:16] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2025-03-06 17:27:16,615] Trial 9 finished with value: 0.7165588568933864 and parameters: {'n_estimators': 200, 'max_depth': 3, 'learning_rate': 0
and parameters: {'n_estimators': 400, 'max_depth': 7, 'learning_rate': 0.02578712562363702, 'subsample': 0.9742176112856996, 'colsample_bytree': 0.840918953030246}. Best is trial 18 with value: 0.7292014568617107.
# /Users/ibtissama/anaconda3/lib/python3.10/site-packages/xgboost/core.py:158: UserWarning: [17:27:46] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/ibtissama/anaconda3/lib/python3.10/site-packages/xgboost/core.py:158: UserWarning: [17:27:46] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/ibtissama/anaconda3/lib/python3.10/site-packages/xgboost/core.py:158: UserWarning: [17:27:47] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/ibtissama/anaconda3/lib/python3.10/site-packages/xgboost/core.py:158: UserWarning: [17:27:48] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/ibtissama/anaconda3/lib/python3.10/site-packages/xgboost/core.py:158: UserWarning: [17:27:49] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2025-03-06 17:27:50,236] Trial 26 finished with value: 0.7207314520857432 and parameters: {'n_estimators': 500, 'max_depth': 8, 'learning_rate': 0.00644550575885685, 'subsample': 0.9134096800043469, 'colsample_bytree': 0.7444695585364132}. Best is trial 18 with value: 0.7292014568617107.
# /Users/ibtissama/anaconda3/lib/python3.10/site-packages/xgboost/core.py:158: UserWarning: [17:27:50] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/ibtissama/anaconda3/lib/python3.10/site-packages/xgboost/core.py:158: UserWarning: [17:27:50] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/ibtissama/anaconda3/lib/python3.10/site-packages/xgboost/core.py:158: UserWarning: [17:27:50] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/ibtissama/anaconda3/lib/python3.10/site-packages/xgboost/core.py:158: UserWarning: [17:27:51] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/ibtissama/anaconda3/lib/python3.10/site-packages/xgboost/core.py:158: UserWarning: [17:27:51] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2025-03-06 17:27:52,126] Trial 27 finished with value: 0.7202292409262067 and parameters: {'n_estimators': 400, 'max_depth': 6, 'learning_rate': 0.011916905574376746, 'subsample': 0.9590522852444661, 'colsample_bytree': 0.5079496234189094}. Best is trial 18 with value: 0.7292014568617107.
# /Users/ibtissama/anaconda3/lib/python3.10/site-packages/xgboost/core.py:158: UserWarning: [17:27:52] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/ibtissama/anaconda3/lib/python3.10/site-packages/xgboost/core.py:158: UserWarning: [17:27:52] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/ibtissama/anaconda3/lib/python3.10/site-packages/xgboost/core.py:158: UserWarning: [17:27:53] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/ibtissama/anaconda3/lib/python3.10/site-packages/xgboost/core.py:158: UserWarning: [17:27:54] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/ibtissama/anaconda3/lib/python3.10/site-packages/xgboost/core.py:158: UserWarning: [17:27:54] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2025-03-06 17:27:55,206] Trial 28 finished with value: 0.710140999631029 and parameters: {'n_estimators': 400, 'max_depth': 7, 'learning_rate': 0.0036373724123395165, 'subsample': 0.8636537608441401, 'colsample_bytree': 0.9588347640753025}. Best is trial 18 with value: 0.7292014568617107.
# /Users/ibtissama/anaconda3/lib/python3.10/site-packages/xgboost/core.py:158: UserWarning: [17:27:55] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/ibtissama/anaconda3/lib/python3.10/site-packages/xgboost/core.py:158: UserWarning: [17:27:55] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/ibtissama/anaconda3/lib/python3.10/site-packages/xgboost/core.py:158: UserWarning: [17:27:55] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/ibtissama/anaconda3/lib/python3.10/site-packages/xgboost/core.py:158: UserWarning: [17:27:56] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/ibtissama/anaconda3/lib/python3.10/site-packages/xgboost/core.py:158: UserWarning: [17:27:56] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2025-03-06 17:27:57,062] Trial 29 finished with value: 0.7248191488810589 and parameters: {'n_estimators': 300, 'max_depth': 8, 'learning_rate': 0.02272252392412381, 'subsample': 0.9072595193167474, 'colsample_bytree': 0.5952615674152902}. Best is trial 18 with value: 0.7292014568617107.
# /Users/ibtissama/anaconda3/lib/python3.10/site-packages/xgboost/core.py:158: UserWarning: [17:27:57] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/ibtissama/anaconda3/lib/python3.10/site-packages/xgboost/core.py:158: UserWarning: [17:27:57] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/ibtissama/anaconda3/lib/python3.10/site-packages/xgboost/core.py:158: UserWarning: [17:27:57] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/ibtissama/anaconda3/lib/python3.10/site-packages/xgboost/core.py:158: UserWarning: [17:27:58] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/ibtissama/anaconda3/lib/python3.10/site-packages/xgboost/core.py:158: UserWarning: [17:27:58] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# ...
#
#   warnings.warn(smsg, UserWarning)
# [I 2025-03-06 17:28:22,737] Trial 41 finished with value: 0.7232754442004876 and parameters: {'n_estimators': 400, 'max_depth': 7, 'learning_rate': 0.00834684865092868, 'subsample': 0.9292600406621367, 'colsample_bytree': 0.5701243208361727}. Best is trial 34 with value: 0.7293700767077682.
# /Users/ibtissama/anaconda3/lib/python3.10/site-packages/xgboost/core.py:158: UserWarning: [17:28:22] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/ibtissama/anaconda3/lib/python3.10/site-packages/xgboost/core.py:158: UserWarning: [17:28:23] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/ibtissama/anaconda3/lib/python3.10/site-packages/xgboost/core.py:158: UserWarning: [17:28:23] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/ibtissama/anaconda3/lib/python3.10/site-packages/xgboost/core.py:158: UserWarning: [17:28:24] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/ibtissama/anaconda3/lib/python3.10/site-packages/xgboost/core.py:158: UserWarning: [17:28:25] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2025-03-06 17:28:25,780] Trial 42 finished with value: 0.7218743659438095 and parameters: {'n_estimators': 500, 'max_depth': 7, 'learning_rate': 0.015565120942550588, 'subsample': 0.9767177833998496, 'colsample_bytree': 0.6269499408657688}. Best is trial 34 with value: 0.7293700767077682.
# /Users/ibtissama/anaconda3/lib/python3.10/site-packages/xgboost/core.py:158: UserWarning: [17:28:25] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/ibtissama/anaconda3/lib/python3.10/site-packages/xgboost/core.py:158: UserWarning: [17:28:25] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/ibtissama/anaconda3/lib/python3.10/site-packages/xgboost/core.py:158: UserWarning: [17:28:26] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/ibtissama/anaconda3/lib/python3.10/site-packages/xgboost/core.py:158: UserWarning: [17:28:26] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/ibtissama/anaconda3/lib/python3.10/site-packages/xgboost/core.py:158: UserWarning: [17:28:26] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2025-03-06 17:28:26,369] Trial 43 finished with value: 0.7116437576590898 and parameters: {'n_estimators': 100, 'max_depth': 7, 'learning_rate': 0.005267911709629249, 'subsample': 0.9961950058108119, 'colsample_bytree': 0.5335916651352021}. Best is trial 34 with value: 0.7293700767077682.
# /Users/ibtissama/anaconda3/lib/python3.10/site-packages/xgboost/core.py:158: UserWarning: [17:28:26] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/ibtissama/anaconda3/lib/python3.10/site-packages/xgboost/core.py:158: UserWarning: [17:28:26] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/ibtissama/anaconda3/lib/python3.10/site-packages/xgboost/core.py:158: UserWarning: [17:28:27] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/ibtissama/anaconda3/lib/python3.10/site-packages/xgboost/core.py:158: UserWarning: [17:28:27] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/ibtissama/anaconda3/lib/python3.10/site-packages/xgboost/core.py:158: UserWarning: [17:28:28] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2025-03-06 17:28:28,362] Trial 44 finished with value: 0.7116048349790829 and parameters: {'n_estimators': 400, 'max_depth': 6, 'learning_rate': 0.002963706036462134, 'subsample': 0.9522059584247597, 'colsample_bytree': 0.6652556221204999}. Best is trial 34 with value: 0.7293700767077682.
# /Users/ibtissama/anaconda3/lib/python3.10/site-packages/xgboost/core.py:158: UserWarning: [17:28:28] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/ibtissama/anaconda3/lib/python3.10/site-packages/xgboost/core.py:158: UserWarning: [17:28:28] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/ibtissama/anaconda3/lib/python3.10/site-packages/xgboost/core.py:158: UserWarning: [17:28:29] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/ibtissama/anaconda3/lib/python3.10/site-packages/xgboost/core.py:158: UserWarning: [17:28:29] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/ibtissama/anaconda3/lib/python3.10/site-packages/xgboost/core.py:158: UserWarning: [17:28:30] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2025-03-06 17:28:30,825] Trial 45 finished with value: 0.7224970220138708 and parameters: {'n_estimators': 500, 'max_depth': 8, 'learning_rate': 0.0794049515540128, 'subsample': 0.9368533239876802, 'colsample_bytree': 0.6101545548582281}. Best is trial 34 with value: 0.7293700767077682.
# /Users/ibtissama/anaconda3/lib/python3.10/site-packages/xgboost/core.py:158: UserWarning: [17:28:30] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/ibtissama/anaconda3/lib/python3.10/site-packages/xgboost/core.py:158: UserWarning: [17:28:31] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/ibtissama/anaconda3/lib/python3.10/site-packages/xgboost/core.py:158: UserWarning: [17:28:32] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/ibtissama/anaconda3/lib/python3.10/site-packages/xgboost/core.py:158: UserWarning: [17:28:33] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/ibtissama/anaconda3/lib/python3.10/site-packages/xgboost/core.py:158: UserWarning: [17:28:34] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2025-03-06 17:28:34,894] Trial 46 finished with value: 0.721584566599037 and parameters: {'n_estimators': 400, 'max_depth': 9, 'learning_rate': 0.006326116209263435, 'subsample': 0.8934579220995151, 'colsample_bytree': 0.6897656253287258}. Best is trial 34 with value: 0.7293700767077682.
# /Users/ibtissama/anaconda3/lib/python3.10/site-packages/xgboost/core.py:158: UserWarning: [17:28:34] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/ibtissama/anaconda3/lib/python3.10/site-packages/xgboost/core.py:158: UserWarning: [17:28:35] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/ibtissama/anaconda3/lib/python3.10/site-packages/xgboost/core.py:158: UserWarning: [17:28:35] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/ibtissama/anaconda3/lib/python3.10/site-packages/xgboost/core.py:158: UserWarning: [17:28:35] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/ibtissama/anaconda3/lib/python3.10/site-packages/xgboost/core.py:158: UserWarning: [17:28:35] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2025-03-06 17:28:36,171] Trial 47 finished with value: 0.7193312897910599 and parameters: {'n_estimators': 200, 'max_depth': 8, 'learning_rate': 0.050694629814827405, 'subsample': 0.8048492052841801, 'colsample_bytree': 0.5498950217252633}. Best is trial 34 with value: 0.7293700767077682.
# /Users/ibtissama/anaconda3/lib/python3.10/site-packages/xgboost/core.py:158: UserWarning: [17:28:36] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/ibtissama/anaconda3/lib/python3.10/site-packages/xgboost/core.py:158: UserWarning: [17:28:36] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/ibtissama/anaconda3/lib/python3.10/site-packages/xgboost/core.py:158: UserWarning: [17:28:37] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/ibtissama/anaconda3/lib/python3.10/site-packages/xgboost/core.py:158: UserWarning: [17:28:37] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/ibtissama/anaconda3/lib/python3.10/site-packages/xgboost/core.py:158: UserWarning: [17:28:38] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2025-03-06 17:28:38,996] Trial 48 finished with value: 0.7241088202136899 and parameters: {'n_estimators': 400, 'max_depth': 7, 'learning_rate': 0.01181042414905766, 'subsample': 0.9768662884953832, 'colsample_bytree': 0.7769774317228602}. Best is trial 34 with value: 0.7293700767077682.
# /Users/ibtissama/anaconda3/lib/python3.10/site-packages/xgboost/core.py:158: UserWarning: [17:28:39] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/ibtissama/anaconda3/lib/python3.10/site-packages/xgboost/core.py:158: UserWarning: [17:28:39] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/ibtissama/anaconda3/lib/python3.10/site-packages/xgboost/core.py:158: UserWarning: [17:28:39] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/ibtissama/anaconda3/lib/python3.10/site-packages/xgboost/core.py:158: UserWarning: [17:28:39] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/ibtissama/anaconda3/lib/python3.10/site-packages/xgboost/core.py:158: UserWarning: [17:28:40] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2025-03-06 17:28:40,459] Trial 49 finished with value: 0.7159459733532356 and parameters: {'n_estimators': 300, 'max_depth': 6, 'learning_rate': 0.0022369327023335443, 'subsample': 0.8545399179978477, 'colsample_bytree': 0.581572827682292}. Best is trial 34 with value: 0.7293700767077682.
# /Users/ibtissama/anaconda3/lib/python3.10/site-packages/xgboost/core.py:158: UserWarning: [17:28:40] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# ✅ Best Hyperparameters Found: {'n_estimators': 400, 'max_depth': 7, 'learning_rate': 0.0062749366799965565, 'subsample': 0.975738982375914, 'colsample_bytree': 0.5493036130608416}
# /Users/ibtissama/anaconda3/lib/python3.10/site-packages/xgboost/core.py:158: UserWarning: [17:28:41] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/ibtissama/anaconda3/lib/python3.10/site-packages/xgboost/core.py:158: UserWarning: [17:28:41] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/ibtissama/anaconda3/lib/python3.10/site-packages/xgboost/core.py:158: UserWarning: [17:28:42] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/ibtissama/anaconda3/lib/python3.10/site-packages/xgboost/core.py:158: UserWarning: [17:28:42] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/ibtissama/anaconda3/lib/python3.10/site-packages/xgboost/core.py:158: UserWarning: [17:28:43] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# 📊 Average Confusion Matrix:
# [[624. 200.]
#  [235. 589.]]
#
# 🎯 Performance Metrics:
# 🔹 Precision (Class 1 - Long Career Players): 0.7455
# 🔹 Recall (Class 1 - Majority): 0.7148
# 🔹 F1-score (Class 1 - Long Career Players): 0.7294
# 🔹 Precision (Class 0 - Short Career Players): 0.7282
# 🔹 Recall (Class 0 - Minority): 0.7573
# 🔹 F1-score (Class 0 - Short Career Players): 0.7421
#
# 📜 Full Classification Report:
#               precision    recall  f1-score   support
#
#          0.0       0.73      0.76      0.74       824
#          1.0       0.75      0.71      0.73       824
#
#     accuracy                           0.74      1648
#    macro avg       0.74      0.74      0.74      1648
# weighted avg       0.74      0.74      0.74      1648
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=0.5493036130608416, device=None,
#               early_stopping_rounds=None, enable_categorical=False,
#               eval_metric='logloss', feature_types=None, gamma=None,
#               grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=0.0062749366799965565,
#               max_bin=None, max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=7, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=400, n_jobs=None,
#               num_parallel_tree=None, random_state=42, ...)

# %% [markdown]
# ✅ F1-score Classe 1 (Longue carrière) : 0.7294
#
# ✅ F1-score Classe 0 (Courte carrière) : 0.7421
#
# ✅ Accuracy globale :  0.74 (+2 points)
#
# 🔍 Analyse :
#
# Meilleure performance globale avec une précision et un rappel plus équilibrés.
# La classe 1 est mieux identifiée, avec un recall de 0.7148, réduisant ainsi les erreurs où un joueur prometteur est mal classé.
# Le recall de la classe 0 atteint 0.7573, ce qui signifie que le modèle est aussi plus efficace pour détecter les joueurs qui échoueront.
# La précision des deux classes s’améliore, indiquant un modèle plus robuste et plus fiable pour l’aide à la décision.

# %% [markdown]
# 👉 *Optuna a permis d’obtenir les meilleures performances, avec un équilibre optimal entre recall et précision pour les deux classes.*

# %% [markdown]
# #### 6. Analyse des Résultats et Sélection du Meilleur Modèle

# %% [markdown]
# L’objectif est de choisir le modèle de classification offrant le meilleur compromis entre précision et recall, tout en assurant une bonne généralisation sur l’ensemble des joueurs.

# %% [markdown]
# 1- Random Forest (RF)
#
# Meilleure précision (0.7523) pour la classe 1 (joueurs avec longue carrière). Meilleur F1-score global (0.7310 pour classe 1 et 0.7447 pour classe 0). Bon rappel pour la classe 0 (0.7644), garantissant que les joueurs qui échoueront en NBA sont bien identifiés.
#
# 🔻 Léger déficit en rappel pour la classe 1 (0.7123), ce qui signifie qu’il rate quelques talents prometteurs.
#
# 2️- Balanced Random Forest (BalancedRF)
#
# Bonne gestion du déséquilibre des classes, mais précision et rappel plus faibles que RF. F1-score global plus faible (0.7209 et 0.7336), ce qui montre une performance légèrement inférieure à RF et XGBoost.
#
# 🔻 Moins performant que RF et XGBoost pour la détection des talents prometteurs.
#
# 3️- XGBoost
#
# Très bon équilibre entre précision et rappel pour les deux classes. F1-score légèrement inférieur à RF (0.7294 pour la classe 1 et 0.7421 pour la classe 0).Meilleur rappel (0.7148) pour la classe 1, ce qui signifie qu'il identifie plus de joueurs prometteurs que RF.
#
# 🔻 Précision légèrement inférieure à RF (0.7455 vs. 0.7523) → peut générer plus de faux positifs (mauvais investissements).
#
#
# *Le meilleur modèle est le Random Forest (RF) optimisé avec Optuna.*
#
# Meilleur compromis entre précision et rappel pour la classe 1 (joueurs avec longue carrière).Meilleur F1-score global, garantissant un bon équilibre entre les erreurs de classification.Meilleure précision générale, réduisant ainsi les faux positifs (évite de sélectionner des joueurs qui ne performeront pas).

# %%
# Enregistrer le meilleut modèle
import joblib
joblib.dump(rf_model, "rf_model.pkl")
print("✅ Modèle RandomForest enregistré avec succès sous 'rf_model.pkl'")
# Out:
# ✅ Modèle RandomForest enregistré avec succès sous 'rf_model.pkl'
